# %% [markdown]
# <a href="https://colab.research.google.com/github/AsimaZaheer/Stress-Detection/blob/main/Binary%20Stress%20Detection%20with%20LSTM%2BCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python3
"""
WESAD SUBJECT-INDEPENDENT STRESS DETECTION FRAMEWORK (v3)

LOSO Cross-Validation
Multi-Rate Multi-Modal CNN-BiGRU + Handcrafted Features
Google Colab + Google Drive
Robust WESAD ZIP/FOLDER detection

IMPORTANT:
- Put WESAD.zip in: /content/drive/MyDrive/WESAD.zip
- Run this entire file/cell.
- The loader searches recursively, so extra ZIP folders are okay.
- S1 and S12 are excluded.
- Binary classification:
    0 = Baseline
    1 = Stress
- Amusement windows are excluded.
"""

# =============================================================================
# 1. GOOGLE DRIVE + ROBUST DATASET SETUP
# =============================================================================

import os
import sys
import copy
import pickle
import zipfile
import shutil
import warnings

try:
    from google.colab import drive
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    drive.mount("/content/drive")

    WESAD_ZIP = "/content/drive/MyDrive/WESAD.zip"
    WESAD_DIR = "/content/WESAD"

    if not os.path.isfile(WESAD_ZIP):
        raise FileNotFoundError(
            "\nWESAD.zip was not found at:\n"
            f"{WESAD_ZIP}\n\n"
            "Upload WESAD.zip to Google Drive > MyDrive and run again."
        )

    print(f"[INFO] WESAD ZIP found: {WESAD_ZIP}")

    existing_subject_files = {}

    for root, dirs, files in os.walk("/content"):
        for filename in files:

            if filename.lower().endswith(".pkl"):

                stem = os.path.splitext(
                    filename
                )[0].upper()

                if stem.startswith("S") and stem[1:].isdigit():

                    existing_subject_files[
                        stem
                    ] = os.path.join(
                        root,
                        filename
                    )

    if len(existing_subject_files) == 0:

        print(
            "[INFO] No WESAD subject pickle files found."
        )

        print(
            "[INFO] Extracting WESAD.zip..."
        )

        if os.path.exists(WESAD_DIR):

            print(
                f"[INFO] Removing incomplete directory: "
                f"{WESAD_DIR}"
            )

            shutil.rmtree(
                WESAD_DIR
            )

        with zipfile.ZipFile(
            WESAD_ZIP,
            "r"
        ) as z:

            z.extractall(
                "/content"
            )

        print(
            "[INFO] Extraction completed."
        )

    else:

        print(
            f"[INFO] Found "
            f"{len(existing_subject_files)} "
            f"existing pickle file(s). "
            "Using existing extracted data."
        )

else:

    WESAD_DIR = "./WESAD"
    WESAD_ZIP = None

    print(
        f"[WARNING] Not running in Colab. "
        f"Assuming dataset is at {WESAD_DIR}"
    )


# =============================================================================
# 2. LIBRARIES
# =============================================================================

import numpy as np
import pandas as pd

from scipy import stats
from scipy.signal import (
    resample,
    find_peaks,
    butter,
    filtfilt
)

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
)

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import (
    Dataset,
    DataLoader
)

import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings(
    "ignore"
)


# =============================================================================
# 3. CONFIGURATION
# =============================================================================

ALL_SUBJECTS = [
    f"S{i}"
    for i in range(2, 18)
    if i != 12
]

BVP_SR = 64
ACC_SR = 32
EDA_SR = 4
TEMP_SR = 4
LABEL_SR = 700

HR_SR = 32
LR_SR = 4

WINDOW_SEC = 60
STEP_SEC = 5

HR_LEN = WINDOW_SEC * HR_SR
LR_LEN = WINDOW_SEC * LR_SR

FEAT_DIM = 14


# =============================================================================
# BINARY CLASSIFICATION
# =============================================================================
#
# Original WESAD labels:
# 1 = Baseline
# 2 = Stress
# 3 = Amusement
#
# Binary setup:
# 1 -> 0 = Baseline
# 2 -> 1 = Stress
# 3 = excluded
# =============================================================================

VALID_LABELS_ORIG = [
    1,
    2
]

LABEL_MAP = {
    1: 0,
    2: 1,
}

CLASS_NAMES = [
    "Baseline",
    "Stress",
]

NUM_CLASSES = 2


# =============================================================================
# TRAINING CONFIGURATION
# =============================================================================

BATCH_SIZE = 64

EPOCHS = 40

EARLY_STOP_PATIENCE = 8

LEARNING_RATE = 7e-4

WEIGHT_DECAY = 1e-4

DROPOUT_RATE = 0.35

GRAD_CLIP_NORM = 5.0

SEED = 42

NUM_WORKERS = 0

TRAIN_DROP_LAST = True


DEVICE = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

print(
    f"[INFO] Using device: {DEVICE}"
)

np.random.seed(
    SEED
)

torch.manual_seed(
    SEED
)

if torch.cuda.is_available():

    torch.cuda.manual_seed_all(
        SEED
    )


# =============================================================================
# 4. ROBUST WESAD FILE SEARCH
# =============================================================================

def find_subject_pickle(
    subject_id,
    search_roots=None
):

    """
    Find <subject_id>.pkl recursively.

    Handles structures such as:

        /content/WESAD/S2/S2.pkl
        /content/WESAD/S2.pkl
        /content/WESAD/WESAD/S2/S2.pkl
        /content/S2/S2.pkl
    """

    subject_id = subject_id.upper()

    if search_roots is None:

        search_roots = []

        if os.path.exists(
            "/content"
        ):

            search_roots.append(
                "/content"
            )

        if os.path.exists(
            WESAD_DIR
        ):

            search_roots.append(
                WESAD_DIR
            )

        if (
            not IN_COLAB
            and os.path.exists(".")
        ):

            search_roots.append(
                "."
            )

    unique_roots = []

    for root in search_roots:

        root = os.path.abspath(
            root
        )

        if (
            root not in unique_roots
            and os.path.exists(root)
        ):

            unique_roots.append(
                root
            )

    target = (
        f"{subject_id}.pkl"
    )

    candidates = []

    for root in unique_roots:

        for current_root, dirs, files in os.walk(
            root
        ):

            for filename in files:

                if filename.lower() == target.lower():

                    candidates.append(
                        os.path.join(
                            current_root,
                            filename
                        )
                    )

    candidates.sort(
        key=lambda p: (
            0
            if os.path.basename(
                os.path.dirname(p)
            ).upper() == subject_id
            else 1,
            len(p),
        )
    )

    if candidates:

        return candidates[0]

    return None


def load_subject_data(
    subject_id,
    wesad_dir=None
):

    """
    Load one WESAD subject pickle.
    """

    if wesad_dir is None:

        wesad_dir = WESAD_DIR

    pkl_path = find_subject_pickle(
        subject_id
    )

    if pkl_path is None:

        raise FileNotFoundError(
            f"Cannot find {subject_id}.pkl under /content.\n"
            f"Expected something like:\n"
            f"  {wesad_dir}/{subject_id}/{subject_id}.pkl"
        )

    print(
        f"  [FOUND] {pkl_path}"
    )

    with open(
        pkl_path,
        "rb"
    ) as f:

        data = pickle.load(
            f,
            encoding="latin1"
        )

    if not isinstance(
        data,
        dict
    ):

        raise ValueError(
            f"{subject_id}.pkl loaded, "
            "but the content is not a dictionary."
        )

    if (
        "signal" not in data
        or "wrist" not in data["signal"]
    ):

        raise ValueError(
            f"{subject_id}.pkl does not contain "
            "signal['wrist']."
        )

    return data


# =============================================================================
# 5. DATASET VERIFICATION
# =============================================================================

def verify_wesad_subjects():

    """
    Check which expected subjects can actually be found.
    """

    print(
        "\n" + "=" * 70
    )

    print(
        "WESAD DATASET VERIFICATION"
    )

    print(
        "=" * 70
    )

    found = {}

    missing = []

    for subject in ALL_SUBJECTS:

        path = find_subject_pickle(
            subject
        )

        if path is not None:

            found[
                subject
            ] = path

            print(
                f"[OK]      {subject}: {path}"
            )

        else:

            missing.append(
                subject
            )

            print(
                f"[MISSING] {subject}"
            )

    print(
        "-" * 70
    )

    print(
        f"[INFO] Found "
        f"{len(found)}/{len(ALL_SUBJECTS)} "
        "expected subjects."
    )

    if missing:

        print(
            f"[INFO] Missing subjects: {missing}"
        )

    print(
        "=" * 70
    )

    return found


# =============================================================================
# 6. WRIST SIGNAL EXTRACTION
# =============================================================================

def extract_wrist_signals(
    subject_data
):

    """
    Extract:

      BVP
      EDA
      TEMP
      ACC magnitude
      labels
    """

    wrist_data = (
        subject_data[
            "signal"
        ][
            "wrist"
        ]
    )

    required = [
        "BVP",
        "EDA",
        "TEMP",
        "ACC"
    ]

    for key in required:

        if key not in wrist_data:

            raise KeyError(
                f"Missing wrist signal: {key}"
            )

    if "label" not in subject_data:

        raise KeyError(
            "Missing subject label."
        )

    bvp = np.asarray(
        wrist_data["BVP"]
    ).flatten().astype(
        np.float32
    )

    eda = np.asarray(
        wrist_data["EDA"]
    ).flatten().astype(
        np.float32
    )

    temp = np.asarray(
        wrist_data["TEMP"]
    ).flatten().astype(
        np.float32
    )

    acc = np.asarray(
        wrist_data["ACC"]
    ).astype(
        np.float32
    )

    if (
        acc.ndim != 2
        or acc.shape[1] != 3
    ):

        raise ValueError(
            f"ACC has unexpected shape: "
            f"{acc.shape}"
        )

    acc_mag = np.sqrt(
        np.sum(
            acc ** 2,
            axis=1
        )
    ).astype(
        np.float32
    )

    labels = np.asarray(
        subject_data["label"]
    ).flatten()

    return (
        bvp,
        eda,
        temp,
        acc_mag,
        labels,
    )


# =============================================================================
# 7. EDA PROCESSING
# =============================================================================

def decompose_eda(
    eda_seg,
    fs=EDA_SR
):

    """
    Split EDA into tonic and phasic components.
    """

    eda_seg = np.asarray(
        eda_seg,
        dtype=np.float64
    )

    if len(eda_seg) == 0:

        return (
            np.zeros(0),
            np.zeros(0)
        )

    if len(eda_seg) < fs * 4:

        mean_value = np.mean(
            eda_seg
        )

        tonic = np.full_like(
            eda_seg,
            mean_value
        )

    else:

        try:

            b, a = butter(
                2,
                0.05 / (fs / 2),
                btype="low"
            )

            tonic = filtfilt(
                b,
                a,
                eda_seg
            )

        except Exception:

            tonic = np.full_like(
                eda_seg,
                np.mean(eda_seg)
            )

    phasic = (
        eda_seg - tonic
    )

    return (
        tonic,
        phasic
    )


# =============================================================================
# 8. HRV FEATURES
# =============================================================================

def compute_hrv_features(
    bvp_seg,
    fs=BVP_SR
):

    """
    Return:

      mean HR
      HR std
      RMSSD
      HR range
      beat count
    """

    if len(bvp_seg) < fs * 5:

        return np.zeros(
            5,
            dtype=np.float32
        )

    sig = np.asarray(
        bvp_seg,
        dtype=np.float64
    )

    sig = (
        sig - np.mean(sig)
    )

    min_distance = max(
        int(
            fs * 60 / 180
        ),
        1
    )

    try:

        peaks, _ = find_peaks(
            sig,
            distance=min_distance
        )

    except Exception:

        return np.zeros(
            5,
            dtype=np.float32
        )

    if len(peaks) < 3:

        return np.zeros(
            5,
            dtype=np.float32
        )

    ibi = (
        np.diff(peaks) / fs
    )

    if len(ibi) == 0:

        return np.zeros(
            5,
            dtype=np.float32
        )

    hr = (
        60.0 / ibi
    )

    valid = (
        (hr > 30)
        & (hr < 220)
        & np.isfinite(hr)
    )

    hr = hr[
        valid
    ]

    if len(hr) < 2:

        return np.zeros(
            5,
            dtype=np.float32
        )

    mean_hr = np.mean(
        hr
    )

    std_hr = np.std(
        hr
    )

    hr_range = (
        np.max(hr)
        - np.min(hr)
    )

    ibi_valid = (
        60.0 / hr
    )

    if len(ibi_valid) > 1:

        rmssd = np.sqrt(
            np.mean(
                np.diff(
                    ibi_valid
                ) ** 2
            )
        )

    else:

        rmssd = 0.0

    beat_count = float(
        len(hr)
    )

    return np.array(
        [
            mean_hr,
            std_hr,
            rmssd,
            hr_range,
            beat_count,
        ],
        dtype=np.float32
    )


# =============================================================================
# 9. EDA FEATURES
# =============================================================================

def compute_eda_features(
    eda_seg,
    fs=EDA_SR
):

    """
    Return:

      mean SCL
      SCR count
      mean SCR amplitude
      phasic standard deviation
    """

    if len(eda_seg) < fs * 10:

        return np.zeros(
            4,
            dtype=np.float32
        )

    tonic, phasic = decompose_eda(
        eda_seg,
        fs
    )

    try:

        scr_peaks, _ = find_peaks(
            phasic,
            height=0.01,
            distance=max(
                fs,
                1
            )
        )

    except Exception:

        scr_peaks = np.array(
            [],
            dtype=int
        )

    mean_scl = float(
        np.mean(tonic)
    )

    scr_count = float(
        len(scr_peaks)
    )

    if len(scr_peaks) > 0:

        mean_scr_amp = float(
            np.mean(
                phasic[
                    scr_peaks
                ]
            )
        )

    else:

        mean_scr_amp = 0.0

    phasic_std = float(
        np.std(phasic)
    )

    return np.array(
        [
            mean_scl,
            scr_count,
            mean_scr_amp,
            phasic_std,
        ],
        dtype=np.float32
    )


# =============================================================================
# 10. ACC FEATURES
# =============================================================================

def compute_acc_features(
    acc_seg
):

    """
    Return:

      mean movement
      std movement
      max movement
    """

    if len(acc_seg) == 0:

        return np.zeros(
            3,
            dtype=np.float32
        )

    return np.array(
        [
            np.mean(acc_seg),
            np.std(acc_seg),
            np.max(acc_seg),
        ],
        dtype=np.float32
    )


# =============================================================================
# 11. TEMP FEATURES
# =============================================================================

def compute_temp_features(
    temp_seg
):

    """
    Return:

      mean temperature
      linear temperature slope
    """

    if len(temp_seg) < 2:

        return np.zeros(
            2,
            dtype=np.float32
        )

    mean_temp = np.mean(
        temp_seg
    )

    x = np.arange(
        len(temp_seg),
        dtype=np.float64
    )

    try:

        slope = np.polyfit(
            x,
            temp_seg,
            1
        )[0]

    except Exception:

        slope = 0.0

    return np.array(
        [
            mean_temp,
            slope,
        ],
        dtype=np.float32
    )


# =============================================================================
# 12. MULTI-RATE WINDOW CREATION
# =============================================================================

def create_multirate_windows(
    bvp,
    eda,
    temp,
    acc_mag,
    labels
):

    """
    Build 60-second windows with 5-second stride.

    HR branch:
        BVP + ACC at 32 Hz

    LR branch:
        EDA tonic + EDA phasic + TEMP at 4 Hz

    Handcrafted features:
        14 total

    Binary window labels:
        0 = Baseline
        1 = Stress

    Amusement windows are excluded.
    """

    duration = min(
        len(bvp) / BVP_SR,
        len(eda) / EDA_SR,
        len(temp) / TEMP_SR,
        len(acc_mag) / ACC_SR,
        len(labels) / LABEL_SR,
    )

    hr_windows = []

    lr_windows = []

    feat_windows = []

    win_labels = []

    start = 0.0

    while start + WINDOW_SEC <= duration:

        end = (
            start + WINDOW_SEC
        )

        bvp_seg = bvp[
            int(start * BVP_SR):
            int(end * BVP_SR)
        ]

        acc_seg = acc_mag[
            int(start * ACC_SR):
            int(end * ACC_SR)
        ]

        eda_seg = eda[
            int(start * EDA_SR):
            int(end * EDA_SR)
        ]

        temp_seg = temp[
            int(start * TEMP_SR):
            int(end * TEMP_SR)
        ]

        label_seg = labels[
            int(start * LABEL_SR):
            int(end * LABEL_SR)
        ]

        if len(label_seg) == 0:

            start += STEP_SEC
            continue

        # -----------------------------------------------------------------
        # Majority label
        # -----------------------------------------------------------------

        try:

            majority_result = stats.mode(
                label_seg,
                keepdims=True
            )

            majority = int(
                majority_result.mode[0]
            )

        except Exception:

            start += STEP_SEC
            continue

        # Only Baseline and Stress are valid.
        # Amusement is excluded.

        if majority not in VALID_LABELS_ORIG:

            start += STEP_SEC
            continue

        # -----------------------------------------------------------------
        # Resample high-rate signals
        # -----------------------------------------------------------------

        try:

            bvp_r = resample(
                bvp_seg,
                HR_LEN
            )

            acc_r = resample(
                acc_seg,
                HR_LEN
            )

            tonic_seg, phasic_seg = (
                decompose_eda(
                    eda_seg
                )
            )

            tonic_r = resample(
                tonic_seg,
                LR_LEN
            )

            phasic_r = resample(
                phasic_seg,
                LR_LEN
            )

            temp_r = resample(
                temp_seg,
                LR_LEN
            )

        except Exception:

            start += STEP_SEC
            continue

        # -----------------------------------------------------------------
        # HR branch
        # 2 channels:
        # BVP + ACC
        # -----------------------------------------------------------------

        hr_win = np.stack(
            [
                bvp_r,
                acc_r
            ],
            axis=-1
        ).astype(
            np.float32
        )

        # -----------------------------------------------------------------
        # LR branch
        # 3 channels:
        # EDA tonic + EDA phasic + TEMP
        # -----------------------------------------------------------------

        lr_win = np.stack(
            [
                tonic_r,
                phasic_r,
                temp_r
            ],
            axis=-1
        ).astype(
            np.float32
        )

        # -----------------------------------------------------------------
        # 14 handcrafted features
        # -----------------------------------------------------------------

        feat_vec = np.concatenate(
            [
                compute_hrv_features(
                    bvp_seg
                ),

                compute_eda_features(
                    eda_seg
                ),

                compute_acc_features(
                    acc_seg
                ),

                compute_temp_features(
                    temp_seg
                ),
            ]
        ).astype(
            np.float32
        )

        if len(feat_vec) != FEAT_DIM:

            raise ValueError(
                f"Expected {FEAT_DIM} features, "
                f"got {len(feat_vec)}."
            )

        hr_windows.append(
            hr_win
        )

        lr_windows.append(
            lr_win
        )

        feat_windows.append(
            feat_vec
        )

        win_labels.append(
            LABEL_MAP[
                majority
            ]
        )

        start += STEP_SEC

    if len(win_labels) == 0:

        return (
            np.zeros(
                (
                    0,
                    HR_LEN,
                    2
                ),
                dtype=np.float32
            ),

            np.zeros(
                (
                    0,
                    LR_LEN,
                    3
                ),
                dtype=np.float32
            ),

            np.zeros(
                (
                    0,
                    FEAT_DIM
                ),
                dtype=np.float32
            ),

            np.zeros(
                0,
                dtype=int
            ),
        )

    return (
        np.asarray(
            hr_windows,
            dtype=np.float32
        ),

        np.asarray(
            lr_windows,
            dtype=np.float32
        ),

        np.asarray(
            feat_windows,
            dtype=np.float32
        ),

        np.asarray(
            win_labels,
            dtype=int
        ),
    )


# =============================================================================
# 13. SUBJECT BASELINE CALIBRATION
# =============================================================================

def subject_baseline_calibration(
    hr_w,
    lr_w,
    feat_w,
    labels
):

    """
    Z-score using only the subject's Baseline windows.

    HR branch:
        BVP + ACC -> 2 channels

    LR branch:
        EDA tonic + EDA phasic + TEMP -> 3 channels

    Features:
        14 handcrafted features
    """

    baseline_mask = (
        labels == 0
    )

    if not np.any(
        baseline_mask
    ):

        print(
            "[WARNING] No baseline windows found "
            "for subject calibration. Skipping."
        )

        return (
            hr_w,
            lr_w,
            feat_w
        )

    def zscore_by_baseline(
        arr
    ):

        base = arr[
            baseline_mask
        ]

        if arr.ndim == 3:

            base_flat = base.reshape(
                -1,
                base.shape[-1]
            )

            mean = base_flat.mean(
                axis=0
            )

            std = base_flat.std(
                axis=0
            )

        else:

            mean = base.mean(
                axis=0
            )

            std = base.std(
                axis=0
            )

        std = np.asarray(
            std,
            dtype=np.float32
        )

        std[
            std == 0
        ] = 1e-8

        return (
            arr - mean
        ) / std

    # -----------------------------------------------------------------
    # IMPORTANT FIX
    #
    # HR -> hr_w
    # LR -> lr_w
    # Features -> feat_w
    # -----------------------------------------------------------------

    hr_calibrated = (
        zscore_by_baseline(
            hr_w
        )
    )

    lr_calibrated = (
        zscore_by_baseline(
            lr_w
        )
    )

    feat_calibrated = (
        zscore_by_baseline(
            feat_w
        )
    )

    return (
        hr_calibrated,
        lr_calibrated,
        feat_calibrated
    )


# =============================================================================
# 14. SUBJECT PREPARATION
# =============================================================================

def prepare_subject_dataset(
    subject_id,
    wesad_dir
):

    print(
        f"  [SUBJECT {subject_id}] "
        "Loading raw data..."
    )

    raw_data = load_subject_data(
        subject_id,
        wesad_dir
    )

    print(
        f"  [SUBJECT {subject_id}] "
        "Extracting wrist signals..."
    )

    (
        bvp,
        eda,
        temp,
        acc_mag,
        labels,
    ) = extract_wrist_signals(
        raw_data
    )

    print(
        f"  [SUBJECT {subject_id}] "
        f"BVP={len(bvp)} | "
        f"EDA={len(eda)} | "
        f"TEMP={len(temp)} | "
        f"ACC={len(acc_mag)} | "
        f"Labels={len(labels)}"
    )

    print(
        f"  [SUBJECT {subject_id}] "
        f"Building {WINDOW_SEC}s windows "
        f"with {STEP_SEC}s step..."
    )

    (
        hr_w,
        lr_w,
        feat_w,
        win_labels,
    ) = create_multirate_windows(
        bvp,
        eda,
        temp,
        acc_mag,
        labels
    )

    if len(win_labels) == 0:

        print(
            f"  [WARNING] {subject_id}: "
            "No valid windows."
        )

        return (
            hr_w,
            lr_w,
            feat_w,
            win_labels
        )

    print(
        f"  [SUBJECT {subject_id}] "
        "Applying baseline calibration..."
    )

    (
        hr_c,
        lr_c,
        feat_c,
    ) = subject_baseline_calibration(
        hr_w,
        lr_w,
        feat_w,
        win_labels
    )

    # -----------------------------------------------------------------
    # Shape verification
    # -----------------------------------------------------------------

    if hr_c.ndim == 3:

        if hr_c.shape[-1] != 2:

            raise ValueError(
                f"HR branch must have 2 channels, "
                f"but got shape {hr_c.shape}"
            )

    if lr_c.ndim == 3:

        if lr_c.shape[-1] != 3:

            raise ValueError(
                f"LR branch must have 3 channels, "
                f"but got shape {lr_c.shape}"
            )

    counts = dict(
        zip(
            *np.unique(
                win_labels,
                return_counts=True
            )
        )
    )

    print(
        f"  [SUBJECT {subject_id}] "
        f"Done: {len(win_labels)} windows | "
        f"Class distribution: {counts}"
    )

    print(
        f"  [SUBJECT {subject_id}] "
        f"HR shape: {hr_c.shape} | "
        f"LR shape: {lr_c.shape} | "
        f"Features shape: {feat_c.shape}"
    )

    return (
        hr_c,
        lr_c,
        feat_c,
        win_labels
    )


# =============================================================================
# 15. PYTORCH DATASET
# =============================================================================

class WindowDataset(
    Dataset
):

    def __init__(
        self,
        hr,
        lr,
        feat,
        y,
        augment=False
    ):

        self.hr = torch.from_numpy(
            np.asarray(
                hr
            )
        ).float()

        self.lr = torch.from_numpy(
            np.asarray(
                lr
            )
        ).float()

        self.feat = torch.from_numpy(
            np.asarray(
                feat
            )
        ).float()

        self.y = torch.from_numpy(
            np.asarray(
                y
            )
        ).long()

        self.augment = augment

    def __len__(
        self
    ):

        return len(
            self.y
        )

    def __getitem__(
        self,
        idx
    ):

        hr = self.hr[
            idx
        ].clone()

        lr = self.lr[
            idx
        ].clone()

        feat = self.feat[
            idx
        ]

        y = self.y[
            idx
        ]

        if self.augment:

            if np.random.rand() < 0.5:

                hr = (
                    hr
                    + torch.randn_like(hr)
                    * 0.05
                )

            if np.random.rand() < 0.5:

                lr = (
                    lr
                    + torch.randn_like(lr)
                    * 0.05
                )

            if np.random.rand() < 0.3:

                scale = (
                    1.0
                    + (
                        np.random.rand()
                        - 0.5
                    )
                    * 0.2
                )

                hr = (
                    hr * scale
                )

        return (
            hr,
            lr,
            feat,
            y
        )


# =============================================================================
# 16. MODEL: HIGH-RATE BRANCH
# =============================================================================

class HRBranch(
    nn.Module
):

    def __init__(
        self,
        in_ch=2,
        out_len=60,
        dropout=DROPOUT_RATE
    ):

        super().__init__()

        self.cnn = nn.Sequential(

            nn.Conv1d(
                in_ch,
                32,
                kernel_size=5,
                padding=2
            ),

            nn.BatchNorm1d(
                32
            ),

            nn.ReLU(),

            nn.MaxPool1d(
                2
            ),

            nn.Conv1d(
                32,
                64,
                kernel_size=5,
                padding=2
            ),

            nn.BatchNorm1d(
                64
            ),

            nn.ReLU(),

            nn.MaxPool1d(
                2
            ),

            nn.Conv1d(
                64,
                64,
                kernel_size=3,
                padding=1
            ),

            nn.BatchNorm1d(
                64
            ),

            nn.ReLU(),

            nn.Dropout(
                dropout
            ),

            nn.AdaptiveAvgPool1d(
                out_len
            ),
        )

        self.gru = nn.GRU(
            input_size=64,
            hidden_size=64,
            num_layers=1,
            batch_first=True,
            bidirectional=True,
        )

    def forward(
        self,
        x
    ):

        x = x.permute(
            0,
            2,
            1
        )

        x = self.cnn(
            x
        )

        x = x.permute(
            0,
            2,
            1
        )

        out, _ = self.gru(
            x
        )

        return out.mean(
            dim=1
        )


# =============================================================================
# 17. MODEL: LOW-RATE BRANCH
# =============================================================================

class LRBranch(
    nn.Module
):

    def __init__(
        self,
        in_ch=3,
        dropout=DROPOUT_RATE
    ):

        super().__init__()

        self.cnn = nn.Sequential(

            nn.Conv1d(
                in_ch,
                32,
                kernel_size=3,
                padding=1
            ),

            nn.BatchNorm1d(
                32
            ),

            nn.ReLU(),

            nn.MaxPool1d(
                2
            ),

            nn.Conv1d(
                32,
                64,
                kernel_size=3,
                padding=1
            ),

            nn.BatchNorm1d(
                64
            ),

            nn.ReLU(),

            nn.Dropout(
                dropout
            ),
        )

    def forward(
        self,
        x
    ):

        x = x.permute(
            0,
            2,
            1
        )

        x = self.cnn(
            x
        )

        avg = x.mean(
            dim=2
        )

        mx, _ = x.max(
            dim=2
        )

        return torch.cat(
            [
                avg,
                mx
            ],
            dim=1
        )


# =============================================================================
# 18. MODEL: FEATURE BRANCH
# =============================================================================

class FeatureBranch(
    nn.Module
):

    def __init__(
        self,
        in_dim=FEAT_DIM,
        dropout=DROPOUT_RATE
    ):

        super().__init__()

        self.net = nn.Sequential(

            nn.Linear(
                in_dim,
                32
            ),

            nn.LayerNorm(
                32
            ),

            nn.ReLU(),

            nn.Dropout(
                dropout
            ),
        )

    def forward(
        self,
        x
    ):

        return self.net(
            x
        )


# =============================================================================
# 19. MULTI-MODAL CNN-BiGRU
# =============================================================================

class MultiModalCNNBiGRU(
    nn.Module
):

    def __init__(
        self,
        num_classes=NUM_CLASSES,
        dropout=DROPOUT_RATE
    ):

        super().__init__()

        self.hr_branch = HRBranch(
            dropout=dropout
        )

        self.lr_branch = LRBranch(
            dropout=dropout
        )

        self.feat_branch = FeatureBranch(
            dropout=dropout
        )

        fusion_dim = (
            128
            + 128
            + 32
        )

        self.classifier = nn.Sequential(

            nn.Linear(
                fusion_dim,
                128
            ),

            nn.ReLU(),

            nn.Dropout(
                dropout
            ),

            nn.Linear(
                128,
                num_classes
            ),
        )

    def forward(
        self,
        hr,
        lr,
        feat
    ):

        e1 = self.hr_branch(
            hr
        )

        e2 = self.lr_branch(
            lr
        )

        e3 = self.feat_branch(
            feat
        )

        fused = torch.cat(
            [
                e1,
                e2,
                e3
            ],
            dim=1
        )

        return self.classifier(
            fused
        )


# =============================================================================
# 20. TRAINING
# =============================================================================

def train_one_epoch(
    model,
    loader,
    criterion,
    optimizer,
    device
):

    model.train()

    total_loss = 0.0

    all_preds = []

    all_true = []

    for hr, lr, feat, y in loader:

        hr = hr.to(
            device
        )

        lr = lr.to(
            device
        )

        feat = feat.to(
            device
        )

        y = y.to(
            device
        )

        optimizer.zero_grad()

        out = model(
            hr,
            lr,
            feat
        )

        loss = criterion(
            out,
            y
        )

        loss.backward()

        torch.nn.utils.clip_grad_norm_(
            model.parameters(),
            GRAD_CLIP_NORM
        )

        optimizer.step()

        total_loss += (
            loss.item()
            * hr.size(0)
        )

        all_preds.extend(
            out.argmax(
                dim=1
            )
            .detach()
            .cpu()
            .numpy()
        )

        all_true.extend(
            y.detach()
            .cpu()
            .numpy()
        )

    if len(
        loader.dataset
    ) == 0:

        return (
            0.0,
            0.0
        )

    avg_loss = (
        total_loss
        / len(loader.dataset)
    )

    acc = accuracy_score(
        all_true,
        all_preds
    )

    return (
        avg_loss,
        acc
    )


# =============================================================================
# 21. EVALUATION
# =============================================================================

def evaluate(
    model,
    loader,
    criterion,
    device
):

    model.eval()

    total_loss = 0.0

    all_preds = []

    all_true = []

    all_probs = []

    with torch.no_grad():

        for hr, lr, feat, y in loader:

            hr = hr.to(
                device
            )

            lr = lr.to(
                device
            )

            feat = feat.to(
                device
            )

            y = y.to(
                device
            )

            out = model(
                hr,
                lr,
                feat
            )

            loss = criterion(
                out,
                y
            )

            total_loss += (
                loss.item()
                * hr.size(0)
            )

            probs = torch.softmax(
                out,
                dim=1
            ).cpu().numpy()

            preds = out.argmax(
                dim=1
            ).cpu().numpy()

            true = y.cpu().numpy()

            all_probs.extend(
                probs
            )

            all_preds.extend(
                preds
            )

            all_true.extend(
                true
            )

    if len(
        loader.dataset
    ) == 0:

        return (
            0.0,
            0.0,
            np.array([]),
            np.array([]),
            np.array([]),
        )

    avg_loss = (
        total_loss
        / len(loader.dataset)
    )

    acc = accuracy_score(
        all_true,
        all_preds
    )

    return (
        avg_loss,
        acc,
        np.asarray(
            all_true
        ),
        np.asarray(
            all_preds
        ),
        np.asarray(
            all_probs
        ),
    )


# =============================================================================
# 22. LOSO FOLD
# =============================================================================

def run_loso_fold(
    subject_data_dict,
    test_subject_id,
    all_subjects
):

    print(
        "\n" + "=" * 70
    )

    print(
        f"[FOLD] Test Subject: "
        f"{test_subject_id}"
    )

    print(
        "=" * 70
    )

    train_subjects_all = [
        s
        for s in all_subjects
        if s != test_subject_id
    ]

    if len(
        train_subjects_all
    ) < 2:

        print(
            "[FOLD] Not enough training subjects."
        )

        return (
            None,
            None
        )

    # Deterministic validation subject.
    # The test subject remains untouched.

    val_subject = (
        train_subjects_all[0]
    )

    train_subjects_final = (
        train_subjects_all[1:]
    )

    def gather(
        subjs
    ):

        hr_l = []

        lr_l = []

        feat_l = []

        y_l = []

        for s in subjs:

            (
                hr,
                lr,
                feat,
                y
            ) = subject_data_dict[
                s
            ]

            if len(y) > 0:

                hr_l.append(
                    hr
                )

                lr_l.append(
                    lr
                )

                feat_l.append(
                    feat
                )

                y_l.append(
                    y
                )

        if not y_l:

            return (
                np.zeros(
                    (
                        0,
                        HR_LEN,
                        2
                    ),
                    dtype=np.float32
                ),

                np.zeros(
                    (
                        0,
                        LR_LEN,
                        3
                    ),
                    dtype=np.float32
                ),

                np.zeros(
                    (
                        0,
                        FEAT_DIM
                    ),
                    dtype=np.float32
                ),

                np.zeros(
                    0,
                    dtype=int
                ),
            )

        return (
            np.concatenate(
                hr_l
            ),

            np.concatenate(
                lr_l
            ),

            np.concatenate(
                feat_l
            ),

            np.concatenate(
                y_l
            ),
        )

    (
        hr_train,
        lr_train,
        feat_train,
        y_train,
    ) = gather(
        train_subjects_final
    )

    (
        hr_val,
        lr_val,
        feat_val,
        y_val,
    ) = subject_data_dict[
        val_subject
    ]

    (
        hr_test,
        lr_test,
        feat_test,
        y_test,
    ) = subject_data_dict[
        test_subject_id
    ]

    if (
        len(y_train) == 0
        or len(y_val) == 0
        or len(y_test) == 0
    ):

        print(
            f"[FOLD] Missing data in "
            f"train/val/test for "
            f"{test_subject_id}. Skipping."
        )

        return (
            None,
            None
        )

    # -----------------------------------------------------------------
    # Scale each deep branch using TRAINING data only.
    # -----------------------------------------------------------------

    def fit_scale_3d(
        train_arr,
        *other_arrs
    ):

        _, _, c = (
            train_arr.shape
        )

        scaler = StandardScaler().fit(
            train_arr.reshape(
                -1,
                c
            )
        )

        def apply(
            arr
        ):

            n2, l2, c2 = (
                arr.shape
            )

            return scaler.transform(
                arr.reshape(
                    -1,
                    c2
                )
            ).reshape(
                n2,
                l2,
                c2
            )

        return (
            apply(
                train_arr
            ),
            *[
                apply(a)
                for a in other_arrs
            ],
        )

    (
        hr_train_s,
        hr_val_s,
        hr_test_s,
    ) = fit_scale_3d(
        hr_train,
        hr_val,
        hr_test
    )

    (
        lr_train_s,
        lr_val_s,
        lr_test_s,
    ) = fit_scale_3d(
        lr_train,
        lr_val,
        lr_test
    )

    feat_scaler = StandardScaler().fit(
        feat_train
    )

    feat_train_s = (
        feat_scaler.transform(
            feat_train
        )
    )

    feat_val_s = (
        feat_scaler.transform(
            feat_val
        )
    )

    feat_test_s = (
        feat_scaler.transform(
            feat_test
        )
    )

    print(
        f"  Train: {len(y_train)} windows | "
        f"Val ({val_subject}): {len(y_val)} | "
        f"Test ({test_subject_id}): {len(y_test)}"
    )

    train_counts = dict(
        zip(
            *np.unique(
                y_train,
                return_counts=True
            )
        )
    )

    print(
        f"  Train class distribution: "
        f"{train_counts}"
    )

    # -----------------------------------------------------------------
    # Class weights
    # -----------------------------------------------------------------

    classes, counts = np.unique(
        y_train,
        return_counts=True
    )

    total = len(
        y_train
    )

    class_weights = np.ones(
        NUM_CLASSES,
        dtype=np.float32
    )

    for idx in range(
        NUM_CLASSES
    ):

        if idx in classes:

            class_weights[
                idx
            ] = (
                total
                / (
                    NUM_CLASSES
                    * counts[
                        classes == idx
                    ][0]
                )
            )

    print(
        "  Class weights:",
        dict(
            zip(
                CLASS_NAMES,
                np.round(
                    class_weights,
                    4
                )
            )
        )
    )

    class_weights_t = torch.tensor(
        class_weights,
        dtype=torch.float32,
        device=DEVICE
    )

    # -----------------------------------------------------------------
    # Data loaders
    # -----------------------------------------------------------------

    train_ds = WindowDataset(
        hr_train_s,
        lr_train_s,
        feat_train_s,
        y_train,
        augment=True
    )

    val_ds = WindowDataset(
        hr_val_s,
        lr_val_s,
        feat_val_s,
        y_val,
        augment=False
    )

    test_ds = WindowDataset(
        hr_test_s,
        lr_test_s,
        feat_test_s,
        y_test,
        augment=False
    )

    train_loader = DataLoader(
        train_ds,
        batch_size=BATCH_SIZE,
        shuffle=True,
        drop_last=True,
        num_workers=NUM_WORKERS,
        pin_memory=torch.cuda.is_available()
    )

    val_loader = DataLoader(
        val_ds,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=torch.cuda.is_available()
    )

    test_loader = DataLoader(
        test_ds,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=torch.cuda.is_available()
    )

    # -----------------------------------------------------------------
    # Model
    # -----------------------------------------------------------------

    torch.manual_seed(
        SEED
        + int(
            test_subject_id[1:]
        )
    )

    if torch.cuda.is_available():

        torch.cuda.manual_seed_all(
            SEED
            + int(
                test_subject_id[1:]
            )
        )

    model = MultiModalCNNBiGRU().to(
        DEVICE
    )

    criterion = nn.CrossEntropyLoss(
        weight=class_weights_t
    )

    optimizer = optim.Adam(
        model.parameters(),
        lr=LEARNING_RATE,
        weight_decay=WEIGHT_DECAY
    )

    scheduler = (
        optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode="min",
            factor=0.5,
            patience=3
        )
    )

    # -----------------------------------------------------------------
    # Training
    # -----------------------------------------------------------------

    best_val_acc = -np.inf

    best_val_loss = np.inf

    best_state = None

    patience_counter = 0

    for epoch in range(
        1,
        EPOCHS + 1
    ):

        (
            train_loss,
            train_acc,
        ) = train_one_epoch(
            model,
            train_loader,
            criterion,
            optimizer,
            DEVICE
        )

        (
            val_loss,
            val_acc,
            _,
            _,
            _,
        ) = evaluate(
            model,
            val_loader,
            criterion,
            DEVICE
        )

        scheduler.step(
            val_loss
        )

        marker = ""

        improved = (
            val_acc > best_val_acc
            or (
                np.isclose(
                    val_acc,
                    best_val_acc
                )
                and val_loss < best_val_loss
            )
        )

        if improved:

            best_val_acc = (
                val_acc
            )

            best_val_loss = (
                val_loss
            )

            best_state = copy.deepcopy(
                model.state_dict()
            )

            patience_counter = 0

            marker = (
                "  <-- BEST (val)"
            )

        else:

            patience_counter += 1

        current_lr = (
            optimizer.param_groups[0][
                "lr"
            ]
        )

        print(
            f"  Epoch [{epoch}/{EPOCHS}] | "
            f"Train Loss: {train_loss:.4f} "
            f"Acc: {train_acc:.4f} | "
            f"Val Loss: {val_loss:.4f} "
            f"Acc: {val_acc:.4f} | "
            f"LR: {current_lr:.2e}"
            f"{marker}"
        )

        if (
            patience_counter
            >= EARLY_STOP_PATIENCE
        ):

            print(
                f"  Early stopping at epoch "
                f"{epoch} "
                f"(no validation improvement "
                f"for {EARLY_STOP_PATIENCE} epochs)."
            )

            break

    # -----------------------------------------------------------------
    # Restore best validation checkpoint.
    # -----------------------------------------------------------------

    if best_state is not None:

        model.load_state_dict(
            best_state
        )

    # -----------------------------------------------------------------
    # Final test evaluation.
    # -----------------------------------------------------------------

    (
        test_loss,
        test_acc,
        y_true,
        y_pred,
        _,
    ) = evaluate(
        model,
        test_loader,
        criterion,
        DEVICE
    )

    test_bal_acc = (
        balanced_accuracy_score(
            y_true,
            y_pred
        )
        if len(y_true) > 0
        else 0.0
    )

    test_f1 = (
        f1_score(
            y_true,
            y_pred,
            average="macro"
        )
        if len(y_true) > 0
        else 0.0
    )

    print(
        f"\n  [FOLD RESULT] "
        f"Subject {test_subject_id} | "
        f"Best Val Acc: {best_val_acc:.4f} | "
        f"TEST Acc: {test_acc:.4f} | "
        f"Balanced Acc: {test_bal_acc:.4f} | "
        f"Macro F1: {test_f1:.4f}"
    )

    return (
        y_true,
        y_pred
    )


# =============================================================================
# 23. CONFUSION MATRIX
# =============================================================================

def plot_confusion_matrix(
    y_true,
    y_pred,
    class_names,
    title="Confusion Matrix (LOSO)"
):

    cm = confusion_matrix(
        y_true,
        y_pred,
        labels=np.arange(
            len(class_names)
        )
    )

    row_sums = cm.sum(
        axis=1,
        keepdims=True
    )

    cm_percent = np.divide(
        cm.astype(float),
        row_sums,
        out=np.zeros_like(
            cm,
            dtype=float
        ),
        where=row_sums != 0
    ) * 100

    fig, ax = plt.subplots(
        figsize=(8, 6)
    )

    sns.heatmap(
        cm_percent,
        annot=True,
        fmt=".1f",
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names,
        cbar_kws={
            "label": "Percentage (%)"
        },
        ax=ax
    )

    for i in range(
        cm.shape[0]
    ):

        for j in range(
            cm.shape[1]
        ):

            count = cm[
                i,
                j
            ]

            ax.text(
                j + 0.5,
                i + 0.72,
                f"(n={count})",
                ha="center",
                va="center",
                color="gray",
                fontsize=9
            )

    ax.set_xlabel(
        "Predicted Label",
        fontsize=12,
        fontweight="bold"
    )

    ax.set_ylabel(
        "True Label",
        fontsize=12,
        fontweight="bold"
    )

    ax.set_title(
        title,
        fontsize=14,
        fontweight="bold",
        pad=15
    )

    plt.tight_layout()

    plt.show()

    return (
        cm,
        cm_percent
    )


# =============================================================================
# 24. MAIN
# =============================================================================

def main():

    print(
        "\n" + "=" * 70
    )

    print(
        "  SUBJECT-INDEPENDENT STRESS DETECTION FRAMEWORK (v3)"
    )

    print(
        "  LOSO | Multi-Rate Multi-Modal CNN-BiGRU + Features"
    )

    print(
        "  Binary Classification: Baseline vs Stress"
    )

    print(
        "  Subjects:",
        ALL_SUBJECTS
    )

    print(
        "=" * 70
    )

    # -----------------------------------------------------------------
    # Verify dataset
    # -----------------------------------------------------------------

    found_subject_paths = (
        verify_wesad_subjects()
    )

    if len(
        found_subject_paths
    ) < 4:

        print(
            "\n[ERROR] Fewer than 4 WESAD subjects "
            "were found."
        )

        print(
            "\nPlease check:"
        )

        print(
            "1. WESAD.zip exists in "
            "/content/drive/MyDrive/"
        )

        print(
            "2. The ZIP actually contains "
            "S2.pkl, S3.pkl, etc."
        )

        print(
            "3. Run the dataset verification cell "
            "again after uploading/extracting."
        )

        return None

    # -----------------------------------------------------------------
    # Preprocess subjects
    # -----------------------------------------------------------------

    subject_data_dict = {}

    print(
        "\n[STEP 1] Preprocessing usable subjects:"
    )

    for subj in ALL_SUBJECTS:

        if subj not in found_subject_paths:

            print(
                f"  [WARNING] Skipping {subj}: "
                "pickle not found."
            )

            subject_data_dict[
                subj
            ] = (
                np.zeros(
                    (
                        0,
                        HR_LEN,
                        2
                    ),
                    dtype=np.float32
                ),

                np.zeros(
                    (
                        0,
                        LR_LEN,
                        3
                    ),
                    dtype=np.float32
                ),

                np.zeros(
                    (
                        0,
                        FEAT_DIM
                    ),
                    dtype=np.float32
                ),

                np.zeros(
                    0,
                    dtype=int
                ),
            )

            print()

            continue

        try:

            (
                hr_c,
                lr_c,
                feat_c,
                y,
            ) = prepare_subject_dataset(
                subj,
                WESAD_DIR
            )

            subject_data_dict[
                subj
            ] = (
                hr_c,
                lr_c,
                feat_c,
                y
            )

        except Exception as e:

            print(
                f"  [ERROR] Failed to process "
                f"{subj}: "
                f"{type(e).__name__}: {e}"
            )

            subject_data_dict[
                subj
            ] = (
                np.zeros(
                    (
                        0,
                        HR_LEN,
                        2
                    ),
                    dtype=np.float32
                ),

                np.zeros(
                    (
                        0,
                        LR_LEN,
                        3
                    ),
                    dtype=np.float32
                ),

                np.zeros(
                    (
                        0,
                        FEAT_DIM
                    ),
                    dtype=np.float32
                ),

                np.zeros(
                    0,
                    dtype=int
                ),
            )

        print()

    # -----------------------------------------------------------------
    # Valid subjects
    # -----------------------------------------------------------------

    valid_subjects = [
        s
        for s in ALL_SUBJECTS
        if len(
            subject_data_dict[
                s
            ][3]
        ) > 0
    ]

    print(
        f"[INFO] {len(valid_subjects)}/"
        f"{len(ALL_SUBJECTS)} subjects "
        "have usable data:"
    )

    print(
        f"       {valid_subjects}"
    )

    if len(
        valid_subjects
    ) < 4:

        print(
            "\n[ERROR] Not enough valid subjects "
            "with usable windows."
        )

        return None

    # -----------------------------------------------------------------
    # LOSO
    # -----------------------------------------------------------------

    print(
        "\n[STEP 2] Running "
        "Leave-One-Subject-Out "
        "Cross-Validation..."
    )

    all_y_true = []

    all_y_pred = []

    fold_accuracies = {}

    fold_balanced_accuracies = {}

    fold_macro_f1 = {}

    for test_subj in valid_subjects:

        (
            y_true_fold,
            y_pred_fold,
        ) = run_loso_fold(
            subject_data_dict,
            test_subj,
            valid_subjects
        )

        if (
            y_true_fold is not None
            and len(y_true_fold) > 0
        ):

            all_y_true.extend(
                y_true_fold
            )

            all_y_pred.extend(
                y_pred_fold
            )

            fold_accuracies[
                test_subj
            ] = accuracy_score(
                y_true_fold,
                y_pred_fold
            )

            fold_balanced_accuracies[
                test_subj
            ] = balanced_accuracy_score(
                y_true_fold,
                y_pred_fold
            )

            fold_macro_f1[
                test_subj
            ] = f1_score(
                y_true_fold,
                y_pred_fold,
                average="macro"
            )

    # -----------------------------------------------------------------
    # Safety check
    # -----------------------------------------------------------------

    if len(
        all_y_true
    ) == 0:

        print(
            "\n[ERROR] No LOSO folds completed."
        )

        return None

    all_y_true = np.asarray(
        all_y_true
    )

    all_y_pred = np.asarray(
        all_y_pred
    )

    # -----------------------------------------------------------------
    # Final results
    # -----------------------------------------------------------------

    print(
        "\n" + "=" * 70
    )

    print(
        "  LOSO CROSS-VALIDATION - FINAL RESULTS"
    )

    print(
        "=" * 70
    )

    print(
        "\nPer-Subject Holdout Results:"
    )

    for subj in fold_accuracies:

        print(
            f"  {subj}: "
            f"Accuracy={fold_accuracies[subj]:.4f} "
            f"({fold_accuracies[subj] * 100:.2f}%) | "
            f"Balanced Acc="
            f"{fold_balanced_accuracies[subj]:.4f} | "
            f"Macro F1="
            f"{fold_macro_f1[subj]:.4f}"
        )

    overall_acc = accuracy_score(
        all_y_true,
        all_y_pred
    )

    overall_bal_acc = (
        balanced_accuracy_score(
            all_y_true,
            all_y_pred
        )
    )

    overall_macro_f1 = f1_score(
        all_y_true,
        all_y_pred,
        average="macro"
    )

    mean_subject_acc = np.mean(
        list(
            fold_accuracies.values()
        )
    )

    std_subject_acc = np.std(
        list(
            fold_accuracies.values()
        )
    )

    print(
        f"\nOverall LOSO Accuracy: "
        f"{overall_acc:.4f} "
        f"({overall_acc * 100:.2f}%)"
    )

    print(
        f"Overall Balanced Accuracy: "
        f"{overall_bal_acc:.4f} "
        f"({overall_bal_acc * 100:.2f}%)"
    )

    print(
        f"Overall Macro F1: "
        f"{overall_macro_f1:.4f}"
    )

    print(
        f"Mean Per-Subject Accuracy: "
        f"{mean_subject_acc:.4f} "
        f"(±{std_subject_acc:.4f})"
    )

    # -----------------------------------------------------------------
    # Classification report
    # -----------------------------------------------------------------

    print(
        "\n" + "=" * 70
    )

    print(
        "  CLASSIFICATION REPORT"
    )

    print(
        "=" * 70
    )

    report = classification_report(
        all_y_true,
        all_y_pred,
        labels=np.arange(
            NUM_CLASSES
        ),
        target_names=CLASS_NAMES,
        digits=4,
        zero_division=0
    )

    print(
        report
    )

    # -----------------------------------------------------------------
    # Confusion matrix
    # -----------------------------------------------------------------

    print(
        "\n" + "=" * 70
    )

    print(
        "  CONFUSION MATRIX"
    )

    print(
        "=" * 70
    )

    (
        cm,
        cm_pct
    ) = plot_confusion_matrix(
        all_y_true,
        all_y_pred,
        CLASS_NAMES
    )

    print(
        "\nConfusion Matrix (Counts):"
    )

    print(
        pd.DataFrame(
            cm,
            index=CLASS_NAMES,
            columns=CLASS_NAMES
        )
    )

    print(
        "\nConfusion Matrix (Row %):"
    )

    print(
        pd.DataFrame(
            np.round(
                cm_pct,
                2
            ),
            index=CLASS_NAMES,
            columns=CLASS_NAMES
        )
    )

    # -----------------------------------------------------------------
    # Final summary
    # -----------------------------------------------------------------

    print(
        "\n" + "=" * 70
    )

    print(
        "  PIPELINE COMPLETE"
    )

    print(
        "=" * 70
    )

    print(
        "\nImportant:"
    )

    print(
        "- Binary classification uses "
        "Baseline and Stress only."
    )

    print(
        "- Amusement windows are excluded."
    )

    print(
        "- The test subject was not used "
        "for checkpoint selection."
    )

    print(
        "- Scaling was fitted using "
        "training subjects only."
    )

    print(
        "- Validation subjects were used "
        "for early stopping."
    )

    print(
        "- The final reported test results "
        "are from held-out subjects."
    )

    print(
        "\nPossible next experiments:"
    )

    print(
        "1. WeightedRandomSampler "
        "for class imbalance."
    )

    print(
        "2. STEP_SEC=3 for more windows."
    )

    print(
        "3. Add chest-device respiration/ECG "
        "features if available."
    )

    print(
        "4. Compare against Random Forest/XGBoost "
        "using handcrafted features."
    )

    return {
        "fold_accuracies": fold_accuracies,

        "fold_balanced_accuracies":
            fold_balanced_accuracies,

        "fold_macro_f1":
            fold_macro_f1,

        "overall_accuracy":
            overall_acc,

        "overall_balanced_accuracy":
            overall_bal_acc,

        "overall_macro_f1":
            overall_macro_f1,

        "classification_report":
            report,

        "confusion_matrix":
            cm,

        "y_true":
            all_y_true,

        "y_pred":
            all_y_pred,
    }


# =============================================================================
# 25. RUN
# =============================================================================

if __name__ == "__main__":

    results = main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [INFO] WESAD ZIP found: /content/drive/MyDrive/WESAD.zip
# [INFO] Found 15 existing pickle file(s). Using existing extracted data.
# [INFO] Using device: cuda
#
# ======================================================================
#   SUBJECT-INDEPENDENT STRESS DETECTION FRAMEWORK (v3)
#   LOSO | Multi-Rate Multi-Modal CNN-BiGRU + Features
#   Binary Classification: Baseline vs Stress
#   Subjects: ['S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S13', 'S14', 'S15', 'S16', 'S17']
# ======================================================================
#
# ======================================================================
# WESAD DATASET VERIFICATION
# ======================================================================
# [OK]      S2: /content/WESAD/S2/S2.pkl
# [OK]      S3: /content/WESAD/S3/S3.pkl
# [OK]      S4: /content/WESAD/S4/S4.pkl
# [OK]      S5: /content/WESAD/S5/S5.pkl
# [OK]      S6: /content/WESAD/S6/S6.pkl
# [OK]      S7: /content/WESAD/S7/S7.pkl
# [OK]      S8: /content/WESAD/S8/S8.pkl
# [OK]      S9: /content/WESAD/S9/S9.pkl
# [OK]      S10: /content/WESAD/S10/S10.pkl
# [OK]      S11: /content/WESAD/S11/S11.pkl
# [OK]      S13: /content/WESAD/S13/S13.pkl
# [OK]      S14: /content/WESAD/S14/S14.pkl
# [OK]      S15: /content/WESAD/S15/S15.pkl
# [OK]      S16: /content/WESAD/S16/S16.pkl
# [OK]      S17: /content/WESAD/S17/S17.pkl
# ----------------------------------------------------------------------
# [INFO] Found 15/15 expected subjects.
# ======================================================================
#
# [STEP 1] Preprocessing usable subjects:
#   [SUBJECT S2] Loading raw data...
#   [FOUND] /content/WESAD/S2/S2.pkl
#   [SUBJECT S2] Extracting wrist signals...
#   [SUBJECT S2] BVP=389056 | EDA=24316 | TEMP=24316 | ACC=194528 | Labels=4255300
#   [SUBJECT S2] Building 60s windows with 5s step...
#   [SUBJECT S2] Applying baseline calibration...
#   [SUBJECT S2] Done: 352 windows | Class distribution: {np.int64(0): np.int64(229), np.int64(1): np.int64(123)}
#   [SUBJECT S2] HR shape: (352, 1920, 2) | LR shape: (352, 240, 3) | Features shape: (352, 14)
#
#   [SUBJECT S3] Loading raw data...
#   [FOUND] /content/WESAD/S3/S3.pkl
#   [SUBJECT S3] Extracting wrist signals...
#   [SUBJECT S3] BVP=415552 | EDA=25972 | TEMP=25972 | ACC=207776 | Labels=4545100
#   [SUBJECT S3] Building 60s windows with 5s step...
#   [SUBJECT S3] Applying baseline calibration...
#   [SUBJECT S3] Done: 356 windows | Class distribution: {np.int64(0): np.int64(228), np.int64(1): np.int64(128)}
#   [SUBJECT S3] HR shape: (356, 1920, 2) | LR shape: (356, 240, 3) | Features shape: (356, 14)
#
#   [SUBJECT S4] Loading raw data...
#   [FOUND] /content/WESAD/S4/S4.pkl
#   [SUBJECT S4] Extracting wrist signals...
#   [SUBJECT S4] BVP=411072 | EDA=25692 | TEMP=25692 | ACC=205536 | Labels=4496100
#   [SUBJECT S4] Building 60s windows with 5s step...
#   [SUBJECT S4] Applying baseline calibration...
#   [SUBJECT S4] Done: 358 windows | Class distribution: {np.int64(0): np.int64(231), np.int64(1): np.int64(127)}
#   [SUBJECT S4] HR shape: (358, 1920, 2) | LR shape: (358, 240, 3) | Features shape: (358, 14)
#
#   [SUBJECT S5] Loading raw data...
#   [FOUND] /content/WESAD/S5/S5.pkl
#   [SUBJECT S5] Extracting wrist signals...
#   [SUBJECT S5] BVP=400512 | EDA=25032 | TEMP=25032 | ACC=200256 | Labels=4380600
#   [SUBJECT S5] Building 60s windows with 5s step...
#   [SUBJECT S5] Applying baseline calibration...
#   [SUBJECT S5] Done: 369 windows | Class distribution: {np.int64(0): np.int64(240), np.int64(1): np.int64(129)}
#   [SUBJECT S5] HR shape: (369, 1920, 2) | LR shape: (369, 240, 3) | Features shape: (369, 14)
#
#   [SUBJECT S6] Loading raw data...
#   [FOUND] /content/WESAD/S6/S6.pkl
#   [SUBJECT S6] Extracting wrist signals...
#   [SUBJECT S6] BVP=452544 | EDA=28284 | TEMP=28284 | ACC=226272 | Labels=4949700
#   [SUBJECT S6] Building 60s windows with 5s step...
#   [SUBJECT S6] Applying baseline calibration...
#   [SUBJECT S6] Done: 366 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(130)}
#   [SUBJECT S6] HR shape: (366, 1920, 2) | LR shape: (366, 240, 3) | Features shape: (366, 14)
#
#   [SUBJECT S7] Loading raw data...
#   [FOUND] /content/WESAD/S7/S7.pkl
#   [SUBJECT S7] Extracting wrist signals...
#   [SUBJECT S7] BVP=335232 | EDA=20952 | TEMP=20952 | ACC=167616 | Labels=3666600
#   [SUBJECT S7] Building 60s windows with 5s step...
#   [SUBJECT S7] Applying baseline calibration...
#   [SUBJECT S7] Done: 365 windows | Class distribution: {np.int64(0): np.int64(237), np.int64(1): np.int64(128)}
#   [SUBJECT S7] HR shape: (365, 1920, 2) | LR shape: (365, 240, 3) | Features shape: (365, 14)
#
#   [SUBJECT S8] Loading raw data...
#   [FOUND] /content/WESAD/S8/S8.pkl
#   [SUBJECT S8] Extracting wrist signals...
#   [SUBJECT S8] BVP=349824 | EDA=21864 | TEMP=21864 | ACC=174912 | Labels=3826200
#   [SUBJECT S8] Building 60s windows with 5s step...
#   [SUBJECT S8] Applying baseline calibration...
#   [SUBJECT S8] Done: 368 windows | Class distribution: {np.int64(0): np.int64(234), np.int64(1): np.int64(134)}
#   [SUBJECT S8] HR shape: (368, 1920, 2) | LR shape: (368, 240, 3) | Features shape: (368, 14)
#
#   [SUBJECT S9] Loading raw data...
#   [FOUND] /content/WESAD/S9/S9.pkl
#   [SUBJECT S9] Extracting wrist signals...
#   [SUBJECT S9] BVP=334272 | EDA=20892 | TEMP=20892 | ACC=167136 | Labels=3656100
#   [SUBJECT S9] Building 60s windows with 5s step...
#   [SUBJECT S9] Applying baseline calibration...
#   [SUBJECT S9] Done: 365 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(129)}
#   [SUBJECT S9] HR shape: (365, 1920, 2) | LR shape: (365, 240, 3) | Features shape: (365, 14)
#
#   [SUBJECT S10] Loading raw data...
#   [FOUND] /content/WESAD/S10/S10.pkl
#   [SUBJECT S10] Extracting wrist signals...
#   [SUBJECT S10] BVP=351744 | EDA=21984 | TEMP=21984 | ACC=175872 | Labels=3847200
#   [SUBJECT S10] Building 60s windows with 5s step...
#   [SUBJECT S10] Applying baseline calibration...
#   [SUBJECT S10] Done: 381 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(145)}
#   [SUBJECT S10] HR shape: (381, 1920, 2) | LR shape: (381, 240, 3) | Features shape: (381, 14)
#
#   [SUBJECT S11] Loading raw data...
#   [FOUND] /content/WESAD/S11/S11.pkl
#   [SUBJECT S11] Extracting wrist signals...
#   [SUBJECT S11] BVP=334912 | EDA=20932 | TEMP=20932 | ACC=167456 | Labels=3663100
#   [SUBJECT S11] Building 60s windows with 5s step...
#   [SUBJECT S11] Applying baseline calibration...
#   [SUBJECT S11] Done: 372 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(136)}
#   [SUBJECT S11] HR shape: (372, 1920, 2) | LR shape: (372, 240, 3) | Features shape: (372, 14)
#
#   [SUBJECT S13] Loading raw data...
#   [FOUND] /content/WESAD/S13/S13.pkl
#   [SUBJECT S13] Extracting wrist signals...
#   [SUBJECT S13] BVP=354368 | EDA=22148 | TEMP=22148 | ACC=177184 | Labels=3875900
#   [SUBJECT S13] Building 60s windows with 5s step...
#   [SUBJECT S13] Applying baseline calibration...
#   [SUBJECT S13] Done: 368 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(132)}
#   [SUBJECT S13] HR shape: (368, 1920, 2) | LR shape: (368, 240, 3) | Features shape: (368, 14)
#
#   [SUBJECT S14] Loading raw data...
#   [FOUND] /content/WESAD/S14/S14.pkl
#   [SUBJECT S14] Extracting wrist signals...
#   [SUBJECT S14] BVP=355072 | EDA=22192 | TEMP=22192 | ACC=177536 | Labels=3883600
#   [SUBJECT S14] Building 60s windows with 5s step...
#   [SUBJECT S14] Applying baseline calibration...
#   [SUBJECT S14] Done: 371 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(135)}
#   [SUBJECT S14] HR shape: (371, 1920, 2) | LR shape: (371, 240, 3) | Features shape: (371, 14)
#
#   [SUBJECT S15] Loading raw data...
#   [FOUND] /content/WESAD/S15/S15.pkl
#   [SUBJECT S15] Extracting wrist signals...
#   [SUBJECT S15] BVP=336128 | EDA=21008 | TEMP=21008 | ACC=168064 | Labels=3676400
#   [SUBJECT S15] Building 60s windows with 5s step...
#   [SUBJECT S15] Applying baseline calibration...
#   [SUBJECT S15] Done: 373 windows | Class distribution: {np.int64(0): np.int64(235), np.int64(1): np.int64(138)}
#   [SUBJECT S15] HR shape: (373, 1920, 2) | LR shape: (373, 240, 3) | Features shape: (373, 14)
#
#   [SUBJECT S16] Loading raw data...
#   [FOUND] /content/WESAD/S16/S16.pkl
#   [SUBJECT S16] Extracting wrist signals...
#   [SUBJECT S16] BVP=360384 | EDA=22524 | TEMP=22524 | ACC=180192 | Labels=3941700
#   [SUBJECT S16] Building 60s windows with 5s step...
#   [SUBJECT S16] Applying baseline calibration...
#   [SUBJECT S16] Done: 371 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(135)}
#   [SUBJECT S16] HR shape: (371, 1920, 2) | LR shape: (371, 240, 3) | Features shape: (371, 14)
#
#   [SUBJECT S17] Loading raw data...
#   [FOUND] /content/WESAD/S17/S17.pkl
#   [SUBJECT S17] Extracting wrist signals...
#   [SUBJECT S17] BVP=378880 | EDA=23680 | TEMP=23680 | ACC=189440 | Labels=4144000
#   [SUBJECT S17] Building 60s windows with 5s step...
#   [SUBJECT S17] Applying baseline calibration...
#   [SUBJECT S17] Done: 381 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(145)}
#   [SUBJECT S17] HR shape: (381, 1920, 2) | LR shape: (381, 240, 3) | Features shape: (381, 14)
#
# [INFO] 15/15 subjects have usable data:
#        ['S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S13', 'S14', 'S15', 'S16', 'S17']
#
# [STEP 2] Running Leave-One-Subject-Out Cross-Validation...
#
# ======================================================================
# [FOLD] Test Subject: S2
# ======================================================================
#   Train: 4808 windows | Val (S3): 356 | Test (S2): 352
#   Train class distribution: {np.int64(0): np.int64(3065), np.int64(1): np.int64(1743)}
#   Class weights: {'Baseline': np.float32(0.7843), 'Stress': np.float32(1.3792)}
#   Epoch [1/40] | Train Loss: 0.1172 Acc: 0.9565 | Val Loss: 0.5689 Acc: 0.7809 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0168 Acc: 0.9948 | Val Loss: 0.2858 Acc: 0.8904 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.0137 Acc: 0.9962 | Val Loss: 1.3043 Acc: 0.6770 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.0105 Acc: 0.9965 | Val Loss: 1.6014 Acc: 0.6404 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.0043 Acc: 0.9988 | Val Loss: 1.9337 Acc: 0.6404 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0022 Acc: 0.9996 | Val Loss: 1.7936 Acc: 0.6517 | LR: 3.50e-04
#   Epoch [7/40] | Train Loss: 0.0011 Acc: 1.0000 | Val Loss: 2.0240 Acc: 0.6517 | LR: 3.50e-04
#   Epoch [8/40] | Train Loss: 0.0015 Acc: 0.9996 | Val Loss: 2.0421 Acc: 0.6404 | LR: 3.50e-04
#   Epoch [9/40] | Train Loss: 0.0010 Acc: 0.9998 | Val Loss: 1.5300 Acc: 0.6798 | LR: 3.50e-04
#   Epoch [10/40] | Train Loss: 0.0009 Acc: 0.9998 | Val Loss: 1.6857 Acc: 0.6798 | LR: 1.75e-04
#   Early stopping at epoch 10 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S2 | Best Val Acc: 0.8904 | TEST Acc: 0.9375 | Balanced Acc: 0.9520 | Macro F1: 0.9337
#
# ======================================================================
# [FOLD] Test Subject: S3
# ======================================================================
#   Train: 4808 windows | Val (S2): 352 | Test (S3): 356
#   Train class distribution: {np.int64(0): np.int64(3065), np.int64(1): np.int64(1743)}
#   Class weights: {'Baseline': np.float32(0.7843), 'Stress': np.float32(1.3792)}
#   Epoch [1/40] | Train Loss: 0.1249 Acc: 0.9571 | Val Loss: 0.1077 Acc: 0.9517 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0181 Acc: 0.9942 | Val Loss: 0.0040 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.0134 Acc: 0.9958 | Val Loss: 0.0045 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.0104 Acc: 0.9965 | Val Loss: 0.0187 Acc: 0.9972 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.0060 Acc: 0.9983 | Val Loss: 0.1769 Acc: 0.9460 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0079 Acc: 0.9973 | Val Loss: 0.0086 Acc: 0.9972 | LR: 3.50e-04
#   Epoch [7/40] | Train Loss: 0.0023 Acc: 0.9994 | Val Loss: 0.0081 Acc: 0.9972 | LR: 3.50e-04
#   Epoch [8/40] | Train Loss: 0.0032 Acc: 0.9981 | Val Loss: 0.0111 Acc: 0.9972 | LR: 3.50e-04
#   Epoch [9/40] | Train Loss: 0.0055 Acc: 0.9981 | Val Loss: 0.0029 Acc: 1.0000 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [10/40] | Train Loss: 0.0027 Acc: 0.9996 | Val Loss: 0.0082 Acc: 0.9972 | LR: 3.50e-04
#   Epoch [11/40] | Train Loss: 0.0025 Acc: 0.9992 | Val Loss: 0.0245 Acc: 0.9886 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0013 Acc: 0.9998 | Val Loss: 0.0055 Acc: 0.9972 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 0.0070 Acc: 0.9972 | LR: 1.75e-04
#   Epoch [14/40] | Train Loss: 0.0025 Acc: 0.9996 | Val Loss: 0.0169 Acc: 0.9943 | LR: 1.75e-04
#   Epoch [15/40] | Train Loss: 0.0008 Acc: 1.0000 | Val Loss: 0.0083 Acc: 0.9972 | LR: 1.75e-04
#   Epoch [16/40] | Train Loss: 0.0009 Acc: 0.9996 | Val Loss: 0.0034 Acc: 1.0000 | LR: 1.75e-04
#   Epoch [17/40] | Train Loss: 0.0015 Acc: 0.9992 | Val Loss: 0.0184 Acc: 0.9943 | LR: 8.75e-05
#   Early stopping at epoch 17 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S3 | Best Val Acc: 1.0000 | TEST Acc: 0.8006 | Balanced Acc: 0.7227 | Macro F1: 0.7407
#
# ======================================================================
# [FOLD] Test Subject: S4
# ======================================================================
#   Train: 4806 windows | Val (S2): 352 | Test (S4): 358
#   Train class distribution: {np.int64(0): np.int64(3062), np.int64(1): np.int64(1744)}
#   Class weights: {'Baseline': np.float32(0.7848), 'Stress': np.float32(1.3779)}
#   Epoch [1/40] | Train Loss: 0.1767 Acc: 0.9354 | Val Loss: 0.0625 Acc: 0.9716 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0284 Acc: 0.9906 | Val Loss: 0.0504 Acc: 0.9716 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.0178 Acc: 0.9948 | Val Loss: 0.0167 Acc: 0.9943 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.0101 Acc: 0.9967 | Val Loss: 0.0080 Acc: 0.9972 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.0076 Acc: 0.9975 | Val Loss: 0.0660 Acc: 0.9688 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0051 Acc: 0.9983 | Val Loss: 0.0222 Acc: 0.9915 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0072 Acc: 0.9977 | Val Loss: 0.0035 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0033 Acc: 0.9994 | Val Loss: 0.0119 Acc: 0.9943 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0021 Acc: 0.9994 | Val Loss: 0.0005 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [10/40] | Train Loss: 0.0025 Acc: 0.9992 | Val Loss: 0.0014 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [11/40] | Train Loss: 0.0028 Acc: 0.9994 | Val Loss: 0.0097 Acc: 0.9943 | LR: 7.00e-04
#   Epoch [12/40] | Train Loss: 0.0006 Acc: 0.9998 | Val Loss: 0.0072 Acc: 0.9943 | LR: 7.00e-04
#   Epoch [13/40] | Train Loss: 0.0010 Acc: 0.9998 | Val Loss: 0.0003 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [14/40] | Train Loss: 0.0044 Acc: 0.9983 | Val Loss: 0.0097 Acc: 0.9943 | LR: 7.00e-04
#   Epoch [15/40] | Train Loss: 0.0023 Acc: 0.9994 | Val Loss: 0.0009 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [16/40] | Train Loss: 0.0007 Acc: 0.9998 | Val Loss: 0.0126 Acc: 0.9943 | LR: 7.00e-04
#   Epoch [17/40] | Train Loss: 0.0002 Acc: 1.0000 | Val Loss: 0.0252 Acc: 0.9915 | LR: 3.50e-04
#   Epoch [18/40] | Train Loss: 0.0007 Acc: 0.9998 | Val Loss: 0.0090 Acc: 0.9943 | LR: 3.50e-04
#   Epoch [19/40] | Train Loss: 0.0008 Acc: 0.9998 | Val Loss: 0.0138 Acc: 0.9943 | LR: 3.50e-04
#   Epoch [20/40] | Train Loss: 0.0007 Acc: 0.9998 | Val Loss: 0.0055 Acc: 0.9943 | LR: 3.50e-04
#   Epoch [21/40] | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 0.0229 Acc: 0.9915 | LR: 1.75e-04
#   Early stopping at epoch 21 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S4 | Best Val Acc: 1.0000 | TEST Acc: 1.0000 | Balanced Acc: 1.0000 | Macro F1: 1.0000
#
# ======================================================================
# [FOLD] Test Subject: S5
# ======================================================================
#   Train: 4795 windows | Val (S2): 352 | Test (S5): 369
#   Train class distribution: {np.int64(0): np.int64(3053), np.int64(1): np.int64(1742)}
#   Class weights: {'Baseline': np.float32(0.7853), 'Stress': np.float32(1.3763)}
#   Epoch [1/40] | Train Loss: 0.1525 Acc: 0.9497 | Val Loss: 0.0026 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0267 Acc: 0.9928 | Val Loss: 0.0685 Acc: 0.9659 | LR: 7.00e-04
#   Epoch [3/40] | Train Loss: 0.0121 Acc: 0.9966 | Val Loss: 0.0116 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.0137 Acc: 0.9964 | Val Loss: 0.0230 Acc: 0.9830 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.0062 Acc: 0.9985 | Val Loss: 0.0036 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [6/40] | Train Loss: 0.0056 Acc: 0.9983 | Val Loss: 0.0018 Acc: 1.0000 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [7/40] | Train Loss: 0.0030 Acc: 0.9996 | Val Loss: 0.0067 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [8/40] | Train Loss: 0.0043 Acc: 0.9987 | Val Loss: 0.0022 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [9/40] | Train Loss: 0.0023 Acc: 0.9996 | Val Loss: 0.0012 Acc: 1.0000 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [10/40] | Train Loss: 0.0011 Acc: 0.9998 | Val Loss: 0.0013 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [11/40] | Train Loss: 0.0010 Acc: 0.9998 | Val Loss: 0.0023 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0020 Acc: 0.9994 | Val Loss: 0.0002 Acc: 1.0000 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [13/40] | Train Loss: 0.0017 Acc: 0.9996 | Val Loss: 0.0056 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0008 Acc: 1.0000 | Val Loss: 0.0443 Acc: 0.9773 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0010 Acc: 0.9998 | Val Loss: 0.0334 Acc: 0.9773 | LR: 3.50e-04
#   Epoch [16/40] | Train Loss: 0.0023 Acc: 0.9992 | Val Loss: 0.0098 Acc: 0.9972 | LR: 1.75e-04
#   Epoch [17/40] | Train Loss: 0.0012 Acc: 0.9998 | Val Loss: 0.0239 Acc: 0.9830 | LR: 1.75e-04
#   Epoch [18/40] | Train Loss: 0.0013 Acc: 0.9996 | Val Loss: 0.0024 Acc: 1.0000 | LR: 1.75e-04
#   Epoch [19/40] | Train Loss: 0.0008 Acc: 0.9996 | Val Loss: 0.0056 Acc: 1.0000 | LR: 1.75e-04
#   Epoch [20/40] | Train Loss: 0.0004 Acc: 1.0000 | Val Loss: 0.0052 Acc: 1.0000 | LR: 8.75e-05
#   Early stopping at epoch 20 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S5 | Best Val Acc: 1.0000 | TEST Acc: 1.0000 | Balanced Acc: 1.0000 | Macro F1: 1.0000
#
# ======================================================================
# [FOLD] Test Subject: S6
# ======================================================================
#   Train: 4798 windows | Val (S2): 352 | Test (S6): 366
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1741)}
#   Class weights: {'Baseline': np.float32(0.7848), 'Stress': np.float32(1.3779)}
#   Epoch [1/40] | Train Loss: 0.1539 Acc: 0.9474 | Val Loss: 0.0442 Acc: 0.9716 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0310 Acc: 0.9892 | Val Loss: 0.0307 Acc: 0.9801 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.0149 Acc: 0.9954 | Val Loss: 0.0280 Acc: 0.9830 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.0205 Acc: 0.9924 | Val Loss: 0.0024 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.0091 Acc: 0.9973 | Val Loss: 0.0165 Acc: 0.9858 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0055 Acc: 0.9985 | Val Loss: 0.0033 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0039 Acc: 0.9983 | Val Loss: 0.0621 Acc: 0.9744 | LR: 7.00e-04
#   Epoch [8/40] | Train Loss: 0.0038 Acc: 0.9985 | Val Loss: 0.0016 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [9/40] | Train Loss: 0.0026 Acc: 0.9992 | Val Loss: 0.2329 Acc: 0.9489 | LR: 7.00e-04
#   Epoch [10/40] | Train Loss: 0.0034 Acc: 0.9987 | Val Loss: 0.0005 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [11/40] | Train Loss: 0.0018 Acc: 0.9998 | Val Loss: 0.0010 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [12/40] | Train Loss: 0.0019 Acc: 0.9992 | Val Loss: 0.0001 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [13/40] | Train Loss: 0.0007 Acc: 0.9998 | Val Loss: 0.0002 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [14/40] | Train Loss: 0.0043 Acc: 0.9983 | Val Loss: 0.0168 Acc: 0.9858 | LR: 7.00e-04
#   Epoch [15/40] | Train Loss: 0.0019 Acc: 0.9992 | Val Loss: 0.0033 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [16/40] | Train Loss: 0.0017 Acc: 0.9996 | Val Loss: 0.0014 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [17/40] | Train Loss: 0.0015 Acc: 0.9998 | Val Loss: 0.0003 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [18/40] | Train Loss: 0.0014 Acc: 0.9996 | Val Loss: 0.0039 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [19/40] | Train Loss: 0.0010 Acc: 0.9998 | Val Loss: 0.0048 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [20/40] | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 0.0038 Acc: 1.0000 | LR: 1.75e-04
#   Early stopping at epoch 20 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S6 | Best Val Acc: 1.0000 | TEST Acc: 0.9973 | Balanced Acc: 0.9962 | Macro F1: 0.9970
#
# ======================================================================
# [FOLD] Test Subject: S7
# ======================================================================
#   Train: 4799 windows | Val (S2): 352 | Test (S7): 365
#   Train class distribution: {np.int64(0): np.int64(3056), np.int64(1): np.int64(1743)}
#   Class weights: {'Baseline': np.float32(0.7852), 'Stress': np.float32(1.3766)}
#   Epoch [1/40] | Train Loss: 0.1062 Acc: 0.9738 | Val Loss: 0.0083 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0197 Acc: 0.9924 | Val Loss: 0.0012 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.0102 Acc: 0.9968 | Val Loss: 0.0010 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.0058 Acc: 0.9981 | Val Loss: 0.0005 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.0049 Acc: 0.9983 | Val Loss: 0.0010 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0040 Acc: 0.9987 | Val Loss: 0.0013 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0039 Acc: 0.9989 | Val Loss: 0.0004 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0033 Acc: 0.9996 | Val Loss: 0.0008 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0026 Acc: 0.9987 | Val Loss: 0.0012 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [10/40] | Train Loss: 0.0014 Acc: 0.9996 | Val Loss: 0.0003 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [11/40] | Train Loss: 0.0030 Acc: 0.9983 | Val Loss: 0.0004 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [12/40] | Train Loss: 0.0065 Acc: 0.9983 | Val Loss: 0.0003 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [13/40] | Train Loss: 0.0020 Acc: 0.9992 | Val Loss: 0.0000 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [14/40] | Train Loss: 0.0015 Acc: 0.9996 | Val Loss: 0.0002 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [15/40] | Train Loss: 0.0020 Acc: 0.9994 | Val Loss: 0.0001 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [16/40] | Train Loss: 0.0007 Acc: 0.9998 | Val Loss: 0.0002 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [17/40] | Train Loss: 0.0007 Acc: 0.9998 | Val Loss: 0.0002 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [18/40] | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 0.0001 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [19/40] | Train Loss: 0.0004 Acc: 1.0000 | Val Loss: 0.0002 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [20/40] | Train Loss: 0.0004 Acc: 1.0000 | Val Loss: 0.0001 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [21/40] | Train Loss: 0.0002 Acc: 1.0000 | Val Loss: 0.0002 Acc: 1.0000 | LR: 1.75e-04
#   Early stopping at epoch 21 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S7 | Best Val Acc: 1.0000 | TEST Acc: 0.7205 | Balanced Acc: 0.6016 | Macro F1: 0.5803
#
# ======================================================================
# [FOLD] Test Subject: S8
# ======================================================================
#   Train: 4796 windows | Val (S2): 352 | Test (S8): 368
#   Train class distribution: {np.int64(0): np.int64(3059), np.int64(1): np.int64(1737)}
#   Class weights: {'Baseline': np.float32(0.7839), 'Stress': np.float32(1.3805)}
#   Epoch [1/40] | Train Loss: 0.1718 Acc: 0.9434 | Val Loss: 0.0170 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0333 Acc: 0.9886 | Val Loss: 0.0094 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.0225 Acc: 0.9918 | Val Loss: 0.0014 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.0163 Acc: 0.9939 | Val Loss: 0.0274 Acc: 0.9830 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.0073 Acc: 0.9975 | Val Loss: 0.1090 Acc: 0.9489 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0036 Acc: 0.9989 | Val Loss: 0.0051 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0062 Acc: 0.9979 | Val Loss: 0.0005 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0104 Acc: 0.9979 | Val Loss: 0.0019 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0022 Acc: 0.9996 | Val Loss: 0.0044 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [10/40] | Train Loss: 0.0023 Acc: 0.9994 | Val Loss: 0.0020 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [11/40] | Train Loss: 0.0022 Acc: 0.9992 | Val Loss: 0.0052 Acc: 0.9972 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0006 Acc: 1.0000 | Val Loss: 0.0015 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0016 Acc: 0.9998 | Val Loss: 0.0014 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0011 Acc: 1.0000 | Val Loss: 0.0022 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0008 Acc: 1.0000 | Val Loss: 0.0005 Acc: 1.0000 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [16/40] | Train Loss: 0.0006 Acc: 0.9998 | Val Loss: 0.0003 Acc: 1.0000 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [17/40] | Train Loss: 0.0031 Acc: 0.9987 | Val Loss: 0.0001 Acc: 1.0000 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [18/40] | Train Loss: 0.0037 Acc: 0.9994 | Val Loss: 0.0035 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [19/40] | Train Loss: 0.0009 Acc: 0.9998 | Val Loss: 0.0025 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [20/40] | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 0.0010 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [21/40] | Train Loss: 0.0025 Acc: 0.9992 | Val Loss: 0.0011 Acc: 1.0000 | LR: 1.75e-04
#   Epoch [22/40] | Train Loss: 0.0007 Acc: 1.0000 | Val Loss: 0.0020 Acc: 1.0000 | LR: 1.75e-04
#   Epoch [23/40] | Train Loss: 0.0004 Acc: 1.0000 | Val Loss: 0.0012 Acc: 1.0000 | LR: 1.75e-04
#   Epoch [24/40] | Train Loss: 0.0021 Acc: 0.9994 | Val Loss: 0.0006 Acc: 1.0000 | LR: 1.75e-04
#   Epoch [25/40] | Train Loss: 0.0007 Acc: 1.0000 | Val Loss: 0.0011 Acc: 1.0000 | LR: 8.75e-05
#   Early stopping at epoch 25 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S8 | Best Val Acc: 1.0000 | TEST Acc: 1.0000 | Balanced Acc: 1.0000 | Macro F1: 1.0000
#
# ======================================================================
# [FOLD] Test Subject: S9
# ======================================================================
#   Train: 4799 windows | Val (S2): 352 | Test (S9): 365
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1742)}
#   Class weights: {'Baseline': np.float32(0.7849), 'Stress': np.float32(1.3774)}
#   Epoch [1/40] | Train Loss: 0.1369 Acc: 0.9538 | Val Loss: 0.0451 Acc: 0.9801 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0231 Acc: 0.9913 | Val Loss: 0.0082 Acc: 0.9972 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.0112 Acc: 0.9962 | Val Loss: 0.0382 Acc: 0.9773 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.0122 Acc: 0.9960 | Val Loss: 0.0082 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.0029 Acc: 0.9992 | Val Loss: 0.0055 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [6/40] | Train Loss: 0.0016 Acc: 0.9998 | Val Loss: 0.1408 Acc: 0.9460 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0047 Acc: 0.9981 | Val Loss: 0.0176 Acc: 0.9886 | LR: 7.00e-04
#   Epoch [8/40] | Train Loss: 0.0044 Acc: 0.9983 | Val Loss: 0.0010 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [9/40] | Train Loss: 0.0016 Acc: 0.9998 | Val Loss: 0.0013 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [10/40] | Train Loss: 0.0006 Acc: 0.9998 | Val Loss: 0.0000 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [11/40] | Train Loss: 0.0007 Acc: 0.9998 | Val Loss: 0.0004 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [12/40] | Train Loss: 0.0014 Acc: 0.9996 | Val Loss: 0.0000 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [13/40] | Train Loss: 0.0015 Acc: 0.9998 | Val Loss: 0.0003 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [14/40] | Train Loss: 0.0003 Acc: 1.0000 | Val Loss: 0.0018 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0004 Acc: 1.0000 | Val Loss: 0.0006 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [16/40] | Train Loss: 0.0002 Acc: 1.0000 | Val Loss: 0.0014 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [17/40] | Train Loss: 0.0002 Acc: 1.0000 | Val Loss: 0.0005 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [18/40] | Train Loss: 0.0003 Acc: 0.9998 | Val Loss: 0.0003 Acc: 1.0000 | LR: 1.75e-04
#   Early stopping at epoch 18 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S9 | Best Val Acc: 1.0000 | TEST Acc: 0.9068 | Balanced Acc: 0.8682 | Macro F1: 0.8905
#
# ======================================================================
# [FOLD] Test Subject: S10
# ======================================================================
#   Train: 4783 windows | Val (S2): 352 | Test (S10): 381
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1726)}
#   Class weights: {'Baseline': np.float32(0.7823), 'Stress': np.float32(1.3856)}
#   Epoch [1/40] | Train Loss: 0.1462 Acc: 0.9514 | Val Loss: 0.0343 Acc: 0.9801 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0271 Acc: 0.9894 | Val Loss: 0.0026 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.0159 Acc: 0.9945 | Val Loss: 0.0013 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.0114 Acc: 0.9964 | Val Loss: 0.0011 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.0034 Acc: 0.9996 | Val Loss: 0.0017 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0058 Acc: 0.9979 | Val Loss: 0.0168 Acc: 0.9915 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0109 Acc: 0.9964 | Val Loss: 0.0002 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0054 Acc: 0.9979 | Val Loss: 0.0006 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0014 Acc: 0.9996 | Val Loss: 0.0005 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [10/40] | Train Loss: 0.0018 Acc: 0.9996 | Val Loss: 0.0009 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [11/40] | Train Loss: 0.0028 Acc: 0.9992 | Val Loss: 0.0003 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0020 Acc: 0.9998 | Val Loss: 0.0048 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0018 Acc: 0.9998 | Val Loss: 0.0106 Acc: 0.9915 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0008 Acc: 1.0000 | Val Loss: 0.0011 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0013 Acc: 0.9996 | Val Loss: 0.0004 Acc: 1.0000 | LR: 1.75e-04
#   Early stopping at epoch 15 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S10 | Best Val Acc: 1.0000 | TEST Acc: 0.9974 | Balanced Acc: 0.9966 | Macro F1: 0.9972
#
# ======================================================================
# [FOLD] Test Subject: S11
# ======================================================================
#   Train: 4792 windows | Val (S2): 352 | Test (S11): 372
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1735)}
#   Class weights: {'Baseline': np.float32(0.7838), 'Stress': np.float32(1.381)}
#   Epoch [1/40] | Train Loss: 0.1551 Acc: 0.9411 | Val Loss: 0.0118 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0274 Acc: 0.9911 | Val Loss: 0.0124 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [3/40] | Train Loss: 0.0193 Acc: 0.9932 | Val Loss: 0.0115 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.0067 Acc: 0.9973 | Val Loss: 0.0038 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.0041 Acc: 0.9985 | Val Loss: 0.0009 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [6/40] | Train Loss: 0.0132 Acc: 0.9954 | Val Loss: 0.0013 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0045 Acc: 0.9989 | Val Loss: 0.0171 Acc: 0.9943 | LR: 7.00e-04
#   Epoch [8/40] | Train Loss: 0.0023 Acc: 0.9994 | Val Loss: 0.0003 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [9/40] | Train Loss: 0.0036 Acc: 0.9987 | Val Loss: 0.0012 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [10/40] | Train Loss: 0.0043 Acc: 0.9987 | Val Loss: 0.0002 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [11/40] | Train Loss: 0.0030 Acc: 0.9989 | Val Loss: 0.0003 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [12/40] | Train Loss: 0.0007 Acc: 1.0000 | Val Loss: 0.0002 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [13/40] | Train Loss: 0.0081 Acc: 0.9975 | Val Loss: 0.0073 Acc: 0.9943 | LR: 7.00e-04
#   Epoch [14/40] | Train Loss: 0.0066 Acc: 0.9977 | Val Loss: 0.0007 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0040 Acc: 0.9987 | Val Loss: 0.0047 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [16/40] | Train Loss: 0.0009 Acc: 1.0000 | Val Loss: 0.0007 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [17/40] | Train Loss: 0.0007 Acc: 1.0000 | Val Loss: 0.0017 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [18/40] | Train Loss: 0.0011 Acc: 0.9996 | Val Loss: 0.0335 Acc: 0.9801 | LR: 1.75e-04
#   Early stopping at epoch 18 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S11 | Best Val Acc: 1.0000 | TEST Acc: 1.0000 | Balanced Acc: 1.0000 | Macro F1: 1.0000
#
# ======================================================================
# [FOLD] Test Subject: S13
# ======================================================================
#   Train: 4796 windows | Val (S2): 352 | Test (S13): 368
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1739)}
#   Class weights: {'Baseline': np.float32(0.7844), 'Stress': np.float32(1.379)}
#   Epoch [1/40] | Train Loss: 0.1540 Acc: 0.9434 | Val Loss: 0.0285 Acc: 0.9943 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0273 Acc: 0.9907 | Val Loss: 0.1812 Acc: 0.9460 | LR: 7.00e-04
#   Epoch [3/40] | Train Loss: 0.0140 Acc: 0.9951 | Val Loss: 0.0028 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.0091 Acc: 0.9975 | Val Loss: 0.0124 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.0062 Acc: 0.9977 | Val Loss: 0.0147 Acc: 0.9915 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0085 Acc: 0.9970 | Val Loss: 0.0315 Acc: 0.9773 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0037 Acc: 0.9992 | Val Loss: 0.0038 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [8/40] | Train Loss: 0.0025 Acc: 0.9994 | Val Loss: 0.0088 Acc: 0.9972 | LR: 3.50e-04
#   Epoch [9/40] | Train Loss: 0.0031 Acc: 0.9987 | Val Loss: 0.0103 Acc: 0.9972 | LR: 3.50e-04
#   Epoch [10/40] | Train Loss: 0.0009 Acc: 1.0000 | Val Loss: 0.0034 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [11/40] | Train Loss: 0.0007 Acc: 1.0000 | Val Loss: 0.0015 Acc: 1.0000 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [12/40] | Train Loss: 0.0009 Acc: 1.0000 | Val Loss: 0.0245 Acc: 0.9858 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0023 Acc: 0.9994 | Val Loss: 0.0080 Acc: 0.9943 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 0.0011 Acc: 1.0000 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [15/40] | Train Loss: 0.0008 Acc: 0.9998 | Val Loss: 0.0107 Acc: 0.9943 | LR: 3.50e-04
#   Epoch [16/40] | Train Loss: 0.0003 Acc: 1.0000 | Val Loss: 0.0019 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [17/40] | Train Loss: 0.0004 Acc: 1.0000 | Val Loss: 0.0307 Acc: 0.9801 | LR: 3.50e-04
#   Epoch [18/40] | Train Loss: 0.0009 Acc: 0.9998 | Val Loss: 0.0004 Acc: 1.0000 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [19/40] | Train Loss: 0.0006 Acc: 1.0000 | Val Loss: 0.0007 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [20/40] | Train Loss: 0.0004 Acc: 1.0000 | Val Loss: 0.1456 Acc: 0.9517 | LR: 3.50e-04
#   Epoch [21/40] | Train Loss: 0.0012 Acc: 0.9998 | Val Loss: 0.0023 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [22/40] | Train Loss: 0.0049 Acc: 0.9983 | Val Loss: 0.0033 Acc: 1.0000 | LR: 1.75e-04
#   Epoch [23/40] | Train Loss: 0.0006 Acc: 1.0000 | Val Loss: 0.0024 Acc: 1.0000 | LR: 1.75e-04
#   Epoch [24/40] | Train Loss: 0.0006 Acc: 1.0000 | Val Loss: 0.0028 Acc: 1.0000 | LR: 1.75e-04
#   Epoch [25/40] | Train Loss: 0.0010 Acc: 0.9998 | Val Loss: 0.0029 Acc: 1.0000 | LR: 1.75e-04
#   Epoch [26/40] | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 0.0055 Acc: 1.0000 | LR: 8.75e-05
#   Early stopping at epoch 26 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S13 | Best Val Acc: 1.0000 | TEST Acc: 1.0000 | Balanced Acc: 1.0000 | Macro F1: 1.0000
#
# ======================================================================
# [FOLD] Test Subject: S14
# ======================================================================
#   Train: 4793 windows | Val (S2): 352 | Test (S14): 371
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1736)}
#   Class weights: {'Baseline': np.float32(0.7839), 'Stress': np.float32(1.3805)}
#   Epoch [1/40] | Train Loss: 0.1264 Acc: 0.9611 | Val Loss: 0.0101 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0274 Acc: 0.9907 | Val Loss: 0.0199 Acc: 0.9943 | LR: 7.00e-04
#   Epoch [3/40] | Train Loss: 0.0172 Acc: 0.9947 | Val Loss: 0.0023 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.0122 Acc: 0.9979 | Val Loss: 0.0305 Acc: 0.9744 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.0061 Acc: 0.9977 | Val Loss: 0.0059 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0049 Acc: 0.9983 | Val Loss: 0.0054 Acc: 0.9972 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0022 Acc: 0.9992 | Val Loss: 0.0021 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0042 Acc: 0.9985 | Val Loss: 0.0025 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0020 Acc: 0.9992 | Val Loss: 0.0004 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [10/40] | Train Loss: 0.0021 Acc: 0.9996 | Val Loss: 0.0241 Acc: 0.9830 | LR: 7.00e-04
#   Epoch [11/40] | Train Loss: 0.0012 Acc: 0.9998 | Val Loss: 0.0021 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [12/40] | Train Loss: 0.0004 Acc: 1.0000 | Val Loss: 0.0109 Acc: 0.9915 | LR: 7.00e-04
#   Epoch [13/40] | Train Loss: 0.0006 Acc: 0.9998 | Val Loss: 0.0061 Acc: 0.9972 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0007 Acc: 0.9998 | Val Loss: 0.0020 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 0.0030 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [16/40] | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 0.0006 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [17/40] | Train Loss: 0.0007 Acc: 0.9998 | Val Loss: 0.0021 Acc: 1.0000 | LR: 1.75e-04
#   Early stopping at epoch 17 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S14 | Best Val Acc: 1.0000 | TEST Acc: 0.6361 | Balanced Acc: 0.5000 | Macro F1: 0.3888
#
# ======================================================================
# [FOLD] Test Subject: S15
# ======================================================================
#   Train: 4791 windows | Val (S2): 352 | Test (S15): 373
#   Train class distribution: {np.int64(0): np.int64(3058), np.int64(1): np.int64(1733)}
#   Class weights: {'Baseline': np.float32(0.7834), 'Stress': np.float32(1.3823)}
#   Epoch [1/40] | Train Loss: 0.1513 Acc: 0.9483 | Val Loss: 0.0078 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0272 Acc: 0.9901 | Val Loss: 0.0083 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [3/40] | Train Loss: 0.0128 Acc: 0.9958 | Val Loss: 0.0009 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.0149 Acc: 0.9947 | Val Loss: 0.0118 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.0072 Acc: 0.9979 | Val Loss: 0.0026 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0055 Acc: 0.9985 | Val Loss: 0.0029 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0028 Acc: 0.9992 | Val Loss: 0.0002 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0070 Acc: 0.9979 | Val Loss: 0.0019 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0022 Acc: 0.9992 | Val Loss: 0.0005 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [10/40] | Train Loss: 0.0021 Acc: 0.9994 | Val Loss: 0.0128 Acc: 0.9886 | LR: 7.00e-04
#   Epoch [11/40] | Train Loss: 0.0037 Acc: 0.9983 | Val Loss: 0.0395 Acc: 0.9801 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0008 Acc: 1.0000 | Val Loss: 0.0012 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0014 Acc: 0.9996 | Val Loss: 0.0008 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0013 Acc: 0.9996 | Val Loss: 0.0003 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0018 Acc: 0.9996 | Val Loss: 0.0015 Acc: 1.0000 | LR: 1.75e-04
#   Early stopping at epoch 15 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S15 | Best Val Acc: 1.0000 | TEST Acc: 1.0000 | Balanced Acc: 1.0000 | Macro F1: 1.0000
#
# ======================================================================
# [FOLD] Test Subject: S16
# ======================================================================
#   Train: 4793 windows | Val (S2): 352 | Test (S16): 371
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1736)}
#   Class weights: {'Baseline': np.float32(0.7839), 'Stress': np.float32(1.3805)}
#   Epoch [1/40] | Train Loss: 0.1303 Acc: 0.9552 | Val Loss: 0.0162 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0254 Acc: 0.9916 | Val Loss: 0.0561 Acc: 0.9631 | LR: 7.00e-04
#   Epoch [3/40] | Train Loss: 0.0122 Acc: 0.9960 | Val Loss: 0.0021 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.0114 Acc: 0.9966 | Val Loss: 0.0002 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.0057 Acc: 0.9983 | Val Loss: 0.0060 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0045 Acc: 0.9989 | Val Loss: 0.0002 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0032 Acc: 0.9989 | Val Loss: 0.0026 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [8/40] | Train Loss: 0.0050 Acc: 0.9981 | Val Loss: 0.0000 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [9/40] | Train Loss: 0.0052 Acc: 0.9983 | Val Loss: 0.0013 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [10/40] | Train Loss: 0.0025 Acc: 0.9989 | Val Loss: 0.0006 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [11/40] | Train Loss: 0.0011 Acc: 0.9996 | Val Loss: 0.0010 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [12/40] | Train Loss: 0.0008 Acc: 0.9998 | Val Loss: 0.0059 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0012 Acc: 0.9996 | Val Loss: 0.0010 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0003 Acc: 1.0000 | Val Loss: 0.0012 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0008 Acc: 0.9998 | Val Loss: 0.0001 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [16/40] | Train Loss: 0.0016 Acc: 0.9996 | Val Loss: 0.0011 Acc: 1.0000 | LR: 1.75e-04
#   Early stopping at epoch 16 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S16 | Best Val Acc: 1.0000 | TEST Acc: 1.0000 | Balanced Acc: 1.0000 | Macro F1: 1.0000
#
# ======================================================================
# [FOLD] Test Subject: S17
# ======================================================================
#   Train: 4783 windows | Val (S2): 352 | Test (S17): 381
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1726)}
#   Class weights: {'Baseline': np.float32(0.7823), 'Stress': np.float32(1.3856)}
#   Epoch [1/40] | Train Loss: 0.1379 Acc: 0.9481 | Val Loss: 0.0106 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.0306 Acc: 0.9882 | Val Loss: 0.0106 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.0097 Acc: 0.9973 | Val Loss: 0.0078 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.0156 Acc: 0.9960 | Val Loss: 0.2124 Acc: 0.9460 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.0156 Acc: 0.9949 | Val Loss: 0.0054 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [6/40] | Train Loss: 0.0056 Acc: 0.9981 | Val Loss: 0.0276 Acc: 0.9858 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0044 Acc: 0.9981 | Val Loss: 0.0062 Acc: 0.9972 | LR: 7.00e-04
#   Epoch [8/40] | Train Loss: 0.0039 Acc: 0.9983 | Val Loss: 0.0039 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [9/40] | Train Loss: 0.0035 Acc: 0.9985 | Val Loss: 0.0009 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [10/40] | Train Loss: 0.0018 Acc: 0.9996 | Val Loss: 0.0060 Acc: 0.9972 | LR: 7.00e-04
#   Epoch [11/40] | Train Loss: 0.0010 Acc: 0.9998 | Val Loss: 0.0057 Acc: 0.9972 | LR: 7.00e-04
#   Epoch [12/40] | Train Loss: 0.0019 Acc: 0.9994 | Val Loss: 0.0009 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [13/40] | Train Loss: 0.0012 Acc: 0.9996 | Val Loss: 0.0026 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [14/40] | Train Loss: 0.0009 Acc: 0.9998 | Val Loss: 0.0246 Acc: 0.9915 | LR: 7.00e-04
#   Epoch [15/40] | Train Loss: 0.0012 Acc: 0.9996 | Val Loss: 0.0003 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [16/40] | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 0.0032 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [17/40] | Train Loss: 0.0005 Acc: 1.0000 | Val Loss: 0.0021 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [18/40] | Train Loss: 0.0006 Acc: 0.9998 | Val Loss: 0.0000 Acc: 1.0000 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [19/40] | Train Loss: 0.0006 Acc: 0.9998 | Val Loss: 0.0020 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [20/40] | Train Loss: 0.0022 Acc: 0.9989 | Val Loss: 0.0025 Acc: 1.0000 | LR: 7.00e-04
#   Epoch [21/40] | Train Loss: 0.0029 Acc: 0.9987 | Val Loss: 0.0230 Acc: 0.9915 | LR: 7.00e-04
#   Epoch [22/40] | Train Loss: 0.0008 Acc: 1.0000 | Val Loss: 0.0005 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [23/40] | Train Loss: 0.0004 Acc: 1.0000 | Val Loss: 0.0107 Acc: 0.9972 | LR: 3.50e-04
#   Epoch [24/40] | Train Loss: 0.0003 Acc: 1.0000 | Val Loss: 0.0015 Acc: 1.0000 | LR: 3.50e-04
#   Epoch [25/40] | Train Loss: 0.0002 Acc: 1.0000 | Val Loss: 0.0026 Acc: 0.9972 | LR: 3.50e-04
#   Epoch [26/40] | Train Loss: 0.0003 Acc: 1.0000 | Val Loss: 0.0037 Acc: 0.9972 | LR: 1.75e-04
#   Early stopping at epoch 26 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S17 | Best Val Acc: 1.0000 | TEST Acc: 1.0000 | Balanced Acc: 1.0000 | Macro F1: 1.0000
#
# ======================================================================
#   LOSO CROSS-VALIDATION - FINAL RESULTS
# ======================================================================
#
# Per-Subject Holdout Results:
#   S2: Accuracy=0.9375 (93.75%) | Balanced Acc=0.9520 | Macro F1=0.9337
#   S3: Accuracy=0.8006 (80.06%) | Balanced Acc=0.7227 | Macro F1=0.7407
#   S4: Accuracy=1.0000 (100.00%) | Balanced Acc=1.0000 | Macro F1=1.0000
#   S5: Accuracy=1.0000 (100.00%) | Balanced Acc=1.0000 | Macro F1=1.0000
#   S6: Accuracy=0.9973 (99.73%) | Balanced Acc=0.9962 | Macro F1=0.9970
#   S7: Accuracy=0.7205 (72.05%) | Balanced Acc=0.6016 | Macro F1=0.5803
#   S8: Accuracy=1.0000 (100.00%) | Balanced Acc=1.0000 | Macro F1=1.0000
#   S9: Accuracy=0.9068 (90.68%) | Balanced Acc=0.8682 | Macro F1=0.8905
#   S10: Accuracy=0.9974 (99.74%) | Balanced Acc=0.9966 | Macro F1=0.9972
#   S11: Accuracy=1.0000 (100.00%) | Balanced Acc=1.0000 | Macro F1=1.0000
#   S13: Accuracy=1.0000 (100.00%) | Balanced Acc=1.0000 | Macro F1=1.0000
#   S14: Accuracy=0.6361 (63.61%) | Balanced Acc=0.5000 | Macro F1=0.3888
#   S15: Accuracy=1.0000 (100.00%) | Balanced Acc=1.0000 | Macro F1=1.0000
#   S16: Accuracy=1.0000 (100.00%) | Balanced Acc=1.0000 | Macro F1=1.0000
#   S17: Accuracy=1.0000 (100.00%) | Balanced Acc=1.0000 | Macro F1=1.0000
#
# Overall LOSO Accuracy: 0.9336 (93.36%)
# Overall Balanced Accuracy: 0.9106 (91.06%)
# Overall Macro F1: 0.9252
# Mean Per-Subject Accuracy: 0.9331 (±0.1142)
#
# ======================================================================
#   CLASSIFICATION REPORT
# ======================================================================
#               precision    recall  f1-score   support
#
#     Baseline     0.9105    0.9938    0.9503      3522
#       Stress     0.9868    0.8275    0.9002      1994
#
#     accuracy                         0.9336      5516
#    macro avg     0.9487    0.9106    0.9252      5516
# weighted avg     0.9381    0.9336    0.9322      5516
#
#
# ======================================================================
#   CONFUSION MATRIX
# ======================================================================
# Confusion Matrix (Counts):
#           Baseline  Stress
# Baseline      3500      22
# Stress         344    1650
#
# Confusion Matrix (Row %):
#           Baseline  Stress
# Baseline     99.38    0.62
# Stress       17.25   82.75
#
# ======================================================================
#   PIPELINE COMPLETE
# ======================================================================
#
# Important:
# - Binary classification uses Baseline and Stress only.
# - Amusement windows are excluded.
# - The test subject was not used for checkpoint selection.
# - Scaling was fitted using training subjects only.
# - Validation subjects were used for early stopping.
# - The final reported test results are from held-out subjects.
#
# Possible next experiments:
# 1. WeightedRandomSampler for class imbalance.
# 2. STEP_SEC=3 for more windows.
# 3. Add chest-device respiration/ECG features if available.
# 4. Compare against Random Forest/XGBoost using handcrafted features.
