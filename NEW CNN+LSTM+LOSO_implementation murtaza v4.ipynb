# %% [markdown]
# <a href="https://colab.research.google.com/github/AsimaZaheer/Stress-Detection/blob/main/NEW%20CNN%2BLSTM%2BLOSO_implementation%20murtaza%20v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python3
"""
WESAD SUBJECT-INDEPENDENT STRESS DETECTION FRAMEWORK (v3)

LOSO Cross-Validation
Multi-Rate Multi-Modal CNN-BiGRU + Handcrafted Features
Google Colab + Google Drive
Robust WESAD ZIP/FOLDER detection

IMPORTANT:
- Put WESAD.zip in: /content/drive/MyDrive/WESAD.zip
- Run this entire file/cell.
- The loader searches recursively, so extra ZIP folders are okay.
- S1 and S12 are excluded.
"""

# =============================================================================
# 1. GOOGLE DRIVE + ROBUST DATASET SETUP
# =============================================================================

import os
import sys
import copy
import pickle
import zipfile
import shutil
import warnings

try:
    from google.colab import drive
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    drive.mount("/content/drive")

    WESAD_ZIP = "/content/drive/MyDrive/WESAD/WESAD.zip"
    WESAD_DIR = "/content/WESAD"

    if not os.path.isfile(WESAD_ZIP):
        raise FileNotFoundError(
            "\nWESAD.zip was not found at:\n"
            f"{WESAD_ZIP}\n\n"
            "Upload WESAD.zip to Google Drive > MyDrive and run again."
        )

    print(f"[INFO] WESAD ZIP found: {WESAD_ZIP}")

    # Search for existing subject pickles anywhere under /content.
    existing_subject_files = {}
    for root, dirs, files in os.walk("/content"):
        for filename in files:
            if filename.lower().endswith(".pkl"):
                stem = os.path.splitext(filename)[0].upper()
                if stem.startswith("S") and stem[1:].isdigit():
                    existing_subject_files[stem] = os.path.join(root, filename)

    if len(existing_subject_files) == 0:
        print("[INFO] No WESAD subject pickle files found.")
        print("[INFO] Extracting WESAD.zip...")

        # Remove only the expected extraction directory if it exists.
        if os.path.exists(WESAD_DIR):
            print(f"[INFO] Removing incomplete directory: {WESAD_DIR}")
            shutil.rmtree(WESAD_DIR)

        with zipfile.ZipFile(WESAD_ZIP, "r") as z:
            z.extractall("/content")

        print("[INFO] Extraction completed.")

    else:
        print(
            f"[INFO] Found {len(existing_subject_files)} existing pickle file(s). "
            "Using existing extracted data."
        )

else:
    WESAD_DIR = "./WESAD"
    WESAD_ZIP = None
    print(f"[WARNING] Not running in Colab. Assuming dataset is at {WESAD_DIR}")


# =============================================================================
# 2. LIBRARIES
# =============================================================================

import numpy as np
import pandas as pd

from scipy import stats
from scipy.signal import resample, find_peaks, butter, filtfilt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
)

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore")


# =============================================================================
# 3. CONFIGURATION
# =============================================================================

ALL_SUBJECTS = [
    f"S{i}" for i in range(2, 18) if i != 12
]

BVP_SR = 64
ACC_SR = 32
EDA_SR = 4
TEMP_SR = 4
LABEL_SR = 700

HR_SR = 32
LR_SR = 4

WINDOW_SEC = 60
STEP_SEC = 5

HR_LEN = WINDOW_SEC * HR_SR
LR_LEN = WINDOW_SEC * LR_SR

FEAT_DIM = 14

VALID_LABELS_ORIG = [1, 2, 3]
LABEL_MAP = {
    1: 0,  # Baseline
    2: 1,  # Stress
    3: 2,  # Amusement
}

CLASS_NAMES = [
    "Baseline",
    "Stress",
    "Amusement",
]

NUM_CLASSES = 3

BATCH_SIZE = 64
EPOCHS = 40
EARLY_STOP_PATIENCE = 8

LEARNING_RATE = 7e-4
WEIGHT_DECAY = 1e-4
DROPOUT_RATE = 0.35
GRAD_CLIP_NORM = 5.0

SEED = 42
NUM_WORKERS = 0
# Always drop an incomplete final training batch.
TRAIN_DROP_LAST = True

DEVICE = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print(f"[INFO] Using device: {DEVICE}")

np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)


# =============================================================================
# 4. ROBUST WESAD FILE SEARCH
# =============================================================================

def find_subject_pickle(subject_id, search_roots=None):
    """
    Find <subject_id>.pkl recursively.

    This handles structures such as:
        /content/WESAD/S2/S2.pkl
        /content/WESAD/S2.pkl
        /content/WESAD/WESAD/S2/S2.pkl
        /content/S2/S2.pkl
    """

    subject_id = subject_id.upper()

    if search_roots is None:
        search_roots = []

        if os.path.exists("/content"):
            search_roots.append("/content")

        if os.path.exists(WESAD_DIR):
            search_roots.append(WESAD_DIR)

        if not IN_COLAB and os.path.exists("."):
            search_roots.append(".")

    # Remove duplicate roots while preserving order.
    unique_roots = []
    for root in search_roots:
        root = os.path.abspath(root)
        if root not in unique_roots and os.path.exists(root):
            unique_roots.append(root)

    target = f"{subject_id}.pkl"

    candidates = []

    for root in unique_roots:
        for current_root, dirs, files in os.walk(root):
            # Exact filename first.
            for filename in files:
                if filename.lower() == target.lower():
                    candidates.append(
                        os.path.join(current_root, filename)
                    )

    # Prefer paths that actually contain the subject folder.
    candidates.sort(
        key=lambda p: (
            0 if os.path.basename(os.path.dirname(p)).upper() == subject_id else 1,
            len(p),
        )
    )

    if candidates:
        return candidates[0]

    return None


def load_subject_data(subject_id, wesad_dir=None):
    """
    Load one WESAD subject pickle using robust recursive search.
    """

    if wesad_dir is None:
        wesad_dir = WESAD_DIR

    pkl_path = find_subject_pickle(subject_id)

    if pkl_path is None:
        raise FileNotFoundError(
            f"Cannot find {subject_id}.pkl under /content.\n"
            f"Expected something like:\n"
            f"  {wesad_dir}/{subject_id}/{subject_id}.pkl"
        )

    print(f"  [FOUND] {pkl_path}")

    with open(pkl_path, "rb") as f:
        data = pickle.load(f, encoding="latin1")

    if not isinstance(data, dict):
        raise ValueError(
            f"{subject_id}.pkl loaded, but the content is not a dictionary."
        )

    if "signal" not in data or "wrist" not in data["signal"]:
        raise ValueError(
            f"{subject_id}.pkl does not contain signal['wrist']."
        )

    return data


# =============================================================================
# 5. DATASET VERIFICATION
# =============================================================================

def verify_wesad_subjects():
    """
    Check which expected subjects can actually be found.
    """

    print("\n" + "=" * 70)
    print("WESAD DATASET VERIFICATION")
    print("=" * 70)

    found = {}
    missing = []

    for subject in ALL_SUBJECTS:
        path = find_subject_pickle(subject)

        if path is not None:
            found[subject] = path
            print(f"[OK]      {subject}: {path}")
        else:
            missing.append(subject)
            print(f"[MISSING] {subject}")

    print("-" * 70)
    print(
        f"[INFO] Found {len(found)}/{len(ALL_SUBJECTS)} "
        f"expected subjects."
    )

    if missing:
        print(f"[INFO] Missing subjects: {missing}")

    print("=" * 70)

    return found


# =============================================================================
# 6. WRIST SIGNAL EXTRACTION
# =============================================================================

def extract_wrist_signals(subject_data):
    """
    Extract:
      BVP
      EDA
      TEMP
      ACC magnitude
      labels
    """

    wrist_data = subject_data["signal"]["wrist"]

    required = ["BVP", "EDA", "TEMP", "ACC"]

    for key in required:
        if key not in wrist_data:
            raise KeyError(
                f"Missing wrist signal: {key}"
            )

    if "label" not in subject_data:
        raise KeyError("Missing subject label.")

    bvp = np.asarray(
        wrist_data["BVP"]
    ).flatten().astype(np.float32)

    eda = np.asarray(
        wrist_data["EDA"]
    ).flatten().astype(np.float32)

    temp = np.asarray(
        wrist_data["TEMP"]
    ).flatten().astype(np.float32)

    acc = np.asarray(
        wrist_data["ACC"]
    ).astype(np.float32)

    if acc.ndim != 2 or acc.shape[1] != 3:
        raise ValueError(
            f"ACC has unexpected shape: {acc.shape}"
        )

    acc_mag = np.sqrt(
        np.sum(acc ** 2, axis=1)
    ).astype(np.float32)

    labels = np.asarray(
        subject_data["label"]
    ).flatten()

    return (
        bvp,
        eda,
        temp,
        acc_mag,
        labels,
    )


# =============================================================================
# 7. EDA PROCESSING
# =============================================================================

def decompose_eda(eda_seg, fs=EDA_SR):
    """
    Split EDA into tonic and phasic components.
    """

    eda_seg = np.asarray(
        eda_seg,
        dtype=np.float64
    )

    if len(eda_seg) == 0:
        return (
            np.zeros(0),
            np.zeros(0)
        )

    if len(eda_seg) < fs * 4:
        mean_value = np.mean(eda_seg)

        tonic = np.full_like(
            eda_seg,
            mean_value
        )

    else:
        try:
            b, a = butter(
                2,
                0.05 / (fs / 2),
                btype="low"
            )

            tonic = filtfilt(
                b,
                a,
                eda_seg
            )

        except Exception:
            tonic = np.full_like(
                eda_seg,
                np.mean(eda_seg)
            )

    phasic = eda_seg - tonic

    return tonic, phasic


# =============================================================================
# 8. HRV FEATURES
# =============================================================================

def compute_hrv_features(
    bvp_seg,
    fs=BVP_SR
):
    """
    Return:
      mean HR
      HR std
      RMSSD
      HR range
      beat count
    """

    if len(bvp_seg) < fs * 5:
        return np.zeros(
            5,
            dtype=np.float32
        )

    sig = np.asarray(
        bvp_seg,
        dtype=np.float64
    )

    sig = sig - np.mean(sig)

    min_distance = max(
        int(fs * 60 / 180),
        1
    )

    try:
        peaks, _ = find_peaks(
            sig,
            distance=min_distance
        )
    except Exception:
        return np.zeros(
            5,
            dtype=np.float32
        )

    if len(peaks) < 3:
        return np.zeros(
            5,
            dtype=np.float32
        )

    ibi = np.diff(peaks) / fs

    if len(ibi) == 0:
        return np.zeros(
            5,
            dtype=np.float32
        )

    hr = 60.0 / ibi

    valid = (
        (hr > 30)
        & (hr < 220)
        & np.isfinite(hr)
    )

    hr = hr[valid]

    if len(hr) < 2:
        return np.zeros(
            5,
            dtype=np.float32
        )

    mean_hr = np.mean(hr)
    std_hr = np.std(hr)
    hr_range = np.max(hr) - np.min(hr)

    ibi_valid = 60.0 / hr

    if len(ibi_valid) > 1:
        rmssd = np.sqrt(
            np.mean(
                np.diff(ibi_valid) ** 2
            )
        )
    else:
        rmssd = 0.0

    beat_count = float(len(hr))

    return np.array(
        [
            mean_hr,
            std_hr,
            rmssd,
            hr_range,
            beat_count,
        ],
        dtype=np.float32
    )


# =============================================================================
# 9. EDA FEATURES
# =============================================================================

def compute_eda_features(
    eda_seg,
    fs=EDA_SR
):
    """
    Return:
      mean SCL
      SCR count
      mean SCR amplitude
      phasic standard deviation
    """

    if len(eda_seg) < fs * 10:
        return np.zeros(
            4,
            dtype=np.float32
        )

    tonic, phasic = decompose_eda(
        eda_seg,
        fs
    )

    try:
        scr_peaks, _ = find_peaks(
            phasic,
            height=0.01,
            distance=max(fs, 1)
        )
    except Exception:
        scr_peaks = np.array(
            [],
            dtype=int
        )

    mean_scl = float(
        np.mean(tonic)
    )

    scr_count = float(
        len(scr_peaks)
    )

    if len(scr_peaks) > 0:
        mean_scr_amp = float(
            np.mean(
                phasic[scr_peaks]
            )
        )
    else:
        mean_scr_amp = 0.0

    phasic_std = float(
        np.std(phasic)
    )

    return np.array(
        [
            mean_scl,
            scr_count,
            mean_scr_amp,
            phasic_std,
        ],
        dtype=np.float32
    )


# =============================================================================
# 10. ACC FEATURES
# =============================================================================

def compute_acc_features(acc_seg):
    """
    Return:
      mean movement
      std movement
      max movement
    """

    if len(acc_seg) == 0:
        return np.zeros(
            3,
            dtype=np.float32
        )

    return np.array(
        [
            np.mean(acc_seg),
            np.std(acc_seg),
            np.max(acc_seg),
        ],
        dtype=np.float32
    )


# =============================================================================
# 11. TEMP FEATURES
# =============================================================================

def compute_temp_features(temp_seg):
    """
    Return:
      mean temperature
      linear temperature slope
    """

    if len(temp_seg) < 2:
        return np.zeros(
            2,
            dtype=np.float32
        )

    mean_temp = np.mean(
        temp_seg
    )

    x = np.arange(
        len(temp_seg),
        dtype=np.float64
    )

    try:
        slope = np.polyfit(
            x,
            temp_seg,
            1
        )[0]
    except Exception:
        slope = 0.0

    return np.array(
        [
            mean_temp,
            slope,
        ],
        dtype=np.float32
    )


# =============================================================================
# 12. MULTI-RATE WINDOW CREATION
# =============================================================================

def create_multirate_windows(
    bvp,
    eda,
    temp,
    acc_mag,
    labels
):
    """
    Build 60-second windows with 5-second stride.

    HR branch:
        BVP + ACC at 32 Hz

    LR branch:
        EDA tonic + EDA phasic + TEMP at 4 Hz

    Handcrafted features:
        14 total

    Window label:
        majority label among labels 1,2,3
    """

    duration = min(
        len(bvp) / BVP_SR,
        len(eda) / EDA_SR,
        len(temp) / TEMP_SR,
        len(acc_mag) / ACC_SR,
        len(labels) / LABEL_SR,
    )

    hr_windows = []
    lr_windows = []
    feat_windows = []
    win_labels = []

    start = 0.0

    while start + WINDOW_SEC <= duration:

        end = start + WINDOW_SEC

        bvp_seg = bvp[
            int(start * BVP_SR):
            int(end * BVP_SR)
        ]

        acc_seg = acc_mag[
            int(start * ACC_SR):
            int(end * ACC_SR)
        ]

        eda_seg = eda[
            int(start * EDA_SR):
            int(end * EDA_SR)
        ]

        temp_seg = temp[
            int(start * TEMP_SR):
            int(end * TEMP_SR)
        ]

        label_seg = labels[
            int(start * LABEL_SR):
            int(end * LABEL_SR)
        ]

        if len(label_seg) == 0:
            start += STEP_SEC
            continue

        # ---------------------------------------------------------
        # Majority label
        # ---------------------------------------------------------

        try:
            majority_result = stats.mode(
                label_seg,
                keepdims=True
            )

            majority = int(
                majority_result.mode[0]
            )

        except Exception:
            start += STEP_SEC
            continue

        if majority not in VALID_LABELS_ORIG:
            start += STEP_SEC
            continue

        # ---------------------------------------------------------
        # Resample high-rate signals to 32 Hz
        # ---------------------------------------------------------

        try:
            bvp_r = resample(
                bvp_seg,
                HR_LEN
            )

            acc_r = resample(
                acc_seg,
                HR_LEN
            )

            tonic_seg, phasic_seg = decompose_eda(
                eda_seg
            )

            tonic_r = resample(
                tonic_seg,
                LR_LEN
            )

            phasic_r = resample(
                phasic_seg,
                LR_LEN
            )

            temp_r = resample(
                temp_seg,
                LR_LEN
            )

        except Exception:
            start += STEP_SEC
            continue

        hr_win = np.stack(
            [
                bvp_r,
                acc_r
            ],
            axis=-1
        ).astype(np.float32)

        lr_win = np.stack(
            [
                tonic_r,
                phasic_r,
                temp_r
            ],
            axis=-1
        ).astype(np.float32)

        # ---------------------------------------------------------
        # 14 handcrafted features
        # ---------------------------------------------------------

        feat_vec = np.concatenate(
            [
                compute_hrv_features(
                    bvp_seg
                ),

                compute_eda_features(
                    eda_seg
                ),

                compute_acc_features(
                    acc_seg
                ),

                compute_temp_features(
                    temp_seg
                ),
            ]
        ).astype(np.float32)

        if len(feat_vec) != FEAT_DIM:
            raise ValueError(
                f"Expected {FEAT_DIM} features, "
                f"got {len(feat_vec)}."
            )

        hr_windows.append(hr_win)
        lr_windows.append(lr_win)
        feat_windows.append(feat_vec)
        win_labels.append(
            LABEL_MAP[majority]
        )

        start += STEP_SEC

    if len(win_labels) == 0:
        return (
            np.zeros(
                (0, HR_LEN, 2),
                dtype=np.float32
            ),
            np.zeros(
                (0, LR_LEN, 3),
                dtype=np.float32
            ),
            np.zeros(
                (0, FEAT_DIM),
                dtype=np.float32
            ),
            np.zeros(
                0,
                dtype=int
            ),
        )

    return (
        np.asarray(
            hr_windows,
            dtype=np.float32
        ),
        np.asarray(
            lr_windows,
            dtype=np.float32
        ),
        np.asarray(
            feat_windows,
            dtype=np.float32
        ),
        np.asarray(
            win_labels,
            dtype=int
        ),
    )


# =============================================================================
# 13. SUBJECT BASELINE CALIBRATION
# =============================================================================

def subject_baseline_calibration(
    hr_w,
    lr_w,
    feat_w,
    labels
):
    """
    Z-score using only the subject's Baseline windows.
    """

    baseline_mask = labels == 0

    if not np.any(baseline_mask):
        print(
            "[WARNING] No baseline windows found "
            "for subject calibration. Skipping."
        )
        return (
            hr_w,
            lr_w,
            feat_w
        )

    def zscore_by_baseline(arr):

        base = arr[
            baseline_mask
        ]

        if arr.ndim == 3:
            base_flat = base.reshape(
                -1,
                base.shape[-1]
            )

            mean = base_flat.mean(
                axis=0
            )

            std = base_flat.std(
                axis=0
            )

        else:
            mean = base.mean(
                axis=0
            )

            std = base.std(
                axis=0
            )

        std = np.asarray(
            std,
            dtype=np.float32
        )

        std[std == 0] = 1e-8

        return (
            arr - mean
        ) / std

    return (
        zscore_by_baseline(hr_w),
        zscore_by_baseline(lr_w),
        zscore_by_baseline(feat_w),
    )


# =============================================================================
# 14. SUBJECT PREPARATION
# =============================================================================

def prepare_subject_dataset(
    subject_id,
    wesad_dir
):

    print(
        f"  [SUBJECT {subject_id}] Loading raw data..."
    )

    raw_data = load_subject_data(
        subject_id,
        wesad_dir
    )

    print(
        f"  [SUBJECT {subject_id}] "
        "Extracting wrist signals..."
    )

    (
        bvp,
        eda,
        temp,
        acc_mag,
        labels,
    ) = extract_wrist_signals(
        raw_data
    )

    print(
        f"  [SUBJECT {subject_id}] "
        f"BVP={len(bvp)} | "
        f"EDA={len(eda)} | "
        f"TEMP={len(temp)} | "
        f"ACC={len(acc_mag)} | "
        f"Labels={len(labels)}"
    )

    print(
        f"  [SUBJECT {subject_id}] "
        f"Building {WINDOW_SEC}s windows "
        f"with {STEP_SEC}s step..."
    )

    (
        hr_w,
        lr_w,
        feat_w,
        win_labels,
    ) = create_multirate_windows(
        bvp,
        eda,
        temp,
        acc_mag,
        labels
    )

    if len(win_labels) == 0:
        print(
            f"  [WARNING] {subject_id}: "
            "No valid windows."
        )

        return (
            hr_w,
            lr_w,
            feat_w,
            win_labels
        )

    print(
        f"  [SUBJECT {subject_id}] "
        "Applying baseline calibration..."
    )

    (
        hr_c,
        lr_c,
        feat_c,
    ) = subject_baseline_calibration(
        hr_w,
        lr_w,
        feat_w,
        win_labels
    )

    counts = dict(
        zip(
            *np.unique(
                win_labels,
                return_counts=True
            )
        )
    )

    print(
        f"  [SUBJECT {subject_id}] "
        f"Done: {len(win_labels)} windows | "
        f"Class distribution: {counts}"
    )

    return (
        hr_c,
        lr_c,
        feat_c,
        win_labels
    )


# =============================================================================
# 15. PYTORCH DATASET
# =============================================================================

class WindowDataset(Dataset):

    def __init__(
        self,
        hr,
        lr,
        feat,
        y,
        augment=False
    ):

        self.hr = torch.from_numpy(
            np.asarray(hr)
        ).float()

        self.lr = torch.from_numpy(
            np.asarray(lr)
        ).float()

        self.feat = torch.from_numpy(
            np.asarray(feat)
        ).float()

        self.y = torch.from_numpy(
            np.asarray(y)
        ).long()

        self.augment = augment

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):

        hr = self.hr[idx].clone()
        lr = self.lr[idx].clone()

        feat = self.feat[idx]
        y = self.y[idx]

        if self.augment:

            if np.random.rand() < 0.5:
                hr = (
                    hr
                    + torch.randn_like(hr) * 0.05
                )

            if np.random.rand() < 0.5:
                lr = (
                    lr
                    + torch.randn_like(lr) * 0.05
                )

            if np.random.rand() < 0.3:
                scale = (
                    1.0
                    + (np.random.rand() - 0.5)
                    * 0.2
                )

                hr = hr * scale

        return (
            hr,
            lr,
            feat,
            y
        )


# =============================================================================
# 16. MODEL: HIGH-RATE BRANCH
# =============================================================================

class HRBranch(nn.Module):

    def __init__(
        self,
        in_ch=2,
        out_len=60,
        dropout=DROPOUT_RATE
    ):

        super().__init__()

        self.cnn = nn.Sequential(

            nn.Conv1d(
                in_ch,
                32,
                kernel_size=5,
                padding=2
            ),

            nn.BatchNorm1d(32),
            nn.ReLU(),

            nn.MaxPool1d(2),

            nn.Conv1d(
                32,
                64,
                kernel_size=5,
                padding=2
            ),

            nn.BatchNorm1d(64),
            nn.ReLU(),

            nn.MaxPool1d(2),

            nn.Conv1d(
                64,
                64,
                kernel_size=3,
                padding=1
            ),

            nn.BatchNorm1d(64),
            nn.ReLU(),

            nn.Dropout(dropout),

            nn.AdaptiveAvgPool1d(
                out_len
            ),
        )

        self.gru = nn.GRU(
            input_size=64,
            hidden_size=64,
            num_layers=1,
            batch_first=True,
            bidirectional=True,
        )

    def forward(self, x):

        x = x.permute(
            0,
            2,
            1
        )

        x = self.cnn(x)

        x = x.permute(
            0,
            2,
            1
        )

        out, _ = self.gru(x)

        return out.mean(
            dim=1
        )


# =============================================================================
# 17. MODEL: LOW-RATE BRANCH
# =============================================================================

class LRBranch(nn.Module):

    def __init__(
        self,
        in_ch=3,
        dropout=DROPOUT_RATE
    ):

        super().__init__()

        self.cnn = nn.Sequential(

            nn.Conv1d(
                in_ch,
                32,
                kernel_size=3,
                padding=1
            ),

            nn.BatchNorm1d(32),
            nn.ReLU(),

            nn.MaxPool1d(2),

            nn.Conv1d(
                32,
                64,
                kernel_size=3,
                padding=1
            ),

            nn.BatchNorm1d(64),
            nn.ReLU(),

            nn.Dropout(dropout),
        )

    def forward(self, x):

        x = x.permute(
            0,
            2,
            1
        )

        x = self.cnn(x)

        avg = x.mean(
            dim=2
        )

        mx, _ = x.max(
            dim=2
        )

        return torch.cat(
            [avg, mx],
            dim=1
        )


# =============================================================================
# 18. MODEL: FEATURE BRANCH
# =============================================================================

class FeatureBranch(nn.Module):

    def __init__(
        self,
        in_dim=FEAT_DIM,
        dropout=DROPOUT_RATE
    ):

        super().__init__()

        self.net = nn.Sequential(

            nn.Linear(
                in_dim,
                32
            ),

            nn.LayerNorm(32),
            nn.ReLU(),

            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)


# =============================================================================
# 19. MULTI-MODAL CNN-BiGRU
# =============================================================================

class MultiModalCNNBiGRU(nn.Module):

    def __init__(
        self,
        num_classes=NUM_CLASSES,
        dropout=DROPOUT_RATE
    ):

        super().__init__()

        self.hr_branch = HRBranch(
            dropout=dropout
        )

        self.lr_branch = LRBranch(
            dropout=dropout
        )

        self.feat_branch = FeatureBranch(
            dropout=dropout
        )

        fusion_dim = (
            128
            + 128
            + 32
        )

        self.classifier = nn.Sequential(

            nn.Linear(
                fusion_dim,
                128
            ),

            nn.ReLU(),

            nn.Dropout(dropout),

            nn.Linear(
                128,
                num_classes
            ),
        )

    def forward(
        self,
        hr,
        lr,
        feat
    ):

        e1 = self.hr_branch(hr)
        e2 = self.lr_branch(lr)
        e3 = self.feat_branch(feat)

        fused = torch.cat(
            [
                e1,
                e2,
                e3
            ],
            dim=1
        )

        return self.classifier(
            fused
        )


# =============================================================================
# 20. TRAINING
# =============================================================================

def train_one_epoch(
    model,
    loader,
    criterion,
    optimizer,
    device
):

    model.train()

    total_loss = 0.0

    all_preds = []
    all_true = []

    for hr, lr, feat, y in loader:

        hr = hr.to(device)
        lr = lr.to(device)
        feat = feat.to(device)
        y = y.to(device)

        optimizer.zero_grad()

        out = model(
            hr,
            lr,
            feat
        )

        loss = criterion(
            out,
            y
        )

        loss.backward()

        torch.nn.utils.clip_grad_norm_(
            model.parameters(),
            GRAD_CLIP_NORM
        )

        optimizer.step()

        total_loss += (
            loss.item()
            * hr.size(0)
        )

        all_preds.extend(
            out.argmax(
                dim=1
            ).detach().cpu().numpy()
        )

        all_true.extend(
            y.detach().cpu().numpy()
        )

    if len(loader.dataset) == 0:
        return 0.0, 0.0

    avg_loss = (
        total_loss
        / len(loader.dataset)
    )

    acc = accuracy_score(
        all_true,
        all_preds
    )

    return avg_loss, acc


# =============================================================================
# 21. EVALUATION
# =============================================================================

def evaluate(
    model,
    loader,
    criterion,
    device
):

    model.eval()

    total_loss = 0.0

    all_preds = []
    all_true = []
    all_probs = []

    with torch.no_grad():

        for hr, lr, feat, y in loader:

            hr = hr.to(device)
            lr = lr.to(device)
            feat = feat.to(device)
            y = y.to(device)

            out = model(
                hr,
                lr,
                feat
            )

            loss = criterion(
                out,
                y
            )

            total_loss += (
                loss.item()
                * hr.size(0)
            )

            probs = torch.softmax(
                out,
                dim=1
            ).cpu().numpy()

            preds = out.argmax(
                dim=1
            ).cpu().numpy()

            true = y.cpu().numpy()

            all_probs.extend(probs)
            all_preds.extend(preds)
            all_true.extend(true)

    if len(loader.dataset) == 0:
        return (
            0.0,
            0.0,
            np.array([]),
            np.array([]),
            np.array([]),
        )

    avg_loss = (
        total_loss
        / len(loader.dataset)
    )

    acc = accuracy_score(
        all_true,
        all_preds
    )

    return (
        avg_loss,
        acc,
        np.asarray(all_true),
        np.asarray(all_preds),
        np.asarray(all_probs),
    )


# =============================================================================
# 22. LOSO FOLD
# =============================================================================

def run_loso_fold(
    subject_data_dict,
    test_subject_id,
    all_subjects
):

    print("\n" + "=" * 70)
    print(
        f"[FOLD] Test Subject: "
        f"{test_subject_id}"
    )
    print("=" * 70)

    train_subjects_all = [
        s for s in all_subjects
        if s != test_subject_id
    ]

    if len(train_subjects_all) < 2:
        print(
            "[FOLD] Not enough training subjects."
        )
        return None, None

    # Deterministic validation subject.
    # The test subject remains untouched.
    val_subject = train_subjects_all[0]

    train_subjects_final = (
        train_subjects_all[1:]
    )

    def gather(subjs):

        hr_l = []
        lr_l = []
        feat_l = []
        y_l = []

        for s in subjs:

            hr, lr, feat, y = (
                subject_data_dict[s]
            )

            if len(y) > 0:

                hr_l.append(hr)
                lr_l.append(lr)
                feat_l.append(feat)
                y_l.append(y)

        if not y_l:

            return (
                np.zeros(
                    (0, HR_LEN, 2),
                    dtype=np.float32
                ),

                np.zeros(
                    (0, LR_LEN, 3),
                    dtype=np.float32
                ),

                np.zeros(
                    (0, FEAT_DIM),
                    dtype=np.float32
                ),

                np.zeros(
                    0,
                    dtype=int
                ),
            )

        return (
            np.concatenate(hr_l),
            np.concatenate(lr_l),
            np.concatenate(feat_l),
            np.concatenate(y_l),
        )

    (
        hr_train,
        lr_train,
        feat_train,
        y_train,
    ) = gather(
        train_subjects_final
    )

    (
        hr_val,
        lr_val,
        feat_val,
        y_val,
    ) = subject_data_dict[
        val_subject
    ]

    (
        hr_test,
        lr_test,
        feat_test,
        y_test,
    ) = subject_data_dict[
        test_subject_id
    ]

    if (
        len(y_train) == 0
        or len(y_val) == 0
        or len(y_test) == 0
    ):

        print(
            f"[FOLD] Missing data in "
            f"train/val/test for "
            f"{test_subject_id}. Skipping."
        )

        return None, None

    # -----------------------------------------------------------------
    # Scale each deep branch using TRAINING data only.
    # -----------------------------------------------------------------

    def fit_scale_3d(
        train_arr,
        *other_arrs
    ):

        _, _, c = train_arr.shape

        scaler = StandardScaler().fit(
            train_arr.reshape(-1, c)
        )

        def apply(arr):

            n2, l2, c2 = arr.shape

            return scaler.transform(
                arr.reshape(-1, c2)
            ).reshape(
                n2,
                l2,
                c2
            )

        return (
            apply(train_arr),
            *[
                apply(a)
                for a in other_arrs
            ],
        )

    (
        hr_train_s,
        hr_val_s,
        hr_test_s,
    ) = fit_scale_3d(
        hr_train,
        hr_val,
        hr_test
    )

    (
        lr_train_s,
        lr_val_s,
        lr_test_s,
    ) = fit_scale_3d(
        lr_train,
        lr_val,
        lr_test
    )

    feat_scaler = StandardScaler().fit(
        feat_train
    )

    feat_train_s = feat_scaler.transform(
        feat_train
    )

    feat_val_s = feat_scaler.transform(
        feat_val
    )

    feat_test_s = feat_scaler.transform(
        feat_test
    )

    print(
        f"  Train: {len(y_train)} windows | "
        f"Val ({val_subject}): {len(y_val)} | "
        f"Test ({test_subject_id}): {len(y_test)}"
    )

    train_counts = dict(
        zip(
            *np.unique(
                y_train,
                return_counts=True
            )
        )
    )

    print(
        f"  Train class distribution: "
        f"{train_counts}"
    )

    # -----------------------------------------------------------------
    # Class weights
    # -----------------------------------------------------------------

    classes, counts = np.unique(
        y_train,
        return_counts=True
    )

    total = len(y_train)

    class_weights = np.ones(
        NUM_CLASSES,
        dtype=np.float32
    )

    for idx in range(NUM_CLASSES):

        if idx in classes:

            class_weights[idx] = (
                total
                / (
                    NUM_CLASSES
                    * counts[
                        classes == idx
                    ][0]
                )
            )

    print(
        "  Class weights:",
        dict(
            zip(
                CLASS_NAMES,
                np.round(
                    class_weights,
                    4
                )
            )
        )
    )

    class_weights_t = torch.tensor(
        class_weights,
        dtype=torch.float32,
        device=DEVICE
    )

    # -----------------------------------------------------------------
    # Data loaders
    # -----------------------------------------------------------------

    train_ds = WindowDataset(
        hr_train_s,
        lr_train_s,
        feat_train_s,
        y_train,
        augment=True
    )

    val_ds = WindowDataset(
        hr_val_s,
        lr_val_s,
        feat_val_s,
        y_val,
        augment=False
    )

    test_ds = WindowDataset(
        hr_test_s,
        lr_test_s,
        feat_test_s,
        y_test,
        augment=False
    )

    train_loader = DataLoader(
        train_ds,
        batch_size=BATCH_SIZE,
        shuffle=True,
        # Prevent a final batch of size 1, which is unsafe with BatchNorm.
        # The FeatureBranch also uses LayerNorm for extra robustness.
        drop_last=True,
        num_workers=NUM_WORKERS,
        pin_memory=torch.cuda.is_available()
    )

    val_loader = DataLoader(
        val_ds,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=torch.cuda.is_available()
    )

    test_loader = DataLoader(
        test_ds,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=torch.cuda.is_available()
    )

    # -----------------------------------------------------------------
    # Model
    # -----------------------------------------------------------------

    torch.manual_seed(
        SEED + int(
            test_subject_id[1:]
        )
    )

    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(
            SEED + int(
                test_subject_id[1:]
            )
        )

    model = MultiModalCNNBiGRU().to(
        DEVICE
    )

    criterion = nn.CrossEntropyLoss(
        weight=class_weights_t
    )

    optimizer = optim.Adam(
        model.parameters(),
        lr=LEARNING_RATE,
        weight_decay=WEIGHT_DECAY
    )

    scheduler = (
        optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode="min",
            factor=0.5,
            patience=3
        )
    )

    # -----------------------------------------------------------------
    # Training
    # -----------------------------------------------------------------

    best_val_acc = -np.inf
    best_val_loss = np.inf
    best_state = None
    patience_counter = 0

    for epoch in range(
        1,
        EPOCHS + 1
    ):

        (
            train_loss,
            train_acc,
        ) = train_one_epoch(
            model,
            train_loader,
            criterion,
            optimizer,
            DEVICE
        )

        (
            val_loss,
            val_acc,
            _,
            _,
            _,
        ) = evaluate(
            model,
            val_loader,
            criterion,
            DEVICE
        )

        scheduler.step(
            val_loss
        )

        marker = ""

        # Primary criterion: validation accuracy.
        # Tie-breaker: validation loss.
        improved = (
            val_acc > best_val_acc
            or (
                np.isclose(
                    val_acc,
                    best_val_acc
                )
                and val_loss < best_val_loss
            )
        )

        if improved:

            best_val_acc = val_acc
            best_val_loss = val_loss

            best_state = copy.deepcopy(
                model.state_dict()
            )

            patience_counter = 0
            marker = "  <-- BEST (val)"

        else:

            patience_counter += 1

        current_lr = optimizer.param_groups[0][
            "lr"
        ]

        print(
            f"  Epoch [{epoch}/{EPOCHS}] | "
            f"Train Loss: {train_loss:.4f} "
            f"Acc: {train_acc:.4f} | "
            f"Val Loss: {val_loss:.4f} "
            f"Acc: {val_acc:.4f} | "
            f"LR: {current_lr:.2e}"
            f"{marker}"
        )

        if (
            patience_counter
            >= EARLY_STOP_PATIENCE
        ):

            print(
                f"  Early stopping at epoch "
                f"{epoch} "
                f"(no validation improvement "
                f"for {EARLY_STOP_PATIENCE} epochs)."
            )

            break

    # -----------------------------------------------------------------
    # Restore best validation checkpoint.
    # -----------------------------------------------------------------

    if best_state is not None:
        model.load_state_dict(
            best_state
        )

    # -----------------------------------------------------------------
    # Final test evaluation.
    # Test is touched only here.
    # -----------------------------------------------------------------

    (
        test_loss,
        test_acc,
        y_true,
        y_pred,
        _,
    ) = evaluate(
        model,
        test_loader,
        criterion,
        DEVICE
    )

    test_bal_acc = (
        balanced_accuracy_score(
            y_true,
            y_pred
        )
        if len(y_true) > 0
        else 0.0
    )

    test_f1 = (
        f1_score(
            y_true,
            y_pred,
            average="macro"
        )
        if len(y_true) > 0
        else 0.0
    )

    print(
        f"\n  [FOLD RESULT] "
        f"Subject {test_subject_id} | "
        f"Best Val Acc: {best_val_acc:.4f} | "
        f"TEST Acc: {test_acc:.4f} | "
        f"Balanced Acc: {test_bal_acc:.4f} | "
        f"Macro F1: {test_f1:.4f}"
    )

    return y_true, y_pred


# =============================================================================
# 23. CONFUSION MATRIX
# =============================================================================

def plot_confusion_matrix(
    y_true,
    y_pred,
    class_names,
    title="Confusion Matrix (LOSO)"
):

    cm = confusion_matrix(
        y_true,
        y_pred,
        labels=np.arange(
            len(class_names)
        )
    )

    row_sums = cm.sum(
        axis=1,
        keepdims=True
    )

    cm_percent = np.divide(
        cm.astype(float),
        row_sums,
        out=np.zeros_like(
            cm,
            dtype=float
        ),
        where=row_sums != 0
    ) * 100

    fig, ax = plt.subplots(
        figsize=(8, 6)
    )

    sns.heatmap(
        cm_percent,
        annot=True,
        fmt=".1f",
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names,
        cbar_kws={
            "label": "Percentage (%)"
        },
        ax=ax
    )

    for i in range(
        cm.shape[0]
    ):

        for j in range(
            cm.shape[1]
        ):

            count = cm[i, j]

            ax.text(
                j + 0.5,
                i + 0.72,
                f"(n={count})",
                ha="center",
                va="center",
                color="gray",
                fontsize=9
            )

    ax.set_xlabel(
        "Predicted Label",
        fontsize=12,
        fontweight="bold"
    )

    ax.set_ylabel(
        "True Label",
        fontsize=12,
        fontweight="bold"
    )

    ax.set_title(
        title,
        fontsize=14,
        fontweight="bold",
        pad=15
    )

    plt.tight_layout()
    plt.show()

    return cm, cm_percent


# =============================================================================
# 24. MAIN
# =============================================================================

def main():

    print("\n" + "=" * 70)
    print(
        "  SUBJECT-INDEPENDENT STRESS DETECTION FRAMEWORK (v3)"
    )
    print(
        "  LOSO | Multi-Rate Multi-Modal CNN-BiGRU + Features"
    )
    print(
        "  Subjects:",
        ALL_SUBJECTS
    )
    print("=" * 70)

    # -----------------------------------------------------------------
    # Verify dataset before any preprocessing.
    # -----------------------------------------------------------------

    found_subject_paths = (
        verify_wesad_subjects()
    )

    if len(found_subject_paths) < 4:

        print(
            "\n[ERROR] Fewer than 4 WESAD subjects "
            "were found."
        )

        print(
            "\nPlease check:"
        )

        print(
            "1. WESAD.zip exists in "
            "/content/drive/MyDrive/"
        )

        print(
            "2. The ZIP actually contains S2.pkl, "
            "S3.pkl, etc."
        )

        print(
            "3. Run the dataset verification cell "
            "again after uploading/extracting."
        )

        return None

    # -----------------------------------------------------------------
    # Preprocess subjects.
    # -----------------------------------------------------------------

    subject_data_dict = {}

    print(
        "\n[STEP 1] Preprocessing usable subjects:"
    )

    for subj in ALL_SUBJECTS:

        if subj not in found_subject_paths:

            print(
                f"  [WARNING] Skipping {subj}: "
                "pickle not found."
            )

            subject_data_dict[subj] = (
                np.zeros(
                    (0, HR_LEN, 2),
                    dtype=np.float32
                ),
                np.zeros(
                    (0, LR_LEN, 3),
                    dtype=np.float32
                ),
                np.zeros(
                    (0, FEAT_DIM),
                    dtype=np.float32
                ),
                np.zeros(
                    0,
                    dtype=int
                ),
            )

            print()
            continue

        try:

            (
                hr_c,
                lr_c,
                feat_c,
                y,
            ) = prepare_subject_dataset(
                subj,
                WESAD_DIR
            )

            subject_data_dict[subj] = (
                hr_c,
                lr_c,
                feat_c,
                y
            )

        except Exception as e:

            print(
                f"  [ERROR] Failed to process "
                f"{subj}: {type(e).__name__}: {e}"
            )

            subject_data_dict[subj] = (
                np.zeros(
                    (0, HR_LEN, 2),
                    dtype=np.float32
                ),
                np.zeros(
                    (0, LR_LEN, 3),
                    dtype=np.float32
                ),
                np.zeros(
                    (0, FEAT_DIM),
                    dtype=np.float32
                ),
                np.zeros(
                    0,
                    dtype=int
                ),
            )

        print()

    # -----------------------------------------------------------------
    # Valid subjects.
    # -----------------------------------------------------------------

    valid_subjects = [
        s
        for s in ALL_SUBJECTS
        if len(
            subject_data_dict[s][3]
        ) > 0
    ]

    print(
        f"[INFO] {len(valid_subjects)}/"
        f"{len(ALL_SUBJECTS)} subjects "
        "have usable data:"
    )

    print(
        f"       {valid_subjects}"
    )

    if len(valid_subjects) < 4:

        print(
            "\n[ERROR] Not enough valid subjects "
            "with usable windows."
        )

        return None

    # -----------------------------------------------------------------
    # LOSO.
    # -----------------------------------------------------------------

    print(
        "\n[STEP 2] Running "
        "Leave-One-Subject-Out "
        "Cross-Validation..."
    )

    all_y_true = []
    all_y_pred = []

    fold_accuracies = {}
    fold_balanced_accuracies = {}
    fold_macro_f1 = {}

    for test_subj in valid_subjects:

        (
            y_true_fold,
            y_pred_fold,
        ) = run_loso_fold(
            subject_data_dict,
            test_subj,
            valid_subjects
        )

        if (
            y_true_fold is not None
            and len(y_true_fold) > 0
        ):

            all_y_true.extend(
                y_true_fold
            )

            all_y_pred.extend(
                y_pred_fold
            )

            fold_accuracies[
                test_subj
            ] = accuracy_score(
                y_true_fold,
                y_pred_fold
            )

            fold_balanced_accuracies[
                test_subj
            ] = balanced_accuracy_score(
                y_true_fold,
                y_pred_fold
            )

            fold_macro_f1[
                test_subj
            ] = f1_score(
                y_true_fold,
                y_pred_fold,
                average="macro"
            )

    # -----------------------------------------------------------------
    # Safety check.
    # -----------------------------------------------------------------

    if len(all_y_true) == 0:

        print(
            "\n[ERROR] No LOSO folds completed."
        )

        return None

    all_y_true = np.asarray(
        all_y_true
    )

    all_y_pred = np.asarray(
        all_y_pred
    )

    # -----------------------------------------------------------------
    # Final results.
    # -----------------------------------------------------------------

    print("\n" + "=" * 70)
    print(
        "  LOSO CROSS-VALIDATION - FINAL RESULTS"
    )
    print("=" * 70)

    print(
        "\nPer-Subject Holdout Results:"
    )

    for subj in fold_accuracies:

        print(
            f"  {subj}: "
            f"Accuracy={fold_accuracies[subj]:.4f} "
            f"({fold_accuracies[subj] * 100:.2f}%) | "
            f"Balanced Acc="
            f"{fold_balanced_accuracies[subj]:.4f} | "
            f"Macro F1="
            f"{fold_macro_f1[subj]:.4f}"
        )

    overall_acc = accuracy_score(
        all_y_true,
        all_y_pred
    )

    overall_bal_acc = (
        balanced_accuracy_score(
            all_y_true,
            all_y_pred
        )
    )

    overall_macro_f1 = f1_score(
        all_y_true,
        all_y_pred,
        average="macro"
    )

    mean_subject_acc = np.mean(
        list(
            fold_accuracies.values()
        )
    )

    std_subject_acc = np.std(
        list(
            fold_accuracies.values()
        )
    )

    print(
        f"\nOverall LOSO Accuracy: "
        f"{overall_acc:.4f} "
        f"({overall_acc * 100:.2f}%)"
    )

    print(
        f"Overall Balanced Accuracy: "
        f"{overall_bal_acc:.4f} "
        f"({overall_bal_acc * 100:.2f}%)"
    )

    print(
        f"Overall Macro F1: "
        f"{overall_macro_f1:.4f}"
    )

    print(
        f"Mean Per-Subject Accuracy: "
        f"{mean_subject_acc:.4f} "
        f"(±{std_subject_acc:.4f})"
    )

    # -----------------------------------------------------------------
    # Classification report.
    # -----------------------------------------------------------------

    print("\n" + "=" * 70)
    print(
        "  CLASSIFICATION REPORT"
    )
    print("=" * 70)

    report = classification_report(
        all_y_true,
        all_y_pred,
        labels=np.arange(
            NUM_CLASSES
        ),
        target_names=CLASS_NAMES,
        digits=4,
        zero_division=0
    )

    print(report)

    # -----------------------------------------------------------------
    # Confusion matrix.
    # -----------------------------------------------------------------

    print("\n" + "=" * 70)
    print(
        "  CONFUSION MATRIX"
    )
    print("=" * 70)

    (
        cm,
        cm_pct
    ) = plot_confusion_matrix(
        all_y_true,
        all_y_pred,
        CLASS_NAMES
    )

    print(
        "\nConfusion Matrix (Counts):"
    )

    print(
        pd.DataFrame(
            cm,
            index=CLASS_NAMES,
            columns=CLASS_NAMES
        )
    )

    print(
        "\nConfusion Matrix (Row %):"
    )

    print(
        pd.DataFrame(
            np.round(
                cm_pct,
                2
            ),
            index=CLASS_NAMES,
            columns=CLASS_NAMES
        )
    )

    # -----------------------------------------------------------------
    # Final summary.
    # -----------------------------------------------------------------

    print("\n" + "=" * 70)
    print(
        "  PIPELINE COMPLETE"
    )
    print("=" * 70)

    print(
        "\nImportant:"
    )

    print(
        "- The test subject was not used for "
        "checkpoint selection."
    )

    print(
        "- Scaling was fitted using training "
        "subjects only."
    )

    print(
        "- Validation subjects were used for "
        "early stopping."
    )

    print(
        "- The final reported test results are "
        "from held-out subjects."
    )

    print(
        "\nPossible next experiments:"
    )

    print(
        "1. WeightedRandomSampler for Amusement."
    )

    print(
        "2. STEP_SEC=3 for more windows."
    )

    print(
        "3. Add chest-device respiration/ECG "
        "features if available."
    )

    print(
        "4. Compare against Random Forest/XGBoost "
        "using handcrafted features."
    )

    return {
        "fold_accuracies": fold_accuracies,
        "fold_balanced_accuracies": fold_balanced_accuracies,
        "fold_macro_f1": fold_macro_f1,
        "overall_accuracy": overall_acc,
        "overall_balanced_accuracy": overall_bal_acc,
        "overall_macro_f1": overall_macro_f1,
        "classification_report": report,
        "confusion_matrix": cm,
        "y_true": all_y_true,
        "y_pred": all_y_pred,
    }


# =============================================================================
# 25. RUN
# =============================================================================

if __name__ == "__main__":
    results = main()
# Out:
# Mounted at /content/drive
# [INFO] WESAD ZIP found: /content/drive/MyDrive/WESAD/WESAD.zip
# [INFO] No WESAD subject pickle files found.
# [INFO] Extracting WESAD.zip...
# [INFO] Extraction completed.
# [INFO] Using device: cuda
#
# ======================================================================
#   SUBJECT-INDEPENDENT STRESS DETECTION FRAMEWORK (v3)
#   LOSO | Multi-Rate Multi-Modal CNN-BiGRU + Features
#   Subjects: ['S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S13', 'S14', 'S15', 'S16', 'S17']
# ======================================================================
#
# ======================================================================
# WESAD DATASET VERIFICATION
# ======================================================================
# [OK]      S2: /content/WESAD/S2/S2.pkl
# [OK]      S3: /content/WESAD/S3/S3.pkl
# [OK]      S4: /content/WESAD/S4/S4.pkl
# [OK]      S5: /content/WESAD/S5/S5.pkl
# [OK]      S6: /content/WESAD/S6/S6.pkl
# [OK]      S7: /content/WESAD/S7/S7.pkl
# [OK]      S8: /content/WESAD/S8/S8.pkl
# [OK]      S9: /content/WESAD/S9/S9.pkl
# [OK]      S10: /content/WESAD/S10/S10.pkl
# [OK]      S11: /content/WESAD/S11/S11.pkl
# [OK]      S13: /content/WESAD/S13/S13.pkl
# [OK]      S14: /content/WESAD/S14/S14.pkl
# [OK]      S15: /content/WESAD/S15/S15.pkl
# [OK]      S16: /content/WESAD/S16/S16.pkl
# [OK]      S17: /content/WESAD/S17/S17.pkl
# ----------------------------------------------------------------------
# [INFO] Found 15/15 expected subjects.
# ======================================================================
#
# [STEP 1] Preprocessing usable subjects:
#   [SUBJECT S2] Loading raw data...
#   [FOUND] /content/WESAD/S2/S2.pkl
#   [SUBJECT S2] Extracting wrist signals...
#   [SUBJECT S2] BVP=389056 | EDA=24316 | TEMP=24316 | ACC=194528 | Labels=4255300
#   [SUBJECT S2] Building 60s windows with 5s step...
#   [SUBJECT S2] Applying baseline calibration...
#   [SUBJECT S2] Done: 425 windows | Class distribution: {np.int64(0): np.int64(229), np.int64(1): np.int64(123), np.int64(2): np.int64(73)}
#
#   [SUBJECT S3] Loading raw data...
#   [FOUND] /content/WESAD/S3/S3.pkl
#   [SUBJECT S3] Extracting wrist signals...
#   [SUBJECT S3] BVP=415552 | EDA=25972 | TEMP=25972 | ACC=207776 | Labels=4545100
#   [SUBJECT S3] Building 60s windows with 5s step...
#   [SUBJECT S3] Applying baseline calibration...
#   [SUBJECT S3] Done: 431 windows | Class distribution: {np.int64(0): np.int64(228), np.int64(1): np.int64(128), np.int64(2): np.int64(75)}
#
#   [SUBJECT S4] Loading raw data...
#   [FOUND] /content/WESAD/S4/S4.pkl
#   [SUBJECT S4] Extracting wrist signals...
#   [SUBJECT S4] BVP=411072 | EDA=25692 | TEMP=25692 | ACC=205536 | Labels=4496100
#   [SUBJECT S4] Building 60s windows with 5s step...
#   [SUBJECT S4] Applying baseline calibration...
#   [SUBJECT S4] Done: 432 windows | Class distribution: {np.int64(0): np.int64(231), np.int64(1): np.int64(127), np.int64(2): np.int64(74)}
#
#   [SUBJECT S5] Loading raw data...
#   [FOUND] /content/WESAD/S5/S5.pkl
#   [SUBJECT S5] Extracting wrist signals...
#   [SUBJECT S5] BVP=400512 | EDA=25032 | TEMP=25032 | ACC=200256 | Labels=4380600
#   [SUBJECT S5] Building 60s windows with 5s step...
#   [SUBJECT S5] Applying baseline calibration...
#   [SUBJECT S5] Done: 444 windows | Class distribution: {np.int64(0): np.int64(240), np.int64(1): np.int64(129), np.int64(2): np.int64(75)}
#
#   [SUBJECT S6] Loading raw data...
#   [FOUND] /content/WESAD/S6/S6.pkl
#   [SUBJECT S6] Extracting wrist signals...
#   [SUBJECT S6] BVP=452544 | EDA=28284 | TEMP=28284 | ACC=226272 | Labels=4949700
#   [SUBJECT S6] Building 60s windows with 5s step...
#   [SUBJECT S6] Applying baseline calibration...
#   [SUBJECT S6] Done: 440 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(130), np.int64(2): np.int64(74)}
#
#   [SUBJECT S7] Loading raw data...
#   [FOUND] /content/WESAD/S7/S7.pkl
#   [SUBJECT S7] Extracting wrist signals...
#   [SUBJECT S7] BVP=335232 | EDA=20952 | TEMP=20952 | ACC=167616 | Labels=3666600
#   [SUBJECT S7] Building 60s windows with 5s step...
#   [SUBJECT S7] Applying baseline calibration...
#   [SUBJECT S7] Done: 439 windows | Class distribution: {np.int64(0): np.int64(237), np.int64(1): np.int64(128), np.int64(2): np.int64(74)}
#
#   [SUBJECT S8] Loading raw data...
#   [FOUND] /content/WESAD/S8/S8.pkl
#   [SUBJECT S8] Extracting wrist signals...
#   [SUBJECT S8] BVP=349824 | EDA=21864 | TEMP=21864 | ACC=174912 | Labels=3826200
#   [SUBJECT S8] Building 60s windows with 5s step...
#   [SUBJECT S8] Applying baseline calibration...
#   [SUBJECT S8] Done: 442 windows | Class distribution: {np.int64(0): np.int64(234), np.int64(1): np.int64(134), np.int64(2): np.int64(74)}
#
#   [SUBJECT S9] Loading raw data...
#   [FOUND] /content/WESAD/S9/S9.pkl
#   [SUBJECT S9] Extracting wrist signals...
#   [SUBJECT S9] BVP=334272 | EDA=20892 | TEMP=20892 | ACC=167136 | Labels=3656100
#   [SUBJECT S9] Building 60s windows with 5s step...
#   [SUBJECT S9] Applying baseline calibration...
#   [SUBJECT S9] Done: 440 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(129), np.int64(2): np.int64(75)}
#
#   [SUBJECT S10] Loading raw data...
#   [FOUND] /content/WESAD/S10/S10.pkl
#   [SUBJECT S10] Extracting wrist signals...
#   [SUBJECT S10] BVP=351744 | EDA=21984 | TEMP=21984 | ACC=175872 | Labels=3847200
#   [SUBJECT S10] Building 60s windows with 5s step...
#   [SUBJECT S10] Applying baseline calibration...
#   [SUBJECT S10] Done: 455 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(145), np.int64(2): np.int64(74)}
#
#   [SUBJECT S11] Loading raw data...
#   [FOUND] /content/WESAD/S11/S11.pkl
#   [SUBJECT S11] Extracting wrist signals...
#   [SUBJECT S11] BVP=334912 | EDA=20932 | TEMP=20932 | ACC=167456 | Labels=3663100
#   [SUBJECT S11] Building 60s windows with 5s step...
#   [SUBJECT S11] Applying baseline calibration...
#   [SUBJECT S11] Done: 446 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(136), np.int64(2): np.int64(74)}
#
#   [SUBJECT S13] Loading raw data...
#   [FOUND] /content/WESAD/S13/S13.pkl
#   [SUBJECT S13] Extracting wrist signals...
#   [SUBJECT S13] BVP=354368 | EDA=22148 | TEMP=22148 | ACC=177184 | Labels=3875900
#   [SUBJECT S13] Building 60s windows with 5s step...
#   [SUBJECT S13] Applying baseline calibration...
#   [SUBJECT S13] Done: 445 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(132), np.int64(2): np.int64(77)}
#
#   [SUBJECT S14] Loading raw data...
#   [FOUND] /content/WESAD/S14/S14.pkl
#   [SUBJECT S14] Extracting wrist signals...
#   [SUBJECT S14] BVP=355072 | EDA=22192 | TEMP=22192 | ACC=177536 | Labels=3883600
#   [SUBJECT S14] Building 60s windows with 5s step...
#   [SUBJECT S14] Applying baseline calibration...
#   [SUBJECT S14] Done: 445 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(135), np.int64(2): np.int64(74)}
#
#   [SUBJECT S15] Loading raw data...
#   [FOUND] /content/WESAD/S15/S15.pkl
#   [SUBJECT S15] Extracting wrist signals...
#   [SUBJECT S15] BVP=336128 | EDA=21008 | TEMP=21008 | ACC=168064 | Labels=3676400
#   [SUBJECT S15] Building 60s windows with 5s step...
#   [SUBJECT S15] Applying baseline calibration...
#   [SUBJECT S15] Done: 447 windows | Class distribution: {np.int64(0): np.int64(235), np.int64(1): np.int64(138), np.int64(2): np.int64(74)}
#
#   [SUBJECT S16] Loading raw data...
#   [FOUND] /content/WESAD/S16/S16.pkl
#   [SUBJECT S16] Extracting wrist signals...
#   [SUBJECT S16] BVP=360384 | EDA=22524 | TEMP=22524 | ACC=180192 | Labels=3941700
#   [SUBJECT S16] Building 60s windows with 5s step...
#   [SUBJECT S16] Applying baseline calibration...
#   [SUBJECT S16] Done: 444 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(135), np.int64(2): np.int64(73)}
#
#   [SUBJECT S17] Loading raw data...
#   [FOUND] /content/WESAD/S17/S17.pkl
#   [SUBJECT S17] Extracting wrist signals...
#   [SUBJECT S17] BVP=378880 | EDA=23680 | TEMP=23680 | ACC=189440 | Labels=4144000
#   [SUBJECT S17] Building 60s windows with 5s step...
#   [SUBJECT S17] Applying baseline calibration...
#   [SUBJECT S17] Done: 455 windows | Class distribution: {np.int64(0): np.int64(236), np.int64(1): np.int64(145), np.int64(2): np.int64(74)}
#
# [INFO] 15/15 subjects have usable data:
#        ['S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S13', 'S14', 'S15', 'S16', 'S17']
#
# [STEP 2] Running Leave-One-Subject-Out Cross-Validation...
#
# ======================================================================
# [FOLD] Test Subject: S2
# ======================================================================
#   Train: 5774 windows | Val (S3): 431 | Test (S2): 425
#   Train class distribution: {np.int64(0): np.int64(3065), np.int64(1): np.int64(1743), np.int64(2): np.int64(966)}
#   Class weights: {'Baseline': np.float32(0.6279), 'Stress': np.float32(1.1042), 'Amusement': np.float32(1.9924)}
#   Epoch [1/40] | Train Loss: 0.4763 Acc: 0.8135 | Val Loss: 1.1885 Acc: 0.5406 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2398 Acc: 0.9087 | Val Loss: 1.2708 Acc: 0.6102 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.1600 Acc: 0.9385 | Val Loss: 2.0531 Acc: 0.5916 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.1504 Acc: 0.9434 | Val Loss: 1.8298 Acc: 0.5800 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.1099 Acc: 0.9575 | Val Loss: 1.9085 Acc: 0.5824 | LR: 3.50e-04
#   Epoch [6/40] | Train Loss: 0.0784 Acc: 0.9714 | Val Loss: 2.2629 Acc: 0.5916 | LR: 3.50e-04
#   Epoch [7/40] | Train Loss: 0.0678 Acc: 0.9743 | Val Loss: 2.0602 Acc: 0.6427 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0564 Acc: 0.9795 | Val Loss: 2.4241 Acc: 0.5916 | LR: 3.50e-04
#   Epoch [9/40] | Train Loss: 0.0504 Acc: 0.9807 | Val Loss: 2.0997 Acc: 0.6241 | LR: 1.75e-04
#   Epoch [10/40] | Train Loss: 0.0381 Acc: 0.9858 | Val Loss: 2.3489 Acc: 0.6265 | LR: 1.75e-04
#   Epoch [11/40] | Train Loss: 0.0347 Acc: 0.9875 | Val Loss: 2.3051 Acc: 0.6357 | LR: 1.75e-04
#   Epoch [12/40] | Train Loss: 0.0352 Acc: 0.9877 | Val Loss: 2.5485 Acc: 0.6381 | LR: 1.75e-04
#   Epoch [13/40] | Train Loss: 0.0396 Acc: 0.9878 | Val Loss: 2.4541 Acc: 0.6334 | LR: 8.75e-05
#   Epoch [14/40] | Train Loss: 0.0269 Acc: 0.9910 | Val Loss: 2.4585 Acc: 0.6311 | LR: 8.75e-05
#   Epoch [15/40] | Train Loss: 0.0247 Acc: 0.9915 | Val Loss: 2.3159 Acc: 0.6381 | LR: 8.75e-05
#   Early stopping at epoch 15 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S2 | Best Val Acc: 0.6427 | TEST Acc: 0.8141 | Balanced Acc: 0.7099 | Macro F1: 0.7097
#
# ======================================================================
# [FOLD] Test Subject: S3
# ======================================================================
#   Train: 5774 windows | Val (S2): 425 | Test (S3): 431
#   Train class distribution: {np.int64(0): np.int64(3065), np.int64(1): np.int64(1743), np.int64(2): np.int64(966)}
#   Class weights: {'Baseline': np.float32(0.6279), 'Stress': np.float32(1.1042), 'Amusement': np.float32(1.9924)}
#   Epoch [1/40] | Train Loss: 0.4827 Acc: 0.8222 | Val Loss: 0.8093 Acc: 0.6118 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2300 Acc: 0.9115 | Val Loss: 0.6766 Acc: 0.7106 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.1686 Acc: 0.9418 | Val Loss: 0.4950 Acc: 0.8024 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.1395 Acc: 0.9451 | Val Loss: 0.5178 Acc: 0.7671 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.1066 Acc: 0.9616 | Val Loss: 0.6710 Acc: 0.7365 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0885 Acc: 0.9684 | Val Loss: 0.8762 Acc: 0.7624 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0783 Acc: 0.9714 | Val Loss: 0.3874 Acc: 0.8329 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0780 Acc: 0.9720 | Val Loss: 0.6012 Acc: 0.7906 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0591 Acc: 0.9806 | Val Loss: 0.5702 Acc: 0.8071 | LR: 7.00e-04
#   Epoch [10/40] | Train Loss: 0.0410 Acc: 0.9852 | Val Loss: 0.4516 Acc: 0.8118 | LR: 7.00e-04
#   Epoch [11/40] | Train Loss: 0.0448 Acc: 0.9828 | Val Loss: 0.5922 Acc: 0.8518 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [12/40] | Train Loss: 0.0291 Acc: 0.9910 | Val Loss: 0.5455 Acc: 0.8024 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0312 Acc: 0.9903 | Val Loss: 0.7440 Acc: 0.7553 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0215 Acc: 0.9931 | Val Loss: 0.8149 Acc: 0.7741 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0291 Acc: 0.9917 | Val Loss: 0.6794 Acc: 0.7741 | LR: 1.75e-04
#   Epoch [16/40] | Train Loss: 0.0174 Acc: 0.9950 | Val Loss: 0.6501 Acc: 0.7859 | LR: 1.75e-04
#   Epoch [17/40] | Train Loss: 0.0173 Acc: 0.9950 | Val Loss: 0.5406 Acc: 0.8165 | LR: 1.75e-04
#   Epoch [18/40] | Train Loss: 0.0174 Acc: 0.9955 | Val Loss: 0.5817 Acc: 0.8094 | LR: 1.75e-04
#   Epoch [19/40] | Train Loss: 0.0145 Acc: 0.9946 | Val Loss: 0.5514 Acc: 0.8141 | LR: 8.75e-05
#   Early stopping at epoch 19 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S3 | Best Val Acc: 0.8518 | TEST Acc: 0.6450 | Balanced Acc: 0.6063 | Macro F1: 0.4814
#
# ======================================================================
# [FOLD] Test Subject: S4
# ======================================================================
#   Train: 5773 windows | Val (S2): 425 | Test (S4): 432
#   Train class distribution: {np.int64(0): np.int64(3062), np.int64(1): np.int64(1744), np.int64(2): np.int64(967)}
#   Class weights: {'Baseline': np.float32(0.6285), 'Stress': np.float32(1.1034), 'Amusement': np.float32(1.99)}
#   Epoch [1/40] | Train Loss: 0.5321 Acc: 0.8057 | Val Loss: 0.7327 Acc: 0.6329 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2690 Acc: 0.9014 | Val Loss: 0.8732 Acc: 0.6259 | LR: 7.00e-04
#   Epoch [3/40] | Train Loss: 0.2085 Acc: 0.9255 | Val Loss: 0.8780 Acc: 0.6282 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.1615 Acc: 0.9375 | Val Loss: 0.6083 Acc: 0.7106 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.1314 Acc: 0.9538 | Val Loss: 0.3948 Acc: 0.8141 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [6/40] | Train Loss: 0.1162 Acc: 0.9590 | Val Loss: 0.6201 Acc: 0.6988 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0890 Acc: 0.9670 | Val Loss: 0.4055 Acc: 0.8259 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0719 Acc: 0.9729 | Val Loss: 0.4412 Acc: 0.8071 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0799 Acc: 0.9698 | Val Loss: 0.5516 Acc: 0.8141 | LR: 3.50e-04
#   Epoch [10/40] | Train Loss: 0.0525 Acc: 0.9823 | Val Loss: 0.2821 Acc: 0.8729 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [11/40] | Train Loss: 0.0469 Acc: 0.9833 | Val Loss: 0.4277 Acc: 0.8306 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0353 Acc: 0.9885 | Val Loss: 0.2532 Acc: 0.9082 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [13/40] | Train Loss: 0.0299 Acc: 0.9903 | Val Loss: 0.5809 Acc: 0.8659 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0416 Acc: 0.9865 | Val Loss: 0.3127 Acc: 0.9365 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [15/40] | Train Loss: 0.0389 Acc: 0.9878 | Val Loss: 0.4382 Acc: 0.8212 | LR: 3.50e-04
#   Epoch [16/40] | Train Loss: 0.0315 Acc: 0.9891 | Val Loss: 0.4714 Acc: 0.8094 | LR: 1.75e-04
#   Epoch [17/40] | Train Loss: 0.0236 Acc: 0.9917 | Val Loss: 0.3183 Acc: 0.8729 | LR: 1.75e-04
#   Epoch [18/40] | Train Loss: 0.0201 Acc: 0.9943 | Val Loss: 0.3261 Acc: 0.8753 | LR: 1.75e-04
#   Epoch [19/40] | Train Loss: 0.0164 Acc: 0.9941 | Val Loss: 0.3370 Acc: 0.8753 | LR: 1.75e-04
#   Epoch [20/40] | Train Loss: 0.0174 Acc: 0.9939 | Val Loss: 0.3204 Acc: 0.9271 | LR: 8.75e-05
#   Epoch [21/40] | Train Loss: 0.0139 Acc: 0.9950 | Val Loss: 0.3121 Acc: 0.9224 | LR: 8.75e-05
#   Epoch [22/40] | Train Loss: 0.0148 Acc: 0.9953 | Val Loss: 0.3863 Acc: 0.8612 | LR: 8.75e-05
#   Early stopping at epoch 22 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S4 | Best Val Acc: 0.9365 | TEST Acc: 0.8426 | Balanced Acc: 0.6968 | Macro F1: 0.6724
#
# ======================================================================
# [FOLD] Test Subject: S5
# ======================================================================
#   Train: 5761 windows | Val (S2): 425 | Test (S5): 444
#   Train class distribution: {np.int64(0): np.int64(3053), np.int64(1): np.int64(1742), np.int64(2): np.int64(966)}
#   Class weights: {'Baseline': np.float32(0.629), 'Stress': np.float32(1.1024), 'Amusement': np.float32(1.9879)}
#   Epoch [1/40] | Train Loss: 0.4996 Acc: 0.8222 | Val Loss: 0.8097 Acc: 0.5835 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2482 Acc: 0.9066 | Val Loss: 0.6422 Acc: 0.6800 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.2009 Acc: 0.9278 | Val Loss: 0.7068 Acc: 0.7106 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.1434 Acc: 0.9467 | Val Loss: 0.9997 Acc: 0.6847 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.1293 Acc: 0.9542 | Val Loss: 0.6405 Acc: 0.7553 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [6/40] | Train Loss: 0.1139 Acc: 0.9563 | Val Loss: 0.4106 Acc: 0.8235 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [7/40] | Train Loss: 0.0833 Acc: 0.9679 | Val Loss: 0.5566 Acc: 0.8306 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0812 Acc: 0.9700 | Val Loss: 0.4286 Acc: 0.8188 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0749 Acc: 0.9734 | Val Loss: 0.4163 Acc: 0.8376 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [10/40] | Train Loss: 0.0631 Acc: 0.9786 | Val Loss: 0.5153 Acc: 0.8329 | LR: 3.50e-04
#   Epoch [11/40] | Train Loss: 0.0486 Acc: 0.9839 | Val Loss: 0.5639 Acc: 0.8118 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0332 Acc: 0.9878 | Val Loss: 0.7032 Acc: 0.7929 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0266 Acc: 0.9913 | Val Loss: 0.6185 Acc: 0.7882 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0314 Acc: 0.9898 | Val Loss: 0.4327 Acc: 0.8494 | LR: 1.75e-04  <-- BEST (val)
#   Epoch [15/40] | Train Loss: 0.0220 Acc: 0.9924 | Val Loss: 0.3954 Acc: 0.8541 | LR: 1.75e-04  <-- BEST (val)
#   Epoch [16/40] | Train Loss: 0.0216 Acc: 0.9938 | Val Loss: 0.4242 Acc: 0.8682 | LR: 1.75e-04  <-- BEST (val)
#   Epoch [17/40] | Train Loss: 0.0160 Acc: 0.9957 | Val Loss: 0.5158 Acc: 0.8259 | LR: 1.75e-04
#   Epoch [18/40] | Train Loss: 0.0165 Acc: 0.9955 | Val Loss: 0.5128 Acc: 0.8306 | LR: 1.75e-04
#   Epoch [19/40] | Train Loss: 0.0138 Acc: 0.9965 | Val Loss: 0.4184 Acc: 0.8635 | LR: 8.75e-05
#   Epoch [20/40] | Train Loss: 0.0169 Acc: 0.9939 | Val Loss: 0.4439 Acc: 0.8635 | LR: 8.75e-05
#   Epoch [21/40] | Train Loss: 0.0128 Acc: 0.9957 | Val Loss: 0.4710 Acc: 0.8424 | LR: 8.75e-05
#   Epoch [22/40] | Train Loss: 0.0128 Acc: 0.9964 | Val Loss: 0.4235 Acc: 0.8588 | LR: 8.75e-05
#   Epoch [23/40] | Train Loss: 0.0125 Acc: 0.9957 | Val Loss: 0.4139 Acc: 0.8682 | LR: 4.37e-05  <-- BEST (val)
#   Epoch [24/40] | Train Loss: 0.0111 Acc: 0.9964 | Val Loss: 0.3642 Acc: 0.8776 | LR: 4.37e-05  <-- BEST (val)
#   Epoch [25/40] | Train Loss: 0.0113 Acc: 0.9970 | Val Loss: 0.4400 Acc: 0.8565 | LR: 4.37e-05
#   Epoch [26/40] | Train Loss: 0.0110 Acc: 0.9965 | Val Loss: 0.4770 Acc: 0.8494 | LR: 4.37e-05
#   Epoch [27/40] | Train Loss: 0.0102 Acc: 0.9972 | Val Loss: 0.3788 Acc: 0.8800 | LR: 4.37e-05  <-- BEST (val)
#   Epoch [28/40] | Train Loss: 0.0113 Acc: 0.9969 | Val Loss: 0.4286 Acc: 0.8706 | LR: 2.19e-05
#   Epoch [29/40] | Train Loss: 0.0123 Acc: 0.9965 | Val Loss: 0.3898 Acc: 0.8729 | LR: 2.19e-05
#   Epoch [30/40] | Train Loss: 0.0110 Acc: 0.9965 | Val Loss: 0.3839 Acc: 0.8729 | LR: 2.19e-05
#   Epoch [31/40] | Train Loss: 0.0114 Acc: 0.9969 | Val Loss: 0.4002 Acc: 0.8753 | LR: 2.19e-05
#   Epoch [32/40] | Train Loss: 0.0105 Acc: 0.9964 | Val Loss: 0.3872 Acc: 0.8871 | LR: 1.09e-05  <-- BEST (val)
#   Epoch [33/40] | Train Loss: 0.0091 Acc: 0.9977 | Val Loss: 0.4357 Acc: 0.8659 | LR: 1.09e-05
#   Epoch [34/40] | Train Loss: 0.0114 Acc: 0.9967 | Val Loss: 0.4653 Acc: 0.8541 | LR: 1.09e-05
#   Epoch [35/40] | Train Loss: 0.0093 Acc: 0.9976 | Val Loss: 0.4173 Acc: 0.8729 | LR: 1.09e-05
#   Epoch [36/40] | Train Loss: 0.0130 Acc: 0.9969 | Val Loss: 0.4562 Acc: 0.8541 | LR: 5.47e-06
#   Epoch [37/40] | Train Loss: 0.0121 Acc: 0.9964 | Val Loss: 0.4574 Acc: 0.8565 | LR: 5.47e-06
#   Epoch [38/40] | Train Loss: 0.0098 Acc: 0.9969 | Val Loss: 0.4521 Acc: 0.8635 | LR: 5.47e-06
#   Epoch [39/40] | Train Loss: 0.0106 Acc: 0.9965 | Val Loss: 0.4151 Acc: 0.8706 | LR: 5.47e-06
#   Epoch [40/40] | Train Loss: 0.0095 Acc: 0.9965 | Val Loss: 0.4400 Acc: 0.8612 | LR: 2.73e-06
#   Early stopping at epoch 40 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S5 | Best Val Acc: 0.8871 | TEST Acc: 0.7252 | Balanced Acc: 0.6260 | Macro F1: 0.6199
#
# ======================================================================
# [FOLD] Test Subject: S6
# ======================================================================
#   Train: 5765 windows | Val (S2): 425 | Test (S6): 440
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1741), np.int64(2): np.int64(967)}
#   Class weights: {'Baseline': np.float32(0.6286), 'Stress': np.float32(1.1038), 'Amusement': np.float32(1.9872)}
#   Epoch [1/40] | Train Loss: 0.5030 Acc: 0.8219 | Val Loss: 0.8786 Acc: 0.6165 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2718 Acc: 0.8938 | Val Loss: 0.7820 Acc: 0.7012 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.2154 Acc: 0.9210 | Val Loss: 0.8009 Acc: 0.7388 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.1662 Acc: 0.9405 | Val Loss: 0.6577 Acc: 0.7129 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.1269 Acc: 0.9540 | Val Loss: 0.3329 Acc: 0.8471 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [6/40] | Train Loss: 0.1050 Acc: 0.9646 | Val Loss: 0.7799 Acc: 0.7012 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0969 Acc: 0.9674 | Val Loss: 0.7087 Acc: 0.7365 | LR: 7.00e-04
#   Epoch [8/40] | Train Loss: 0.0731 Acc: 0.9769 | Val Loss: 0.6247 Acc: 0.8141 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0651 Acc: 0.9793 | Val Loss: 0.8651 Acc: 0.7600 | LR: 3.50e-04
#   Epoch [10/40] | Train Loss: 0.0463 Acc: 0.9852 | Val Loss: 0.8577 Acc: 0.7718 | LR: 3.50e-04
#   Epoch [11/40] | Train Loss: 0.0361 Acc: 0.9873 | Val Loss: 0.6902 Acc: 0.8235 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0347 Acc: 0.9884 | Val Loss: 0.5263 Acc: 0.8376 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0394 Acc: 0.9851 | Val Loss: 1.2823 Acc: 0.7012 | LR: 1.75e-04
#   Early stopping at epoch 13 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S6 | Best Val Acc: 0.8471 | TEST Acc: 0.9523 | Balanced Acc: 0.9132 | Macro F1: 0.9314
#
# ======================================================================
# [FOLD] Test Subject: S7
# ======================================================================
#   Train: 5766 windows | Val (S2): 425 | Test (S7): 439
#   Train class distribution: {np.int64(0): np.int64(3056), np.int64(1): np.int64(1743), np.int64(2): np.int64(967)}
#   Class weights: {'Baseline': np.float32(0.6289), 'Stress': np.float32(1.1027), 'Amusement': np.float32(1.9876)}
#   Epoch [1/40] | Train Loss: 0.5027 Acc: 0.8293 | Val Loss: 1.0632 Acc: 0.5647 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2872 Acc: 0.8972 | Val Loss: 1.1516 Acc: 0.5506 | LR: 7.00e-04
#   Epoch [3/40] | Train Loss: 0.2289 Acc: 0.9139 | Val Loss: 0.7416 Acc: 0.7765 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.1742 Acc: 0.9358 | Val Loss: 0.8437 Acc: 0.7647 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.1565 Acc: 0.9422 | Val Loss: 1.0782 Acc: 0.6729 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.1306 Acc: 0.9521 | Val Loss: 0.7254 Acc: 0.7741 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.1180 Acc: 0.9543 | Val Loss: 1.1934 Acc: 0.6941 | LR: 7.00e-04
#   Epoch [8/40] | Train Loss: 0.1020 Acc: 0.9627 | Val Loss: 0.9090 Acc: 0.7247 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0749 Acc: 0.9740 | Val Loss: 0.8368 Acc: 0.7718 | LR: 7.00e-04
#   Epoch [10/40] | Train Loss: 0.0768 Acc: 0.9719 | Val Loss: 1.3554 Acc: 0.7012 | LR: 3.50e-04
#   Epoch [11/40] | Train Loss: 0.0480 Acc: 0.9842 | Val Loss: 1.0430 Acc: 0.7482 | LR: 3.50e-04
#   Early stopping at epoch 11 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S7 | Best Val Acc: 0.7765 | TEST Acc: 0.9658 | Balanced Acc: 0.9641 | Macro F1: 0.9559
#
# ======================================================================
# [FOLD] Test Subject: S8
# ======================================================================
#   Train: 5763 windows | Val (S2): 425 | Test (S8): 442
#   Train class distribution: {np.int64(0): np.int64(3059), np.int64(1): np.int64(1737), np.int64(2): np.int64(967)}
#   Class weights: {'Baseline': np.float32(0.628), 'Stress': np.float32(1.1059), 'Amusement': np.float32(1.9866)}
#   Epoch [1/40] | Train Loss: 0.5020 Acc: 0.8255 | Val Loss: 1.0298 Acc: 0.5576 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2410 Acc: 0.9168 | Val Loss: 1.4539 Acc: 0.6376 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.1753 Acc: 0.9418 | Val Loss: 0.6817 Acc: 0.7694 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.1338 Acc: 0.9495 | Val Loss: 1.0694 Acc: 0.6541 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.1001 Acc: 0.9672 | Val Loss: 0.5926 Acc: 0.7906 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [6/40] | Train Loss: 0.0728 Acc: 0.9760 | Val Loss: 0.7236 Acc: 0.7882 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0538 Acc: 0.9816 | Val Loss: 0.9012 Acc: 0.7671 | LR: 7.00e-04
#   Epoch [8/40] | Train Loss: 0.0656 Acc: 0.9788 | Val Loss: 1.4206 Acc: 0.7200 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0469 Acc: 0.9849 | Val Loss: 0.8046 Acc: 0.7506 | LR: 3.50e-04
#   Epoch [10/40] | Train Loss: 0.0359 Acc: 0.9885 | Val Loss: 1.0576 Acc: 0.7671 | LR: 3.50e-04
#   Epoch [11/40] | Train Loss: 0.0261 Acc: 0.9918 | Val Loss: 0.6375 Acc: 0.7906 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0337 Acc: 0.9896 | Val Loss: 1.1077 Acc: 0.7271 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0326 Acc: 0.9892 | Val Loss: 1.3527 Acc: 0.6824 | LR: 1.75e-04
#   Early stopping at epoch 13 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S8 | Best Val Acc: 0.7906 | TEST Acc: 0.8326 | Balanced Acc: 0.6667 | Macro F1: 0.6212
#
# ======================================================================
# [FOLD] Test Subject: S9
# ======================================================================
#   Train: 5765 windows | Val (S2): 425 | Test (S9): 440
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1742), np.int64(2): np.int64(966)}
#   Class weights: {'Baseline': np.float32(0.6286), 'Stress': np.float32(1.1031), 'Amusement': np.float32(1.9893)}
#   Epoch [1/40] | Train Loss: 0.4673 Acc: 0.8274 | Val Loss: 1.0896 Acc: 0.5976 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2393 Acc: 0.9075 | Val Loss: 0.6755 Acc: 0.7341 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.1821 Acc: 0.9255 | Val Loss: 0.8097 Acc: 0.7718 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.1539 Acc: 0.9434 | Val Loss: 1.0233 Acc: 0.7506 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.1072 Acc: 0.9597 | Val Loss: 0.9669 Acc: 0.7388 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.0815 Acc: 0.9677 | Val Loss: 1.0077 Acc: 0.7200 | LR: 3.50e-04
#   Epoch [7/40] | Train Loss: 0.0802 Acc: 0.9694 | Val Loss: 1.2055 Acc: 0.7647 | LR: 3.50e-04
#   Epoch [8/40] | Train Loss: 0.0463 Acc: 0.9845 | Val Loss: 0.8188 Acc: 0.7976 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [9/40] | Train Loss: 0.0540 Acc: 0.9830 | Val Loss: 1.4778 Acc: 0.7671 | LR: 3.50e-04
#   Epoch [10/40] | Train Loss: 0.0423 Acc: 0.9866 | Val Loss: 0.6052 Acc: 0.8094 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [11/40] | Train Loss: 0.0457 Acc: 0.9837 | Val Loss: 1.0255 Acc: 0.7929 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0310 Acc: 0.9894 | Val Loss: 0.8482 Acc: 0.7906 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0309 Acc: 0.9899 | Val Loss: 0.5521 Acc: 0.8282 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [14/40] | Train Loss: 0.0308 Acc: 0.9898 | Val Loss: 0.9026 Acc: 0.7788 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0295 Acc: 0.9901 | Val Loss: 1.0056 Acc: 0.7812 | LR: 3.50e-04
#   Epoch [16/40] | Train Loss: 0.0235 Acc: 0.9929 | Val Loss: 1.5164 Acc: 0.7482 | LR: 3.50e-04
#   Epoch [17/40] | Train Loss: 0.0209 Acc: 0.9932 | Val Loss: 0.7573 Acc: 0.7906 | LR: 1.75e-04
#   Epoch [18/40] | Train Loss: 0.0147 Acc: 0.9951 | Val Loss: 1.1019 Acc: 0.7788 | LR: 1.75e-04
#   Epoch [19/40] | Train Loss: 0.0210 Acc: 0.9934 | Val Loss: 1.1440 Acc: 0.7812 | LR: 1.75e-04
#   Epoch [20/40] | Train Loss: 0.0172 Acc: 0.9953 | Val Loss: 0.9757 Acc: 0.7929 | LR: 1.75e-04
#   Epoch [21/40] | Train Loss: 0.0157 Acc: 0.9941 | Val Loss: 0.9006 Acc: 0.7929 | LR: 8.75e-05
#   Early stopping at epoch 21 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S9 | Best Val Acc: 0.8282 | TEST Acc: 0.8818 | Balanced Acc: 0.8321 | Macro F1: 0.8299
#
# ======================================================================
# [FOLD] Test Subject: S10
# ======================================================================
#   Train: 5750 windows | Val (S2): 425 | Test (S10): 455
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1726), np.int64(2): np.int64(967)}
#   Class weights: {'Baseline': np.float32(0.627), 'Stress': np.float32(1.1105), 'Amusement': np.float32(1.9821)}
#   Epoch [1/40] | Train Loss: 0.4702 Acc: 0.8327 | Val Loss: 0.6382 Acc: 0.7459 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2549 Acc: 0.9108 | Val Loss: 0.8792 Acc: 0.6635 | LR: 7.00e-04
#   Epoch [3/40] | Train Loss: 0.2079 Acc: 0.9242 | Val Loss: 1.0611 Acc: 0.7224 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.1626 Acc: 0.9463 | Val Loss: 0.4726 Acc: 0.7647 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.1225 Acc: 0.9589 | Val Loss: 0.3813 Acc: 0.8047 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [6/40] | Train Loss: 0.1080 Acc: 0.9628 | Val Loss: 1.0512 Acc: 0.7906 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0961 Acc: 0.9661 | Val Loss: 0.5320 Acc: 0.8118 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0859 Acc: 0.9693 | Val Loss: 0.7899 Acc: 0.7647 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0620 Acc: 0.9784 | Val Loss: 0.7221 Acc: 0.7318 | LR: 3.50e-04
#   Epoch [10/40] | Train Loss: 0.0422 Acc: 0.9860 | Val Loss: 0.8282 Acc: 0.7953 | LR: 3.50e-04
#   Epoch [11/40] | Train Loss: 0.0480 Acc: 0.9821 | Val Loss: 0.8421 Acc: 0.7929 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0388 Acc: 0.9853 | Val Loss: 0.7889 Acc: 0.7694 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0327 Acc: 0.9891 | Val Loss: 0.4894 Acc: 0.8447 | LR: 1.75e-04  <-- BEST (val)
#   Epoch [14/40] | Train Loss: 0.0271 Acc: 0.9914 | Val Loss: 0.6726 Acc: 0.8212 | LR: 1.75e-04
#   Epoch [15/40] | Train Loss: 0.0206 Acc: 0.9930 | Val Loss: 0.7404 Acc: 0.8047 | LR: 1.75e-04
#   Epoch [16/40] | Train Loss: 0.0239 Acc: 0.9928 | Val Loss: 0.5656 Acc: 0.8306 | LR: 1.75e-04
#   Epoch [17/40] | Train Loss: 0.0210 Acc: 0.9923 | Val Loss: 0.8155 Acc: 0.7906 | LR: 8.75e-05
#   Epoch [18/40] | Train Loss: 0.0165 Acc: 0.9949 | Val Loss: 0.7568 Acc: 0.8165 | LR: 8.75e-05
#   Epoch [19/40] | Train Loss: 0.0204 Acc: 0.9928 | Val Loss: 0.6324 Acc: 0.8282 | LR: 8.75e-05
#   Epoch [20/40] | Train Loss: 0.0158 Acc: 0.9963 | Val Loss: 0.7810 Acc: 0.8024 | LR: 8.75e-05
#   Epoch [21/40] | Train Loss: 0.0156 Acc: 0.9949 | Val Loss: 0.7318 Acc: 0.8212 | LR: 4.37e-05
#   Early stopping at epoch 21 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S10 | Best Val Acc: 0.8447 | TEST Acc: 0.8769 | Balanced Acc: 0.7592 | Macro F1: 0.7779
#
# ======================================================================
# [FOLD] Test Subject: S11
# ======================================================================
#   Train: 5759 windows | Val (S2): 425 | Test (S11): 446
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1735), np.int64(2): np.int64(967)}
#   Class weights: {'Baseline': np.float32(0.628), 'Stress': np.float32(1.1064), 'Amusement': np.float32(1.9852)}
#   Epoch [1/40] | Train Loss: 0.4875 Acc: 0.8227 | Val Loss: 0.8336 Acc: 0.6471 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2616 Acc: 0.9033 | Val Loss: 0.4363 Acc: 0.7412 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.2173 Acc: 0.9199 | Val Loss: 0.3642 Acc: 0.8024 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [4/40] | Train Loss: 0.1640 Acc: 0.9400 | Val Loss: 0.3553 Acc: 0.8706 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.1338 Acc: 0.9505 | Val Loss: 0.4917 Acc: 0.7671 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.1204 Acc: 0.9561 | Val Loss: 0.4633 Acc: 0.7835 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0831 Acc: 0.9703 | Val Loss: 0.4701 Acc: 0.8259 | LR: 7.00e-04
#   Epoch [8/40] | Train Loss: 0.0796 Acc: 0.9689 | Val Loss: 0.5286 Acc: 0.8000 | LR: 3.50e-04
#   Epoch [9/40] | Train Loss: 0.0576 Acc: 0.9791 | Val Loss: 0.5272 Acc: 0.8118 | LR: 3.50e-04
#   Epoch [10/40] | Train Loss: 0.0414 Acc: 0.9854 | Val Loss: 0.5288 Acc: 0.8424 | LR: 3.50e-04
#   Epoch [11/40] | Train Loss: 0.0381 Acc: 0.9888 | Val Loss: 0.5599 Acc: 0.8329 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0275 Acc: 0.9912 | Val Loss: 0.5887 Acc: 0.8235 | LR: 1.75e-04
#   Early stopping at epoch 12 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S11 | Best Val Acc: 0.8706 | TEST Acc: 0.9686 | Balanced Acc: 0.9802 | Macro F1: 0.9610
#
# ======================================================================
# [FOLD] Test Subject: S13
# ======================================================================
#   Train: 5760 windows | Val (S2): 425 | Test (S13): 445
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1739), np.int64(2): np.int64(964)}
#   Class weights: {'Baseline': np.float32(0.6281), 'Stress': np.float32(1.1041), 'Amusement': np.float32(1.9917)}
#   Epoch [1/40] | Train Loss: 0.4971 Acc: 0.8115 | Val Loss: 1.0566 Acc: 0.6165 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2564 Acc: 0.9075 | Val Loss: 0.7421 Acc: 0.7765 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.1909 Acc: 0.9271 | Val Loss: 1.2087 Acc: 0.7224 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.1484 Acc: 0.9479 | Val Loss: 0.6803 Acc: 0.7176 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.1123 Acc: 0.9622 | Val Loss: 0.5357 Acc: 0.7624 | LR: 7.00e-04
#   Epoch [6/40] | Train Loss: 0.1079 Acc: 0.9608 | Val Loss: 0.6250 Acc: 0.7929 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [7/40] | Train Loss: 0.0876 Acc: 0.9696 | Val Loss: 1.3905 Acc: 0.6612 | LR: 7.00e-04
#   Epoch [8/40] | Train Loss: 0.0595 Acc: 0.9786 | Val Loss: 1.2994 Acc: 0.7129 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0578 Acc: 0.9797 | Val Loss: 0.5937 Acc: 0.8118 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [10/40] | Train Loss: 0.0370 Acc: 0.9891 | Val Loss: 0.7808 Acc: 0.7929 | LR: 3.50e-04
#   Epoch [11/40] | Train Loss: 0.0273 Acc: 0.9915 | Val Loss: 0.4705 Acc: 0.8494 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [12/40] | Train Loss: 0.0377 Acc: 0.9859 | Val Loss: 0.5885 Acc: 0.8259 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0253 Acc: 0.9925 | Val Loss: 1.3699 Acc: 0.7200 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0220 Acc: 0.9922 | Val Loss: 1.6005 Acc: 0.7035 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0239 Acc: 0.9922 | Val Loss: 0.9059 Acc: 0.7859 | LR: 1.75e-04
#   Epoch [16/40] | Train Loss: 0.0155 Acc: 0.9946 | Val Loss: 0.9643 Acc: 0.7671 | LR: 1.75e-04
#   Epoch [17/40] | Train Loss: 0.0137 Acc: 0.9953 | Val Loss: 0.9201 Acc: 0.7788 | LR: 1.75e-04
#   Epoch [18/40] | Train Loss: 0.0154 Acc: 0.9958 | Val Loss: 0.7401 Acc: 0.8165 | LR: 1.75e-04
#   Epoch [19/40] | Train Loss: 0.0153 Acc: 0.9957 | Val Loss: 1.4303 Acc: 0.7224 | LR: 8.75e-05
#   Early stopping at epoch 19 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S13 | Best Val Acc: 0.8494 | TEST Acc: 0.8270 | Balanced Acc: 0.6703 | Macro F1: 0.6349
#
# ======================================================================
# [FOLD] Test Subject: S14
# ======================================================================
#   Train: 5760 windows | Val (S2): 425 | Test (S14): 445
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1736), np.int64(2): np.int64(967)}
#   Class weights: {'Baseline': np.float32(0.6281), 'Stress': np.float32(1.106), 'Amusement': np.float32(1.9855)}
#   Epoch [1/40] | Train Loss: 0.4927 Acc: 0.8175 | Val Loss: 0.5440 Acc: 0.7529 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2692 Acc: 0.8969 | Val Loss: 0.7399 Acc: 0.7624 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.1942 Acc: 0.9290 | Val Loss: 0.6284 Acc: 0.7224 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.1397 Acc: 0.9491 | Val Loss: 0.9556 Acc: 0.7365 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.1249 Acc: 0.9564 | Val Loss: 1.2619 Acc: 0.6588 | LR: 3.50e-04
#   Epoch [6/40] | Train Loss: 0.0891 Acc: 0.9682 | Val Loss: 0.8363 Acc: 0.7482 | LR: 3.50e-04
#   Epoch [7/40] | Train Loss: 0.0721 Acc: 0.9757 | Val Loss: 0.6464 Acc: 0.7976 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0588 Acc: 0.9793 | Val Loss: 0.4815 Acc: 0.8376 | LR: 3.50e-04  <-- BEST (val)
#   Epoch [9/40] | Train Loss: 0.0593 Acc: 0.9826 | Val Loss: 1.4344 Acc: 0.6918 | LR: 3.50e-04
#   Epoch [10/40] | Train Loss: 0.0449 Acc: 0.9826 | Val Loss: 0.9441 Acc: 0.7694 | LR: 3.50e-04
#   Epoch [11/40] | Train Loss: 0.0491 Acc: 0.9826 | Val Loss: 0.5952 Acc: 0.8094 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0503 Acc: 0.9839 | Val Loss: 0.5992 Acc: 0.8141 | LR: 1.75e-04
#   Epoch [13/40] | Train Loss: 0.0340 Acc: 0.9892 | Val Loss: 0.7744 Acc: 0.7929 | LR: 1.75e-04
#   Epoch [14/40] | Train Loss: 0.0277 Acc: 0.9922 | Val Loss: 0.7700 Acc: 0.8094 | LR: 1.75e-04
#   Epoch [15/40] | Train Loss: 0.0308 Acc: 0.9908 | Val Loss: 0.6957 Acc: 0.8118 | LR: 1.75e-04
#   Epoch [16/40] | Train Loss: 0.0253 Acc: 0.9922 | Val Loss: 0.8777 Acc: 0.7976 | LR: 8.75e-05
#   Early stopping at epoch 16 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S14 | Best Val Acc: 0.8376 | TEST Acc: 0.6876 | Balanced Acc: 0.6486 | Macro F1: 0.5006
#
# ======================================================================
# [FOLD] Test Subject: S15
# ======================================================================
#   Train: 5758 windows | Val (S2): 425 | Test (S15): 447
#   Train class distribution: {np.int64(0): np.int64(3058), np.int64(1): np.int64(1733), np.int64(2): np.int64(967)}
#   Class weights: {'Baseline': np.float32(0.6276), 'Stress': np.float32(1.1075), 'Amusement': np.float32(1.9848)}
#   Epoch [1/40] | Train Loss: 0.4996 Acc: 0.8246 | Val Loss: 0.8524 Acc: 0.5906 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2718 Acc: 0.8957 | Val Loss: 0.7686 Acc: 0.6965 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.2065 Acc: 0.9184 | Val Loss: 0.9740 Acc: 0.6941 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.1581 Acc: 0.9398 | Val Loss: 0.7673 Acc: 0.7882 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.1233 Acc: 0.9515 | Val Loss: 0.5120 Acc: 0.7953 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [6/40] | Train Loss: 0.1062 Acc: 0.9587 | Val Loss: 1.9718 Acc: 0.6424 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.0989 Acc: 0.9628 | Val Loss: 0.6811 Acc: 0.7694 | LR: 7.00e-04
#   Epoch [8/40] | Train Loss: 0.0816 Acc: 0.9677 | Val Loss: 0.5245 Acc: 0.7553 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0809 Acc: 0.9723 | Val Loss: 0.4347 Acc: 0.8541 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [10/40] | Train Loss: 0.0517 Acc: 0.9796 | Val Loss: 0.4392 Acc: 0.8353 | LR: 7.00e-04
#   Epoch [11/40] | Train Loss: 0.0598 Acc: 0.9802 | Val Loss: 1.7099 Acc: 0.6682 | LR: 7.00e-04
#   Epoch [12/40] | Train Loss: 0.0442 Acc: 0.9856 | Val Loss: 0.3251 Acc: 0.8753 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [13/40] | Train Loss: 0.0377 Acc: 0.9896 | Val Loss: 0.3235 Acc: 0.8800 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [14/40] | Train Loss: 0.0421 Acc: 0.9854 | Val Loss: 1.1480 Acc: 0.7671 | LR: 7.00e-04
#   Epoch [15/40] | Train Loss: 0.0345 Acc: 0.9874 | Val Loss: 0.4190 Acc: 0.8635 | LR: 7.00e-04
#   Epoch [16/40] | Train Loss: 0.0463 Acc: 0.9861 | Val Loss: 0.7152 Acc: 0.7553 | LR: 7.00e-04
#   Epoch [17/40] | Train Loss: 0.0391 Acc: 0.9870 | Val Loss: 0.2671 Acc: 0.9318 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [18/40] | Train Loss: 0.0395 Acc: 0.9874 | Val Loss: 0.7516 Acc: 0.8094 | LR: 7.00e-04
#   Epoch [19/40] | Train Loss: 0.0191 Acc: 0.9946 | Val Loss: 0.3928 Acc: 0.8753 | LR: 7.00e-04
#   Epoch [20/40] | Train Loss: 0.0268 Acc: 0.9891 | Val Loss: 2.1403 Acc: 0.6635 | LR: 7.00e-04
#   Epoch [21/40] | Train Loss: 0.0244 Acc: 0.9916 | Val Loss: 0.3513 Acc: 0.9153 | LR: 3.50e-04
#   Epoch [22/40] | Train Loss: 0.0161 Acc: 0.9951 | Val Loss: 0.4468 Acc: 0.8588 | LR: 3.50e-04
#   Epoch [23/40] | Train Loss: 0.0129 Acc: 0.9953 | Val Loss: 0.5294 Acc: 0.8541 | LR: 3.50e-04
#   Epoch [24/40] | Train Loss: 0.0095 Acc: 0.9974 | Val Loss: 0.5040 Acc: 0.8518 | LR: 3.50e-04
#   Epoch [25/40] | Train Loss: 0.0107 Acc: 0.9963 | Val Loss: 0.6895 Acc: 0.8212 | LR: 1.75e-04
#   Early stopping at epoch 25 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S15 | Best Val Acc: 0.9318 | TEST Acc: 0.9866 | Balanced Acc: 0.9730 | Macro F1: 0.9793
#
# ======================================================================
# [FOLD] Test Subject: S16
# ======================================================================
#   Train: 5761 windows | Val (S2): 425 | Test (S16): 444
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1736), np.int64(2): np.int64(968)}
#   Class weights: {'Baseline': np.float32(0.6282), 'Stress': np.float32(1.1062), 'Amusement': np.float32(1.9838)}
#   Epoch [1/40] | Train Loss: 0.4742 Acc: 0.8236 | Val Loss: 0.9074 Acc: 0.6071 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2602 Acc: 0.9010 | Val Loss: 0.4343 Acc: 0.7835 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.1922 Acc: 0.9311 | Val Loss: 0.4485 Acc: 0.7835 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.1416 Acc: 0.9453 | Val Loss: 0.8204 Acc: 0.7741 | LR: 7.00e-04
#   Epoch [5/40] | Train Loss: 0.1366 Acc: 0.9507 | Val Loss: 0.6313 Acc: 0.8047 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [6/40] | Train Loss: 0.1092 Acc: 0.9604 | Val Loss: 0.5663 Acc: 0.7482 | LR: 3.50e-04
#   Epoch [7/40] | Train Loss: 0.0730 Acc: 0.9724 | Val Loss: 0.7210 Acc: 0.7412 | LR: 3.50e-04
#   Epoch [8/40] | Train Loss: 0.0619 Acc: 0.9774 | Val Loss: 0.8176 Acc: 0.7600 | LR: 3.50e-04
#   Epoch [9/40] | Train Loss: 0.0457 Acc: 0.9847 | Val Loss: 0.7528 Acc: 0.7647 | LR: 3.50e-04
#   Epoch [10/40] | Train Loss: 0.0504 Acc: 0.9811 | Val Loss: 0.4796 Acc: 0.8047 | LR: 1.75e-04  <-- BEST (val)
#   Epoch [11/40] | Train Loss: 0.0408 Acc: 0.9866 | Val Loss: 0.2888 Acc: 0.8706 | LR: 1.75e-04  <-- BEST (val)
#   Epoch [12/40] | Train Loss: 0.0332 Acc: 0.9887 | Val Loss: 0.6111 Acc: 0.7741 | LR: 1.75e-04
#   Epoch [13/40] | Train Loss: 0.0288 Acc: 0.9911 | Val Loss: 0.5735 Acc: 0.7765 | LR: 1.75e-04
#   Epoch [14/40] | Train Loss: 0.0281 Acc: 0.9915 | Val Loss: 0.5810 Acc: 0.7671 | LR: 1.75e-04
#   Epoch [15/40] | Train Loss: 0.0280 Acc: 0.9903 | Val Loss: 0.3081 Acc: 0.8541 | LR: 8.75e-05
#   Epoch [16/40] | Train Loss: 0.0259 Acc: 0.9922 | Val Loss: 0.5321 Acc: 0.7882 | LR: 8.75e-05
#   Epoch [17/40] | Train Loss: 0.0253 Acc: 0.9917 | Val Loss: 0.6724 Acc: 0.7576 | LR: 8.75e-05
#   Epoch [18/40] | Train Loss: 0.0222 Acc: 0.9922 | Val Loss: 0.4735 Acc: 0.8000 | LR: 8.75e-05
#   Epoch [19/40] | Train Loss: 0.0222 Acc: 0.9918 | Val Loss: 0.6892 Acc: 0.7365 | LR: 4.37e-05
#   Early stopping at epoch 19 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S16 | Best Val Acc: 0.8706 | TEST Acc: 0.9212 | Balanced Acc: 0.8402 | Macro F1: 0.8569
#
# ======================================================================
# [FOLD] Test Subject: S17
# ======================================================================
#   Train: 5750 windows | Val (S2): 425 | Test (S17): 455
#   Train class distribution: {np.int64(0): np.int64(3057), np.int64(1): np.int64(1726), np.int64(2): np.int64(967)}
#   Class weights: {'Baseline': np.float32(0.627), 'Stress': np.float32(1.1105), 'Amusement': np.float32(1.9821)}
#   Epoch [1/40] | Train Loss: 0.4902 Acc: 0.8172 | Val Loss: 1.2045 Acc: 0.4612 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [2/40] | Train Loss: 0.2641 Acc: 0.8955 | Val Loss: 0.7102 Acc: 0.6847 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [3/40] | Train Loss: 0.2067 Acc: 0.9226 | Val Loss: 0.7428 Acc: 0.6824 | LR: 7.00e-04
#   Epoch [4/40] | Train Loss: 0.1593 Acc: 0.9424 | Val Loss: 0.5513 Acc: 0.7882 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [5/40] | Train Loss: 0.1306 Acc: 0.9482 | Val Loss: 0.3370 Acc: 0.8212 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [6/40] | Train Loss: 0.1041 Acc: 0.9598 | Val Loss: 0.6160 Acc: 0.7671 | LR: 7.00e-04
#   Epoch [7/40] | Train Loss: 0.1206 Acc: 0.9577 | Val Loss: 0.2176 Acc: 0.8847 | LR: 7.00e-04  <-- BEST (val)
#   Epoch [8/40] | Train Loss: 0.0763 Acc: 0.9719 | Val Loss: 0.7784 Acc: 0.7318 | LR: 7.00e-04
#   Epoch [9/40] | Train Loss: 0.0671 Acc: 0.9759 | Val Loss: 0.5689 Acc: 0.6988 | LR: 7.00e-04
#   Epoch [10/40] | Train Loss: 0.0600 Acc: 0.9775 | Val Loss: 0.6828 Acc: 0.7365 | LR: 7.00e-04
#   Epoch [11/40] | Train Loss: 0.0433 Acc: 0.9842 | Val Loss: 1.3677 Acc: 0.6494 | LR: 3.50e-04
#   Epoch [12/40] | Train Loss: 0.0394 Acc: 0.9837 | Val Loss: 0.6146 Acc: 0.7953 | LR: 3.50e-04
#   Epoch [13/40] | Train Loss: 0.0309 Acc: 0.9909 | Val Loss: 0.3267 Acc: 0.8471 | LR: 3.50e-04
#   Epoch [14/40] | Train Loss: 0.0348 Acc: 0.9874 | Val Loss: 1.0475 Acc: 0.7318 | LR: 3.50e-04
#   Epoch [15/40] | Train Loss: 0.0289 Acc: 0.9907 | Val Loss: 0.5500 Acc: 0.8047 | LR: 1.75e-04
#   Early stopping at epoch 15 (no validation improvement for 8 epochs).
#
#   [FOLD RESULT] Subject S17 | Best Val Acc: 0.8847 | TEST Acc: 0.8396 | Balanced Acc: 0.8207 | Macro F1: 0.7895
#
# ======================================================================
#   LOSO CROSS-VALIDATION - FINAL RESULTS
# ======================================================================
#
# Per-Subject Holdout Results:
#   S2: Accuracy=0.8141 (81.41%) | Balanced Acc=0.7099 | Macro F1=0.7097
#   S3: Accuracy=0.6450 (64.50%) | Balanced Acc=0.6063 | Macro F1=0.4814
#   S4: Accuracy=0.8426 (84.26%) | Balanced Acc=0.6968 | Macro F1=0.6724
#   S5: Accuracy=0.7252 (72.52%) | Balanced Acc=0.6260 | Macro F1=0.6199
#   S6: Accuracy=0.9523 (95.23%) | Balanced Acc=0.9132 | Macro F1=0.9314
#   S7: Accuracy=0.9658 (96.58%) | Balanced Acc=0.9641 | Macro F1=0.9559
#   S8: Accuracy=0.8326 (83.26%) | Balanced Acc=0.6667 | Macro F1=0.6212
#   S9: Accuracy=0.8818 (88.18%) | Balanced Acc=0.8321 | Macro F1=0.8299
#   S10: Accuracy=0.8769 (87.69%) | Balanced Acc=0.7592 | Macro F1=0.7779
#   S11: Accuracy=0.9686 (96.86%) | Balanced Acc=0.9802 | Macro F1=0.9610
#   S13: Accuracy=0.8270 (82.70%) | Balanced Acc=0.6703 | Macro F1=0.6349
#   S14: Accuracy=0.6876 (68.76%) | Balanced Acc=0.6486 | Macro F1=0.5006
#   S15: Accuracy=0.9866 (98.66%) | Balanced Acc=0.9730 | Macro F1=0.9793
#   S16: Accuracy=0.9212 (92.12%) | Balanced Acc=0.8402 | Macro F1=0.8569
#   S17: Accuracy=0.8396 (83.96%) | Balanced Acc=0.8207 | Macro F1=0.7895
#
# Overall LOSO Accuracy: 0.8516 (85.16%)
# Overall Balanced Accuracy: 0.7803 (78.03%)
# Overall Macro F1: 0.7905
# Mean Per-Subject Accuracy: 0.8511 (±0.0999)
#
# ======================================================================
#   CLASSIFICATION REPORT
# ======================================================================
#               precision    recall  f1-score   support
#
#     Baseline     0.8861    0.9699    0.9261      3522
#       Stress     0.9272    0.7984    0.8580      1994
#    Amusement     0.6030    0.5727    0.5875      1114
#
#     accuracy                         0.8516      6630
#    macro avg     0.8054    0.7803    0.7905      6630
# weighted avg     0.8509    0.8516    0.8487      6630
#
#
# ======================================================================
#   CONFUSION MATRIX
# ======================================================================
# Confusion Matrix (Counts):
#            Baseline  Stress  Amusement
# Baseline       3416      11         95
# Stress           77    1592        325
# Amusement       362     114        638
#
# Confusion Matrix (Row %):
#            Baseline  Stress  Amusement
# Baseline      96.99    0.31       2.70
# Stress         3.86   79.84      16.30
# Amusement     32.50   10.23      57.27
#
# ======================================================================
#   PIPELINE COMPLETE
# ======================================================================
#
# Important:
# - The test subject was not used for checkpoint selection.
# - Scaling was fitted using training subjects only.
# - Validation subjects were used for early stopping.
# - The final reported test results are from held-out subjects.
#
# Possible next experiments:
# 1. WeightedRandomSampler for Amusement.
# 2. STEP_SEC=3 for more windows.
# 3. Add chest-device respiration/ECG features if available.
# 4. Compare against Random Forest/XGBoost using handcrafted features.
